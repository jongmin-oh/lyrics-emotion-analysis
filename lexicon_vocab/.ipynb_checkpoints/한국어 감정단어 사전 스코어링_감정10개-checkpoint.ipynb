# %%
from konlpy.tag import Kkma , Komoran , Okt
from collections import Counter
import matplotlib.pyplot as plt
import re

plt.style.use('default')

import pandas as pd
import numpy as np

# %%
kmoran = Komoran()

# %%
data = pd.read_excel('../preprocessing/emotion_labels(ko).xlsb.xlsx')
del data['Unnamed: 0']

# %%
data = data[data['emotion_v2'].notnull() & data['emotion_v2'] != 0]

# %%
data = data[['lyrics splited','emotion_v2']]

# %%
data['emotion_v2'].hist()
# Out:
# <AxesSubplot:>

# %%
emotion = {'thrill' : '' ,'love' : '' ,'fun' : '' , 'enthusiasm' : '' ,'happyness':''
           , 'sadness' : '' ,'anger': '','lonely': '' , 'longing' : '' , 'fear' : ''}

# %%
for i in range(len(emotion)):
    emotion_df = data[data['emotion_v2'] == i+1]
    corpus = " ".join(emotion_df['lyrics splited'].values)
    emotion[list(emotion.keys())[i]] = corpus

# %%
#코모란 형태소 분석기
def emotion_tokenizer(corpus):
    temp = []
    for i in kmoran.pos(corpus):
        if (i[1] == 'NNG' or i[1] == 'NNP'or i[1] == 'NNB' or i[1] == 'MAG' or i[1] == 'IC'):
            temp.append(i[0])
        elif (i[1] == 'VV' or i[1] == 'VA'):
            temp.append(i[0] + "다")
        elif (i[1] == 'SL'):
            temp.append(i[0].lower())
    return temp

# %%
emotion_count = {}
vocab = {}
for i in range(len(emotion)):
    emotion_key = list(emotion.keys())[i]
    emotion_count[emotion_key] = Counter(emotion_tokenizer(emotion[emotion_key])).most_common(1000)
    for words , counts in emotion_count[emotion_key]:
        if words in list(vocab.keys()):
            vocab[words][emotion_key] = counts
        else:
            vocab[words] = {emotion_key : counts }

# %%
emotion_keys = list(emotion.keys())
for word in list(vocab.keys()):
    total = sum(vocab[word].values())
    for keys in emotion_keys:
        try:
            vocab[word][keys] = round( (vocab[word][keys]  / total) , 2 )
        except KeyError:
            pass

# %%
vocab
# Out:
# {'있다': {'thrill': 0.36,
#   'love': 0.14,
#   'fun': 0.06,
#   'enthusiasm': 0.06,
#   'happyness': 0.09,
#   'sadness': 0.14,
#   'anger': 0.05,
#   'lonely': 0.05,
#   'longing': 0.05,
#   'fear': 0.01},
#  '보다': {'thrill': 0.42,
#   'love': 0.07,
#   'fun': 0.07,
#   'enthusiasm': 0.04,
#   'happyness': 0.04,
#   'sadness': 0.15,
#   'anger': 0.1,
#   'lonely': 0.04,
#   'longing': 0.04,
#   'fear': 0.01},
#  '하다': {'thrill': 0.22,
#   'love': 0.11,
#   'fun': 0.06,
#   'enthusiasm': 0.07,
#   'happyness': 0.04,
#   'sadness': 0.21,
#   'anger': 0.19,
#   'lonely': 0.04,
#   'longing': 0.05,
#   'fear': 0.02},
#  '맘': {'thrill': 0.6,
#   'love': 0.08,
#   'fun': 0.02,
#   'enthusiasm': 0.0,
#   'happyness': 0.02,
#   'sadness': 0.19,
#   'anger': 0.04,
#   'lonely': 0.03,
#   'longing': 0.02,
#   'fear': 0.0},
#  '나다': {'thrill': 0.22,
#   'love': 0.09,
#   'fun': 0.08,
#   'enthusiasm': 0.12,
#   'happyness': 0.06,
#   'sadness': 0.19,
#   'anger': 0.13,
#   'lonely': 0.06,
#   'longing': 0.04,
#   'fear': 0.02},
#  '말': {'thrill': 0.32,
#   'love': 0.13,
#   'fun': 0.07,
#   'enthusiasm': 0.05,
#   'happyness': 0.03,
#   'sadness': 0.17,
#   'anger': 0.18,
#   'lonely': 0.01,
#   'longing': 0.02,
#   'fear': 0.02},
#  '날': {'thrill': 0.3,
#   'love': 0.13,
#   'fun': 0.05,
#   'enthusiasm': 0.05,
#   'happyness': 0.05,
#   'sadness': 0.19,
#   'anger': 0.12,
#   'lonely': 0.05,
#   'longing': 0.05,
#   'fear': 0.01},
#  '수': {'thrill': 0.29,
#   'love': 0.08,
#   'fun': 0.03,
#   'enthusiasm': 0.06,
#   'happyness': 0.03,
#   'sadness': 0.23,
#   'anger': 0.07,
#   'lonely': 0.07,
#   'longing': 0.09,
#   'fear': 0.04},
#  '생각': {'thrill': 0.57,
#   'love': 0.04,
#   'fun': 0.04,
#   'enthusiasm': 0.04,
#   'happyness': 0.02,
#   'sadness': 0.12,
#   'anger': 0.09,
#   'lonely': 0.02,
#   'longing': 0.06,
#   'fear': 0.01},
#  '눈': {'thrill': 0.57,
#   'love': 0.09,
#   'fun': 0.04,
#   'enthusiasm': 0.01,
#   'happyness': 0.07,
#   'sadness': 0.09,
#   'anger': 0.06,
#   'lonely': 0.03,
#   'longing': 0.02,
#   'fear': 0.01},
#  '같다': {'thrill': 0.37,
#   'love': 0.12,
#   'fun': 0.05,
#   'enthusiasm': 0.04,
#   'happyness': 0.04,
#   'sadness': 0.19,
#   'anger': 0.08,
#   'lonely': 0.06,
#   'longing': 0.02,
#   'fear': 0.02},
#  '되다': {'thrill': 0.28,
#   'love': 0.14,
#   'fun': 0.06,
#   'enthusiasm': 0.11,
#   'happyness': 0.08,
#   'sadness': 0.14,
#   'anger': 0.12,
#   'lonely': 0.02,
#   'longing': 0.03,
#   'fear': 0.01},
#  '마음': {'thrill': 0.47,
#   'love': 0.12,
#   'fun': 0.02,
#   'enthusiasm': 0.01,
#   'happyness': 0.04,
#   'sadness': 0.26,
#   'anger': 0.01,
#   'lonely': 0.04,
#   'longing': 0.03,
#   'fear': 0.01},
#  '함께': {'thrill': 0.58,
#   'love': 0.15,
#   'fun': 0.09,
#   'enthusiasm': 0.01,
#   'happyness': 0.05,
#   'sadness': 0.03,
#   'anger': 0.03,
#   'lonely': 0.01,
#   'longing': 0.05},
#  '알다': {'thrill': 0.34,
#   'love': 0.1,
#   'fun': 0.07,
#   'enthusiasm': 0.03,
#   'happyness': 0.06,
#   'sadness': 0.18,
#   'anger': 0.14,
#   'lonely': 0.03,
#   'longing': 0.03,
#   'fear': 0.01},
#  '기다리다': {'thrill': 0.77,
#   'love': 0.04,
#   'happyness': 0.01,
#   'sadness': 0.08,
#   'anger': 0.03,
#   'lonely': 0.01,
#   'longing': 0.07},
#  '것': {'thrill': 0.26,
#   'love': 0.13,
#   'fun': 0.04,
#   'enthusiasm': 0.07,
#   'happyness': 0.06,
#   'sadness': 0.22,
#   'anger': 0.1,
#   'lonely': 0.06,
#   'longing': 0.05,
#   'fear': 0.02},
#  '밤': {'thrill': 0.35,
#   'love': 0.05,
#   'fun': 0.33,
#   'enthusiasm': 0.01,
#   'happyness': 0.03,
#   'sadness': 0.1,
#   'anger': 0.02,
#   'lonely': 0.08,
#   'fear': 0.02},
#  '오늘': {'thrill': 0.39,
#   'love': 0.05,
#   'fun': 0.17,
#   'enthusiasm': 0.08,
#   'happyness': 0.05,
#   'sadness': 0.11,
#   'anger': 0.06,
#   'lonely': 0.06,
#   'longing': 0.02,
#   'fear': 0.01},
#  '좋다': {'thrill': 0.42,
#   'love': 0.21,
#   'fun': 0.05,
#   'enthusiasm': 0.01,
#   'happyness': 0.22,
#   'sadness': 0.03,
#   'anger': 0.03,
#   'lonely': 0.01,
#   'longing': 0.01},
#  '때': {'thrill': 0.27,
#   'love': 0.11,
#   'fun': 0.09,
#   'enthusiasm': 0.07,
#   'happyness': 0.04,
#   'sadness': 0.18,
#   'anger': 0.07,
#   'lonely': 0.07,
#   'longing': 0.08,
#   'fear': 0.01},
#  '거': {'thrill': 0.25,
#   'love': 0.16,
#   'fun': 0.05,
#   'enthusiasm': 0.1,
#   'happyness': 0.1,
#   'sadness': 0.16,
#   'anger': 0.11,
#   'lonely': 0.05,
#   'longing': 0.02,
#   'fear': 0.0},
#  '만나다': {'thrill': 0.55,
#   'love': 0.07,
#   'fun': 0.03,
#   'enthusiasm': 0.01,
#   'happyness': 0.08,
#   'sadness': 0.12,
#   'anger': 0.06,
#   'lonely': 0.02,
#   'longing': 0.07},
#  '내다': {'thrill': 0.3,
#   'love': 0.2,
#   'fun': 0.05,
#   'enthusiasm': 0.05,
#   'happyness': 0.06,
#   'sadness': 0.18,
#   'anger': 0.08,
#   'lonely': 0.02,
#   'longing': 0.06,
#   'fear': 0.01},
#  '걸다': {'thrill': 0.28,
#   'love': 0.13,
#   'fun': 0.04,
#   'enthusiasm': 0.07,
#   'happyness': 0.04,
#   'sadness': 0.21,
#   'anger': 0.09,
#   'lonely': 0.09,
#   'longing': 0.03,
#   'fear': 0.02},
#  '모습': {'thrill': 0.46,
#   'love': 0.07,
#   'happyness': 0.03,
#   'sadness': 0.21,
#   'anger': 0.03,
#   'lonely': 0.09,
#   'longing': 0.09,
#   'fear': 0.02},
#  '속': {'thrill': 0.35,
#   'love': 0.08,
#   'fun': 0.08,
#   'enthusiasm': 0.03,
#   'happyness': 0.04,
#   'sadness': 0.11,
#   'anger': 0.05,
#   'lonely': 0.07,
#   'longing': 0.12,
#   'fear': 0.07},
#  '넌': {'thrill': 0.33,
#   'love': 0.1,
#   'fun': 0.06,
#   'enthusiasm': 0.02,
#   'happyness': 0.07,
#   'sadness': 0.13,
#   'anger': 0.2,
#   'lonely': 0.06,
#   'longing': 0.02,
#   'fear': 0.01},
#  '없다': {'thrill': 0.11,
#   'love': 0.08,
#   'fun': 0.02,
#   'enthusiasm': 0.05,
#   'happyness': 0.01,
#   'sadness': 0.24,
#   'anger': 0.17,
#   'lonely': 0.19,
#   'longing': 0.07,
#   'fear': 0.05},
#  '손': {'thrill': 0.59,
#   'love': 0.15,
#   'fun': 0.08,
#   'enthusiasm': 0.04,
#   'happyness': 0.01,
#   'sadness': 0.07,
#   'anger': 0.04,
#   'longing': 0.01,
#   'fear': 0.01},
#  '오다': {'thrill': 0.35,
#   'love': 0.15,
#   'fun': 0.07,
#   'enthusiasm': 0.05,
#   'happyness': 0.05,
#   'sadness': 0.14,
#   'anger': 0.06,
#   'lonely': 0.05,
#   'longing': 0.07},
#  '가다': {'thrill': 0.26,
#   'love': 0.07,
#   'fun': 0.1,
#   'enthusiasm': 0.14,
#   'happyness': 0.05,
#   'sadness': 0.12,
#   'anger': 0.08,
#   'lonely': 0.1,
#   'longing': 0.07,
#   'fear': 0.01},
#  '더': {'thrill': 0.2,
#   'love': 0.1,
#   'fun': 0.11,
#   'enthusiasm': 0.07,
#   'happyness': 0.06,
#   'sadness': 0.18,
#   'anger': 0.17,
#   'lonely': 0.05,
#   'longing': 0.03,
#   'fear': 0.01},
#  '걷다': {'thrill': 0.6,
#   'love': 0.01,
#   'fun': 0.06,
#   'enthusiasm': 0.09,
#   'sadness': 0.09,
#   'lonely': 0.09,
#   'longing': 0.05,
#   'fear': 0.02},
#  '지금': {'thrill': 0.33,
#   'love': 0.14,
#   'fun': 0.17,
#   'enthusiasm': 0.07,
#   'happyness': 0.05,
#   'sadness': 0.13,
#   'anger': 0.05,
#   'lonely': 0.02,
#   'longing': 0.03,
#   'fear': 0.01},
#  '안': {'thrill': 0.24,
#   'love': 0.14,
#   'fun': 0.07,
#   'enthusiasm': 0.03,
#   'happyness': 0.03,
#   'sadness': 0.17,
#   'anger': 0.23,
#   'lonely': 0.05,
#   'longing': 0.02,
#   'fear': 0.02},
#  '이제': {'thrill': 0.18,
#   'love': 0.15,
#   'fun': 0.04,
#   'enthusiasm': 0.08,
#   'happyness': 0.03,
#   'sadness': 0.22,
#   'anger': 0.16,
#   'lonely': 0.06,
#   'longing': 0.08,
#   'fear': 0.01},
#  '다시': {'thrill': 0.29,
#   'love': 0.08,
#   'fun': 0.06,
#   'enthusiasm': 0.07,
#   'happyness': 0.02,
#   'sadness': 0.13,
#   'anger': 0.09,
#   'lonely': 0.03,
#   'longing': 0.22},
#  '들다': {'thrill': 0.41,
#   'love': 0.02,
#   'fun': 0.15,
#   'enthusiasm': 0.04,
#   'happyness': 0.08,
#   'sadness': 0.1,
#   'anger': 0.14,
#   'lonely': 0.06,
#   'longing': 0.02},
#  '시간': {'thrill': 0.3,
#   'love': 0.09,
#   'fun': 0.09,
#   'enthusiasm': 0.06,
#   'happyness': 0.03,
#   'sadness': 0.19,
#   'anger': 0.05,
#   'lonely': 0.04,
#   'longing': 0.12,
#   'fear': 0.02},
#  '다': {'thrill': 0.18,
#   'love': 0.15,
#   'fun': 0.13,
#   'enthusiasm': 0.08,
#   'happyness': 0.06,
#   'sadness': 0.16,
#   'anger': 0.16,
#   'lonely': 0.05,
#   'longing': 0.03},
#  '이렇다': {'thrill': 0.31,
#   'love': 0.15,
#   'fun': 0.06,
#   'enthusiasm': 0.01,
#   'happyness': 0.01,
#   'sadness': 0.22,
#   'anger': 0.11,
#   'lonely': 0.1,
#   'longing': 0.03,
#   'fear': 0.01},
#  '아직': {'thrill': 0.41,
#   'love': 0.09,
#   'enthusiasm': 0.06,
#   'happyness': 0.03,
#   'sadness': 0.17,
#   'anger': 0.06,
#   'lonely': 0.04,
#   'longing': 0.11,
#   'fear': 0.02},
#  '바라보다': {'thrill': 0.66,
#   'love': 0.12,
#   'enthusiasm': 0.02,
#   'happyness': 0.05,
#   'sadness': 0.09,
#   'anger': 0.03,
#   'lonely': 0.03},
#  '보이다': {'thrill': 0.32,
#   'love': 0.07,
#   'fun': 0.07,
#   'enthusiasm': 0.04,
#   'happyness': 0.06,
#   'sadness': 0.17,
#   'anger': 0.12,
#   'lonely': 0.07,
#   'longing': 0.02,
#   'fear': 0.06},
#  '처음': {'thrill': 0.69,
#   'love': 0.11,
#   'fun': 0.02,
#   'enthusiasm': 0.04,
#   'sadness': 0.07,
#   'anger': 0.04,
#   'lonely': 0.02,
#   'longing': 0.02},
#  '순간': {'thrill': 0.51,
#   'love': 0.1,
#   'fun': 0.06,
#   'enthusiasm': 0.07,
#   'happyness': 0.1,
#   'sadness': 0.1,
#   'lonely': 0.03,
#   'longing': 0.04},
#  '매일': {'thrill': 0.41,
#   'love': 0.06,
#   'fun': 0.03,
#   'enthusiasm': 0.08,
#   'happyness': 0.08,
#   'sadness': 0.17,
#   'anger': 0.11,
#   'lonely': 0.03,
#   'longing': 0.02},
#  '향기': {'thrill': 0.78,
#   'love': 0.04,
#   'happyness': 0.02,
#   'sadness': 0.04,
#   'longing': 0.11},
#  '잠': {'thrill': 0.71,
#   'fun': 0.04,
#   'enthusiasm': 0.06,
#   'happyness': 0.06,
#   'sadness': 0.02,
#   'anger': 0.04,
#   'lonely': 0.04,
#   'longing': 0.02},
#  '느끼다': {'thrill': 0.56,
#   'love': 0.08,
#   'fun': 0.08,
#   'enthusiasm': 0.03,
#   'happyness': 0.02,
#   'sadness': 0.1,
#   'anger': 0.03,
#   'lonely': 0.1,
#   'fear': 0.02},
#  '모르다': {'thrill': 0.19,
#   'love': 0.08,
#   'fun': 0.09,
#   'enthusiasm': 0.04,
#   'happyness': 0.04,
#   'sadness': 0.46,
#   'anger': 0.08,
#   'lonely': 0.01,
#   'longing': 0.01,
#   'fear': 0.01},
#  '잡다': {'thrill': 0.51,
#   'love': 0.12,
#   'fun': 0.07,
#   'enthusiasm': 0.04,
#   'sadness': 0.09,
#   'anger': 0.07,
#   'lonely': 0.01,
#   'longing': 0.06,
#   'fear': 0.01},
#  '그렇다': {'thrill': 0.3,
#   'love': 0.1,
#   'fun': 0.04,
#   'enthusiasm': 0.02,
#   'happyness': 0.04,
#   'sadness': 0.25,
#   'anger': 0.16,
#   'lonely': 0.05,
#   'longing': 0.06},
#  '길': {'thrill': 0.35,
#   'love': 0.02,
#   'fun': 0.03,
#   'enthusiasm': 0.14,
#   'happyness': 0.03,
#   'sadness': 0.14,
#   'anger': 0.08,
#   'lonely': 0.11,
#   'longing': 0.07,
#   'fear': 0.03},
#  '미소': {'thrill': 0.72,
#   'love': 0.02,
#   'happyness': 0.07,
#   'sadness': 0.09,
#   'lonely': 0.07,
#   'longing': 0.02},
#  'you': {'thrill': 0.27,
#   'love': 0.35,
#   'fun': 0.09,
#   'enthusiasm': 0.05,
#   'happyness': 0.07,
#   'sadness': 0.03,
#   'anger': 0.08,
#   'longing': 0.06,
#   'fear': 0.01},
#  '조금': {'thrill': 0.45,
#   'love': 0.04,
#   'fun': 0.09,
#   'enthusiasm': 0.04,
#   'happyness': 0.01,
#   'sadness': 0.13,
#   'anger': 0.07,
#   'lonely': 0.1,
#   'longing': 0.04,
#   'fear': 0.01},
#  '사람': {'thrill': 0.2,
#   'love': 0.21,
#   'fun': 0.03,
#   'enthusiasm': 0.03,
#   'happyness': 0.1,
#   'sadness': 0.19,
#   'anger': 0.1,
#   'lonely': 0.07,
#   'longing': 0.06,
#   'fear': 0.02},
#  '번': {'thrill': 0.37,
#   'love': 0.05,
#   'fun': 0.07,
#   'enthusiasm': 0.11,
#   'happyness': 0.05,
#   'sadness': 0.11,
#   'anger': 0.16,
#   'lonely': 0.04,
#   'longing': 0.04},
#  '너무': {'thrill': 0.18,
#   'love': 0.14,
#   'fun': 0.04,
#   'enthusiasm': 0.05,
#   'happyness': 0.07,
#   'sadness': 0.28,
#   'anger': 0.1,
#   'lonely': 0.07,
#   'longing': 0.06,
#   'fear': 0.02},
#  '눈빛': {'thrill': 0.67,
#   'love': 0.04,
#   'happyness': 0.04,
#   'sadness': 0.13,
#   'anger': 0.02,
#   'lonely': 0.09},
#  '너에게': {'thrill': 0.54,
#   'love': 0.25,
#   'happyness': 0.05,
#   'sadness': 0.11,
#   'lonely': 0.04,
#   'longing': 0.02},
#  '부르다': {'thrill': 0.36,
#   'love': 0.09,
#   'fun': 0.29,
#   'enthusiasm': 0.04,
#   'happyness': 0.05,
#   'sadness': 0.06,
#   'anger': 0.04,
#   'lonely': 0.04,
#   'longing': 0.04},
#  '그때': {'thrill': 0.35,
#   'love': 0.08,
#   'fun': 0.04,
#   'enthusiasm': 0.03,
#   'happyness': 0.05,
#   'sadness': 0.18,
#   'anger': 0.03,
#   'lonely': 0.04,
#   'longing': 0.2,
#   'fear': 0.01},
#  '꿈': {'thrill': 0.25,
#   'love': 0.05,
#   'fun': 0.04,
#   'enthusiasm': 0.48,
#   'happyness': 0.02,
#   'sadness': 0.03,
#   'anger': 0.06,
#   'lonely': 0.05,
#   'longing': 0.02,
#   'fear': 0.01},
#  'me': {'thrill': 0.38,
#   'love': 0.18,
#   'fun': 0.21,
#   'enthusiasm': 0.03,
#   'happyness': 0.03,
#   'sadness': 0.09,
#   'anger': 0.07,
#   'lonely': 0.01},
#  '어떻다': {'thrill': 0.46,
#   'love': 0.04,
#   'sadness': 0.14,
#   'anger': 0.28,
#   'lonely': 0.02,
#   'longing': 0.04,
#   'fear': 0.04},
#  '서로': {'thrill': 0.4,
#   'love': 0.18,
#   'happyness': 0.05,
#   'sadness': 0.23,
#   'anger': 0.03,
#   'lonely': 0.03,
#   'longing': 0.06,
#   'fear': 0.02},
#  '위하다': {'thrill': 0.32,
#   'love': 0.24,
#   'fun': 0.11,
#   'enthusiasm': 0.03,
#   'happyness': 0.05,
#   'sadness': 0.12,
#   'anger': 0.05,
#   'lonely': 0.01,
#   'longing': 0.05,
#   'fear': 0.01},
#  '아침': {'thrill': 0.59,
#   'love': 0.1,
#   'fun': 0.12,
#   'enthusiasm': 0.02,
#   'happyness': 0.1,
#   'longing': 0.05,
#   'fear': 0.02},
#  '듯': {'thrill': 0.44,
#   'love': 0.09,
#   'fun': 0.11,
#   'enthusiasm': 0.04,
#   'happyness': 0.02,
#   'sadness': 0.13,
#   'anger': 0.07,
#   'lonely': 0.04,
#   'longing': 0.05,
#   'fear': 0.02},
#  '자꾸': {'thrill': 0.36,
#   'love': 0.05,
#   'fun': 0.05,
#   'happyness': 0.02,
#   'sadness': 0.26,
#   'anger': 0.14,
#   'lonely': 0.05,
#   'longing': 0.06,
#   'fear': 0.03},
#  '기억': {'thrill': 0.18,
#   'love': 0.08,
#   'fun': 0.02,
#   'enthusiasm': 0.02,
#   'happyness': 0.02,
#   'sadness': 0.1,
#   'anger': 0.02,
#   'longing': 0.55,
#   'fear': 0.01},
#  '믿다': {'thrill': 0.37,
#   'love': 0.17,
#   'enthusiasm': 0.03,
#   'happyness': 0.08,
#   'sadness': 0.13,
#   'anger': 0.16,
#   'lonely': 0.03,
#   'longing': 0.03},
#  '하루': {'thrill': 0.31,
#   'love': 0.14,
#   'fun': 0.04,
#   'enthusiasm': 0.07,
#   'happyness': 0.07,
#   'sadness': 0.14,
#   'anger': 0.04,
#   'lonely': 0.16,
#   'longing': 0.04},
#  '세상': {'thrill': 0.2,
#   'love': 0.16,
#   'fun': 0.1,
#   'enthusiasm': 0.08,
#   'happyness': 0.13,
#   'sadness': 0.13,
#   'anger': 0.12,
#   'lonely': 0.03,
#   'longing': 0.01,
#   'fear': 0.04},
#  '앞': {'thrill': 0.32,
#   'love': 0.09,
#   'fun': 0.07,
#   'enthusiasm': 0.06,
#   'happyness': 0.03,
#   'sadness': 0.18,
#   'anger': 0.1,
#   'lonely': 0.06,
#   'longing': 0.07,
#   'fear': 0.01},
#  'oh': {'thrill': 0.21,
#   'love': 0.19,
#   'fun': 0.3,
#   'enthusiasm': 0.06,
#   'happyness': 0.06,
#   'sadness': 0.05,
#   'anger': 0.08,
#   'lonely': 0.02,
#   'longing': 0.01,
#   'fear': 0.03},
#  '곁': {'thrill': 0.24,
#   'love': 0.44,
#   'happyness': 0.03,
#   'sadness': 0.13,
#   'anger': 0.02,
#   'lonely': 0.07,
#   'longing': 0.06},
#  '게': {'thrill': 0.19,
#   'love': 0.15,
#   'fun': 0.03,
#   'enthusiasm': 0.14,
#   'happyness': 0.04,
#   'sadness': 0.19,
#   'anger': 0.13,
#   'lonely': 0.07,
#   'longing': 0.04,
#   'fear': 0.03},
#  '가슴': {'thrill': 0.25,
#   'love': 0.26,
#   'fun': 0.04,
#   'enthusiasm': 0.01,
#   'happyness': 0.04,
#   'sadness': 0.27,
#   'anger': 0.04,
#   'lonely': 0.04,
#   'longing': 0.05,
#   'fear': 0.02},
#  '잠들다': {'thrill': 0.72,
#   'fun': 0.1,
#   'happyness': 0.03,
#   'sadness': 0.07,
#   'lonely': 0.03,
#   'longing': 0.03},
#  '왜': {'thrill': 0.18,
#   'love': 0.06,
#   'fun': 0.04,
#   'enthusiasm': 0.03,
#   'happyness': 0.05,
#   'sadness': 0.27,
#   'anger': 0.22,
#   'lonely': 0.13,
#   'longing': 0.02},
#  '하얗다': {'thrill': 0.91, 'enthusiasm': 0.05, 'happyness': 0.05},
#  '꼭': {'thrill': 0.43,
#   'love': 0.38,
#   'enthusiasm': 0.04,
#   'sadness': 0.09,
#   'lonely': 0.02,
#   'longing': 0.04},
#  '다가오다': {'thrill': 0.56,
#   'love': 0.28,
#   'fun': 0.08,
#   'enthusiasm': 0.06,
#   'longing': 0.03},
#  '감다': {'thrill': 0.63,
#   'love': 0.13,
#   'fun': 0.07,
#   'lonely': 0.1,
#   'longing': 0.07},
#  '하늘': {'thrill': 0.31,
#   'love': 0.07,
#   'fun': 0.21,
#   'enthusiasm': 0.08,
#   'happyness': 0.18,
#   'sadness': 0.13,
#   'fear': 0.02},
#  '건': {'thrill': 0.18,
#   'love': 0.12,
#   'fun': 0.03,
#   'enthusiasm': 0.09,
#   'happyness': 0.05,
#   'sadness': 0.21,
#   'anger': 0.23,
#   'lonely': 0.06,
#   'longing': 0.02,
#   'fear': 0.02},
#  '닿다': {'thrill': 0.63,
#   'love': 0.1,
#   'enthusiasm': 0.07,
#   'happyness': 0.03,
#   'sadness': 0.13,
#   'longing': 0.03},
#  '기분': {'thrill': 0.42,
#   'love': 0.02,
#   'fun': 0.16,
#   'happyness': 0.27,
#   'anger': 0.13},
#  'i': {'thrill': 0.14,
#   'love': 0.19,
#   'fun': 0.17,
#   'enthusiasm': 0.16,
#   'happyness': 0.06,
#   'sadness': 0.08,
#   'anger': 0.13,
#   'lonely': 0.01,
#   'longing': 0.04,
#   'fear': 0.01},
#  '늘': {'thrill': 0.33,
#   'love': 0.16,
#   'fun': 0.05,
#   'enthusiasm': 0.05,
#   'happyness': 0.04,
#   'sadness': 0.21,
#   'anger': 0.04,
#   'lonely': 0.07,
#   'longing': 0.04,
#   'fear': 0.02},
#  '느낌': {'thrill': 0.79, 'sadness': 0.04, 'lonely': 0.17},
#  'baby': {'thrill': 0.23,
#   'love': 0.2,
#   'fun': 0.23,
#   'enthusiasm': 0.06,
#   'happyness': 0.05,
#   'sadness': 0.09,
#   'anger': 0.11,
#   'lonely': 0.01,
#   'longing': 0.03},
#  '만들다': {'thrill': 0.38,
#   'love': 0.15,
#   'enthusiasm': 0.11,
#   'happyness': 0.06,
#   'sadness': 0.17,
#   'anger': 0.06,
#   'lonely': 0.02,
#   'fear': 0.04},
#  '정말': {'thrill': 0.23,
#   'love': 0.22,
#   'fun': 0.03,
#   'enthusiasm': 0.04,
#   'happyness': 0.04,
#   'sadness': 0.25,
#   'anger': 0.12,
#   'lonely': 0.01,
#   'longing': 0.04,
#   'fear': 0.03},
#  '작다': {'thrill': 0.53,
#   'love': 0.09,
#   'fun': 0.06,
#   'enthusiasm': 0.06,
#   'happyness': 0.06,
#   'sadness': 0.09,
#   'anger': 0.06,
#   'lonely': 0.06},
#  '언제나': {'thrill': 0.39,
#   'love': 0.24,
#   'fun': 0.09,
#   'enthusiasm': 0.02,
#   'happyness': 0.07,
#   'sadness': 0.07,
#   'anger': 0.04,
#   'lonely': 0.07,
#   'fear': 0.02},
#  '나오다': {'thrill': 0.36,
#   'love': 0.1,
#   'fun': 0.2,
#   'enthusiasm': 0.02,
#   'happyness': 0.06,
#   'sadness': 0.14,
#   'anger': 0.08,
#   'lonely': 0.02,
#   'longing': 0.02},
#  '이름': {'thrill': 0.42,
#   'love': 0.12,
#   'enthusiasm': 0.12,
#   'happyness': 0.05,
#   'sadness': 0.14,
#   'anger': 0.05,
#   'lonely': 0.02,
#   'longing': 0.09},
#  '곳': {'thrill': 0.3,
#   'love': 0.09,
#   'fun': 0.12,
#   'enthusiasm': 0.11,
#   'happyness': 0.02,
#   'sadness': 0.16,
#   'anger': 0.05,
#   'lonely': 0.05,
#   'longing': 0.09,
#   'fear': 0.02},
#  '위': {'thrill': 0.22,
#   'love': 0.05,
#   'fun': 0.4,
#   'enthusiasm': 0.17,
#   'happyness': 0.06,
#   'sadness': 0.06,
#   'lonely': 0.03,
#   'longing': 0.01},
#  '목소리': {'thrill': 0.49,
#   'love': 0.14,
#   'happyness': 0.03,
#   'sadness': 0.2,
#   'lonely': 0.09,
#   'fear': 0.06},
#  '햇살': {'thrill': 0.61, 'love': 0.07, 'happyness': 0.25, 'sadness': 0.07},
#  '모두': {'thrill': 0.15,
#   'love': 0.11,
#   'fun': 0.19,
#   'enthusiasm': 0.14,
#   'happyness': 0.07,
#   'sadness': 0.15,
#   'anger': 0.13,
#   'lonely': 0.02,
#   'longing': 0.06},
#  '기대': {'thrill': 0.77,
#   'love': 0.05,
#   'enthusiasm': 0.05,
#   'anger': 0.05,
#   'lonely': 0.09},
#  '바람': {'thrill': 0.36,
#   'love': 0.06,
#   'fun': 0.15,
#   'enthusiasm': 0.04,
#   'happyness': 0.04,
#   'sadness': 0.06,
#   'anger': 0.04,
#   'lonely': 0.13,
#   'longing': 0.09,
#   'fear': 0.02},
#  '멈추다': {'thrill': 0.31,
#   'love': 0.09,
#   'fun': 0.04,
#   'enthusiasm': 0.13,
#   'sadness': 0.19,
#   'anger': 0.04,
#   'lonely': 0.06,
#   'longing': 0.11,
#   'fear': 0.04},
#  '가끔': {'thrill': 0.52,
#   'happyness': 0.06,
#   'sadness': 0.09,
#   'anger': 0.15,
#   'lonely': 0.06,
#   'longing': 0.12},
#  '뜨다': {'thrill': 0.4,
#   'love': 0.05,
#   'fun': 0.05,
#   'enthusiasm': 0.1,
#   'happyness': 0.1,
#   'sadness': 0.07,
#   'anger': 0.1,
#   'lonely': 0.05,
#   'longing': 0.07,
#   'fear': 0.02},
#  '설레다': {'thrill': 1.0},
#  '입술': {'thrill': 0.46, 'love': 0.46, 'sadness': 0.05, 'anger': 0.03},
#  '얼굴': {'thrill': 0.38,
#   'love': 0.07,
#   'happyness': 0.14,
#   'sadness': 0.14,
#   'anger': 0.17,
#   'longing': 0.1},
#  '스치다': {'thrill': 0.57,
#   'love': 0.04,
#   'sadness': 0.07,
#   'lonely': 0.04,
#   'longing': 0.25,
#   'fear': 0.04},
#  '많다': {'thrill': 0.18,
#   'love': 0.06,
#   'fun': 0.09,
#   'enthusiasm': 0.18,
#   'happyness': 0.05,
#   'sadness': 0.18,
#   'anger': 0.13,
#   'lonely': 0.05,
#   'longing': 0.07,
#   'fear': 0.01},
#  '같이': {'thrill': 0.31,
#   'love': 0.08,
#   'fun': 0.31,
#   'enthusiasm': 0.02,
#   'happyness': 0.1,
#   'sadness': 0.06,
#   'anger': 0.06,
#   'lonely': 0.04,
#   'longing': 0.04},
#  '내리다': {'thrill': 0.4,
#   'love': 0.05,
#   'fun': 0.12,
#   'enthusiasm': 0.03,
#   'happyness': 0.15,
#   'sadness': 0.12,
#   'longing': 0.1,
#   'fear': 0.03},
#  '살다': {'thrill': 0.17,
#   'love': 0.12,
#   'fun': 0.07,
#   'enthusiasm': 0.13,
#   'happyness': 0.08,
#   'sadness': 0.15,
#   'anger': 0.13,
#   'lonely': 0.07,
#   'longing': 0.08,
#   'fear': 0.01},
#  '끝': {'thrill': 0.25,
#   'love': 0.05,
#   'fun': 0.14,
#   'enthusiasm': 0.11,
#   'happyness': 0.02,
#   'sadness': 0.18,
#   'anger': 0.09,
#   'lonely': 0.06,
#   'longing': 0.08,
#   'fear': 0.03},
#  '그냥': {'thrill': 0.21,
#   'love': 0.13,
#   'fun': 0.1,
#   'enthusiasm': 0.06,
#   'happyness': 0.09,
#   'sadness': 0.16,
#   'anger': 0.13,
#   'lonely': 0.05,
#   'longing': 0.05,
#   'fear': 0.01},
#  '닮다': {'thrill': 0.75, 'love': 0.05, 'happyness': 0.1, 'sadness': 0.1},
#  '못': {'thrill': 0.17,
#   'love': 0.07,
#   'fun': 0.07,
#   'enthusiasm': 0.08,
#   'happyness': 0.02,
#   'sadness': 0.22,
#   'anger': 0.29,
#   'lonely': 0.04,
#   'longing': 0.01,
#   'fear': 0.03},
#  '향하다': {'thrill': 0.42,
#   'love': 0.08,
#   'fun': 0.17,
#   'enthusiasm': 0.11,
#   'happyness': 0.11,
#   'sadness': 0.08,
#   'longing': 0.03},
#  '그러다': {'thrill': 0.31,
#   'love': 0.04,
#   'fun': 0.04,
#   'enthusiasm': 0.08,
#   'happyness': 0.04,
#   'sadness': 0.21,
#   'anger': 0.21,
#   'lonely': 0.04,
#   'longing': 0.02},
#  '빛나다': {'thrill': 0.58, 'love': 0.19, 'enthusiasm': 0.08, 'happyness': 0.15},
#  '내일': {'thrill': 0.38,
#   'fun': 0.08,
#   'enthusiasm': 0.28,
#   'happyness': 0.05,
#   'sadness': 0.08,
#   'anger': 0.08,
#   'lonely': 0.03,
#   'longing': 0.03},
#  '눈부시다': {'thrill': 0.71, 'love': 0.1, 'happyness': 0.19},
#  '바보': {'thrill': 0.31,
#   'love': 0.1,
#   'sadness': 0.44,
#   'anger': 0.12,
#   'longing': 0.02},
#  '뿐': {'thrill': 0.24,
#   'love': 0.21,
#   'fun': 0.06,
#   'enthusiasm': 0.08,
#   'happyness': 0.06,
#   'sadness': 0.13,
#   'anger': 0.08,
#   'lonely': 0.06,
#   'longing': 0.06,
#   'fear': 0.02},
#  '아름답다': {'thrill': 0.21,
#   'love': 0.62,
#   'happyness': 0.11,
#   'sadness': 0.03,
#   'lonely': 0.01,
#   'longing': 0.03},
#  '너와 나': {'thrill': 0.36,
#   'love': 0.18,
#   'fun': 0.13,
#   'happyness': 0.05,
#   'sadness': 0.13,
#   'anger': 0.08,
#   'lonely': 0.08},
#  '맞추다': {'thrill': 0.32,
#   'love': 0.39,
#   'fun': 0.2,
#   'happyness': 0.02,
#   'anger': 0.07},
#  '떨리다': {'thrill': 0.74, 'love': 0.21, 'fun': 0.05},
#  '별': {'thrill': 0.45, 'love': 0.13, 'fun': 0.29, 'happyness': 0.13},
#  '좀': {'thrill': 0.22,
#   'love': 0.05,
#   'fun': 0.11,
#   'enthusiasm': 0.05,
#   'happyness': 0.05,
#   'sadness': 0.13,
#   'anger': 0.35,
#   'lonely': 0.03,
#   'fear': 0.02},
#  '머리': {'thrill': 0.47,
#   'love': 0.07,
#   'fun': 0.1,
#   'enthusiasm': 0.03,
#   'sadness': 0.13,
#   'anger': 0.13,
#   'longing': 0.07},
#  '항상': {'thrill': 0.36,
#   'love': 0.31,
#   'fun': 0.05,
#   'enthusiasm': 0.03,
#   'happyness': 0.08,
#   'sadness': 0.08,
#   'anger': 0.05,
#   'lonely': 0.03,
#   'fear': 0.03},
#  '그리다': {'thrill': 0.54,
#   'love': 0.04,
#   'enthusiasm': 0.12,
#   'happyness': 0.04,
#   'lonely': 0.04,
#   'longing': 0.23},
#  '잘': {'thrill': 0.15,
#   'love': 0.09,
#   'fun': 0.11,
#   'enthusiasm': 0.1,
#   'happyness': 0.1,
#   'sadness': 0.21,
#   'anger': 0.13,
#   'lonely': 0.02,
#   'longing': 0.08},
#  '거리': {'thrill': 0.33,
#   'love': 0.05,
#   'fun': 0.12,
#   'enthusiasm': 0.03,
#   'happyness': 0.03,
#   'sadness': 0.12,
#   'anger': 0.05,
#   'lonely': 0.12,
#   'longing': 0.07,
#   'fear': 0.07},
#  '길다': {'thrill': 0.39,
#   'love': 0.12,
#   'fun': 0.12,
#   'enthusiasm': 0.03,
#   'happyness': 0.03,
#   'sadness': 0.24,
#   'lonely': 0.06},
#  '마주': {'thrill': 0.65,
#   'love': 0.1,
#   'fun': 0.05,
#   'happyness': 0.1,
#   'sadness': 0.1},
#  '찾다': {'thrill': 0.25,
#   'love': 0.06,
#   'fun': 0.12,
#   'enthusiasm': 0.12,
#   'happyness': 0.04,
#   'sadness': 0.12,
#   'anger': 0.12,
#   'lonely': 0.06,
#   'longing': 0.12,
#   'fear': 0.02},
#  'yeah': {'thrill': 0.22,
#   'love': 0.09,
#   'fun': 0.41,
#   'enthusiasm': 0.03,
#   'happyness': 0.05,
#   'sadness': 0.07,
#   'anger': 0.09,
#   'longing': 0.02,
#   'fear': 0.02},
#  '가득': {'thrill': 0.39,
#   'love': 0.18,
#   'fun': 0.06,
#   'happyness': 0.09,
#   'sadness': 0.09,
#   'anger': 0.06,
#   'lonely': 0.09,
#   'longing': 0.03},
#  '내': {'thrill': 0.28,
#   'love': 0.28,
#   'fun': 0.09,
#   'enthusiasm': 0.09,
#   'sadness': 0.13,
#   'anger': 0.04,
#   'lonely': 0.04,
#   'longing': 0.06},
#  '상상': {'thrill': 0.68, 'fun': 0.16, 'enthusiasm': 0.16},
#  '새롭다': {'thrill': 0.52, 'fun': 0.35, 'enthusiasm': 0.13},
#  '일': {'thrill': 0.14,
#   'love': 0.07,
#   'fun': 0.1,
#   'enthusiasm': 0.13,
#   'happyness': 0.06,
#   'sadness': 0.19,
#   'anger': 0.22,
#   'lonely': 0.07,
#   'longing': 0.02},
#  '빛': {'thrill': 0.33,
#   'love': 0.11,
#   'fun': 0.14,
#   'enthusiasm': 0.03,
#   'happyness': 0.08,
#   'sadness': 0.14,
#   'lonely': 0.08,
#   'longing': 0.06,
#   'fear': 0.03},
#  '전화': {'thrill': 0.55,
#   'fun': 0.09,
#   'sadness': 0.18,
#   'anger': 0.09,
#   'longing': 0.09},
#  '깊다': {'thrill': 0.44,
#   'love': 0.11,
#   'fun': 0.15,
#   'happyness': 0.04,
#   'sadness': 0.15,
#   'anger': 0.04,
#   'lonely': 0.04,
#   'fear': 0.04},
#  '그저': {'thrill': 0.4,
#   'love': 0.07,
#   'fun': 0.1,
#   'enthusiasm': 0.13,
#   'sadness': 0.1,
#   'anger': 0.13,
#   'lonely': 0.07},
#  '깨다': {'thrill': 0.55, 'love': 0.15, 'enthusiasm': 0.25, 'anger': 0.05},
#  '들리다': {'thrill': 0.31,
#   'love': 0.14,
#   'fun': 0.14,
#   'enthusiasm': 0.08,
#   'happyness': 0.08,
#   'anger': 0.11,
#   'lonely': 0.08,
#   'longing': 0.03,
#   'fear': 0.03},
#  '숨기다': {'thrill': 0.39,
#   'love': 0.21,
#   'happyness': 0.04,
#   'sadness': 0.11,
#   'anger': 0.14,
#   'lonely': 0.04,
#   'longing': 0.04,
#   'fear': 0.04},
#  '얘기': {'thrill': 0.28,
#   'love': 0.05,
#   'fun': 0.05,
#   'happyness': 0.15,
#   'sadness': 0.25,
#   'anger': 0.17,
#   'longing': 0.03,
#   'fear': 0.03},
#  '비': {'thrill': 0.35,
#   'love': 0.03,
#   'fun': 0.03,
#   'happyness': 0.1,
#   'sadness': 0.32,
#   'lonely': 0.03,
#   'longing': 0.13},
#  '비추다': {'thrill': 0.52,
#   'love': 0.05,
#   'fun': 0.29,
#   'happyness': 0.1,
#   'lonely': 0.05},
#  '영화': {'thrill': 0.55,
#   'fun': 0.1,
#   'happyness': 0.1,
#   'sadness': 0.15,
#   'anger': 0.05,
#   'lonely': 0.05},
#  '아냐': {'thrill': 0.34,
#   'fun': 0.09,
#   'enthusiasm': 0.09,
#   'happyness': 0.03,
#   'sadness': 0.19,
#   'anger': 0.19,
#   'lonely': 0.03,
#   'fear': 0.03},
#  '끌리다': {'thrill': 0.79, 'enthusiasm': 0.07, 'anger': 0.14},
#  '어깨': {'thrill': 0.79, 'enthusiasm': 0.07, 'lonely': 0.07, 'fear': 0.07},
#  '척': {'thrill': 0.26,
#   'enthusiasm': 0.05,
#   'sadness': 0.21,
#   'anger': 0.38,
#   'lonely': 0.07,
#   'fear': 0.02},
#  '다르다': {'thrill': 0.61,
#   'love': 0.06,
#   'fun': 0.11,
#   'sadness': 0.06,
#   'anger': 0.17},
#  '원하다': {'thrill': 0.24,
#   'love': 0.15,
#   'fun': 0.09,
#   'enthusiasm': 0.3,
#   'happyness': 0.13,
#   'anger': 0.04,
#   'lonely': 0.04},
#  '꺼내다': {'thrill': 0.58,
#   'enthusiasm': 0.05,
#   'happyness': 0.05,
#   'sadness': 0.11,
#   'longing': 0.16,
#   'fear': 0.05},
#  '웃다': {'thrill': 0.1,
#   'love': 0.05,
#   'fun': 0.04,
#   'happyness': 0.61,
#   'sadness': 0.17,
#   'lonely': 0.01,
#   'longing': 0.03},
#  '맞다': {'thrill': 0.34,
#   'love': 0.12,
#   'fun': 0.03,
#   'enthusiasm': 0.09,
#   'happyness': 0.25,
#   'sadness': 0.06,
#   'anger': 0.09},
#  '옆': {'thrill': 0.37,
#   'love': 0.17,
#   'fun': 0.2,
#   'happyness': 0.07,
#   'sadness': 0.03,
#   'lonely': 0.17},
#  '많이': {'thrill': 0.23,
#   'love': 0.21,
#   'fun': 0.02,
#   'enthusiasm': 0.02,
#   'happyness': 0.04,
#   'sadness': 0.36,
#   'lonely': 0.02,
#   'longing': 0.02,
#   'fear': 0.06},
#  '만': {'thrill': 0.34,
#   'love': 0.12,
#   'fun': 0.22,
#   'happyness': 0.06,
#   'sadness': 0.09,
#   'anger': 0.09,
#   'lonely': 0.06},
#  '몰래': {'thrill': 0.55,
#   'love': 0.1,
#   'happyness': 0.05,
#   'sadness': 0.25,
#   'longing': 0.05},
#  '사랑': {'thrill': 0.02,
#   'love': 0.72,
#   'enthusiasm': 0.0,
#   'happyness': 0.01,
#   'sadness': 0.17,
#   'anger': 0.03,
#   'lonely': 0.02,
#   'longing': 0.02,
#   'fear': 0.0},
#  '입다': {'thrill': 0.53, 'fun': 0.32, 'happyness': 0.05, 'anger': 0.11},
#  '그날': {'thrill': 0.38,
#   'love': 0.15,
#   'fun': 0.04,
#   'sadness': 0.19,
#   'longing': 0.23},
#  '입': {'thrill': 0.29,
#   'love': 0.46,
#   'happyness': 0.06,
#   'sadness': 0.06,
#   'anger': 0.14},
#  '분위기': {'thrill': 0.83, 'fun': 0.17},
#  '바로': {'thrill': 0.38,
#   'love': 0.12,
#   'fun': 0.23,
#   'happyness': 0.08,
#   'sadness': 0.08,
#   'anger': 0.08,
#   'longing': 0.04},
#  '여전히': {'thrill': 0.42,
#   'fun': 0.08,
#   'happyness': 0.08,
#   'sadness': 0.17,
#   'anger': 0.04,
#   'lonely': 0.08,
#   'longing': 0.08,
#   'fear': 0.04},
#  '아주': {'thrill': 0.43,
#   'love': 0.26,
#   'happyness': 0.17,
#   'anger': 0.04,
#   'lonely': 0.04,
#   'longing': 0.04},
#  '서다': {'thrill': 0.29,
#   'fun': 0.11,
#   'enthusiasm': 0.11,
#   'happyness': 0.06,
#   'sadness': 0.11,
#   'anger': 0.11,
#   'lonely': 0.17,
#   'longing': 0.03},
#  '시작': {'thrill': 0.23,
#   'love': 0.09,
#   'fun': 0.14,
#   'enthusiasm': 0.27,
#   'happyness': 0.02,
#   'sadness': 0.14,
#   'anger': 0.11},
#  '참': {'thrill': 0.21,
#   'love': 0.17,
#   'happyness': 0.13,
#   'sadness': 0.23,
#   'anger': 0.23,
#   'fear': 0.02},
#  '밝다': {'thrill': 0.53,
#   'enthusiasm': 0.11,
#   'happyness': 0.32,
#   'sadness': 0.05},
#  '어느새': {'thrill': 0.4,
#   'love': 0.12,
#   'enthusiasm': 0.04,
#   'happyness': 0.08,
#   'sadness': 0.28,
#   'lonely': 0.04,
#   'longing': 0.04},
#  '없이': {'thrill': 0.13,
#   'love': 0.19,
#   'fun': 0.04,
#   'enthusiasm': 0.09,
#   'happyness': 0.04,
#   'sadness': 0.14,
#   'anger': 0.1,
#   'lonely': 0.17,
#   'longing': 0.06,
#   'fear': 0.04},
#  '종일': {'thrill': 0.43,
#   'love': 0.09,
#   'fun': 0.09,
#   'enthusiasm': 0.09,
#   'happyness': 0.13,
#   'lonely': 0.17},
#  '사이': {'thrill': 0.34,
#   'love': 0.14,
#   'fun': 0.07,
#   'sadness': 0.21,
#   'anger': 0.1,
#   'lonely': 0.03,
#   'longing': 0.07,
#   'fear': 0.03},
#  '친구': {'thrill': 0.18,
#   'love': 0.04,
#   'fun': 0.25,
#   'enthusiasm': 0.09,
#   'happyness': 0.07,
#   'sadness': 0.09,
#   'anger': 0.21,
#   'lonely': 0.04,
#   'longing': 0.05},
#  '예쁘다': {'thrill': 0.27, 'love': 0.68, 'happyness': 0.05},
#  '계속': {'thrill': 0.28,
#   'love': 0.17,
#   'fun': 0.19,
#   'enthusiasm': 0.19,
#   'happyness': 0.03,
#   'anger': 0.08,
#   'lonely': 0.03,
#   'fear': 0.03},
#  '떠올리다': {'thrill': 0.75, 'love': 0.08, 'sadness': 0.17},
#  '따르다': {'thrill': 0.36,
#   'love': 0.08,
#   'fun': 0.32,
#   'enthusiasm': 0.04,
#   'happyness': 0.04,
#   'anger': 0.08,
#   'lonely': 0.04,
#   'longing': 0.04},
#  '떠오르다': {'thrill': 0.53,
#   'fun': 0.12,
#   'happyness': 0.06,
#   'sadness': 0.18,
#   'longing': 0.06,
#   'fear': 0.06},
#  '왠지': {'thrill': 0.5,
#   'sadness': 0.28,
#   'anger': 0.06,
#   'lonely': 0.11,
#   'longing': 0.06},
#  '어': {'thrill': 0.43,
#   'love': 0.19,
#   'enthusiasm': 0.05,
#   'sadness': 0.19,
#   'lonely': 0.14},
#  '오': {'thrill': 0.26,
#   'love': 0.12,
#   'fun': 0.29,
#   'enthusiasm': 0.06,
#   'happyness': 0.09,
#   'sadness': 0.06,
#   'anger': 0.06,
#   'lonely': 0.06},
#  '앉다': {'thrill': 0.45,
#   'love': 0.05,
#   'happyness': 0.15,
#   'sadness': 0.1,
#   'lonely': 0.1,
#   'longing': 0.1,
#   'fear': 0.05},
#  '새벽': {'thrill': 0.5, 'fun': 0.22, 'sadness': 0.22, 'fear': 0.06},
#  '미치다': {'thrill': 0.15,
#   'love': 0.28,
#   'fun': 0.21,
#   'enthusiasm': 0.03,
#   'happyness': 0.02,
#   'sadness': 0.07,
#   'anger': 0.16,
#   'longing': 0.08},
#  '가깝다': {'thrill': 0.69, 'love': 0.15, 'happyness': 0.08, 'lonely': 0.08},
#  '나누다': {'thrill': 0.41,
#   'love': 0.18,
#   'happyness': 0.23,
#   'sadness': 0.09,
#   'anger': 0.09},
#  '속삭이다': {'thrill': 0.6, 'love': 0.33, 'happyness': 0.07},
#  '달빛': {'thrill': 0.56, 'love': 0.25, 'fun': 0.12, 'happyness': 0.06},
#  'my': {'thrill': 0.16,
#   'love': 0.22,
#   'fun': 0.22,
#   'enthusiasm': 0.19,
#   'happyness': 0.1,
#   'sadness': 0.03,
#   'lonely': 0.07},
#  '듣다': {'thrill': 0.25,
#   'love': 0.06,
#   'fun': 0.19,
#   'enthusiasm': 0.06,
#   'happyness': 0.08,
#   'sadness': 0.08,
#   'anger': 0.25,
#   'longing': 0.03},
#  '혹시': {'thrill': 0.53, 'sadness': 0.35, 'longing': 0.06, 'fear': 0.06},
#  '두그': {'thrill': 1.0},
#  '봄': {'thrill': 1.0},
#  'girl': {'thrill': 0.26,
#   'love': 0.29,
#   'fun': 0.13,
#   'enthusiasm': 0.03,
#   'happyness': 0.1,
#   'sadness': 0.1,
#   'anger': 0.1},
#  '멀다': {'thrill': 0.12,
#   'love': 0.05,
#   'enthusiasm': 0.03,
#   'happyness': 0.08,
#   'sadness': 0.09,
#   'lonely': 0.48,
#   'longing': 0.09,
#   'fear': 0.06},
#  '가만히': {'thrill': 0.57,
#   'love': 0.14,
#   'happyness': 0.14,
#   'lonely': 0.07,
#   'longing': 0.07},
#  '참다': {'thrill': 0.21,
#   'love': 0.08,
#   'enthusiasm': 0.05,
#   'sadness': 0.32,
#   'anger': 0.26,
#   'lonely': 0.03,
#   'longing': 0.05},
#  '숨': {'thrill': 0.24,
#   'love': 0.15,
#   'fun': 0.12,
#   'happyness': 0.09,
#   'sadness': 0.15,
#   'anger': 0.21,
#   'lonely': 0.03,
#   'longing': 0.03},
#  '담다': {'thrill': 0.32,
#   'love': 0.12,
#   'fun': 0.12,
#   'enthusiasm': 0.08,
#   'happyness': 0.04,
#   'sadness': 0.16,
#   'lonely': 0.04,
#   'longing': 0.12},
#  '마치': {'thrill': 0.28,
#   'love': 0.07,
#   'fun': 0.1,
#   'enthusiasm': 0.07,
#   'happyness': 0.1,
#   'sadness': 0.07,
#   'anger': 0.17,
#   'lonely': 0.1,
#   'longing': 0.03},
#  '떡': {'thrill': 0.42,
#   'love': 0.16,
#   'enthusiasm': 0.05,
#   'sadness': 0.21,
#   'lonely': 0.16},
#  '기대다': {'thrill': 0.8, 'sadness': 0.1, 'lonely': 0.1},
#  '채': {'thrill': 0.18,
#   'love': 0.16,
#   'fun': 0.04,
#   'enthusiasm': 0.04,
#   'sadness': 0.33,
#   'anger': 0.04,
#   'lonely': 0.13,
#   'longing': 0.07},
#  '소리': {'thrill': 0.19,
#   'love': 0.07,
#   'fun': 0.38,
#   'enthusiasm': 0.02,
#   'happyness': 0.05,
#   'sadness': 0.07,
#   'anger': 0.1,
#   'lonely': 0.12},
#  '전하다': {'thrill': 0.62, 'love': 0.15, 'fun': 0.23},
#  '꽃': {'thrill': 0.35,
#   'love': 0.04,
#   'happyness': 0.35,
#   'sadness': 0.17,
#   'longing': 0.09},
#  '마주치다': {'thrill': 0.62,
#   'love': 0.08,
#   'happyness': 0.08,
#   'sadness': 0.08,
#   'longing': 0.15},
#  '쓰다': {'thrill': 0.22,
#   'fun': 0.16,
#   'enthusiasm': 0.16,
#   'happyness': 0.08,
#   'sadness': 0.14,
#   'anger': 0.22,
#   'longing': 0.03},
#  '한참': {'thrill': 0.53,
#   'love': 0.07,
#   'sadness': 0.2,
#   'lonely': 0.13,
#   'longing': 0.07},
#  '받다': {'thrill': 0.2,
#   'love': 0.17,
#   'enthusiasm': 0.07,
#   'sadness': 0.27,
#   'anger': 0.24,
#   'lonely': 0.05},
#  '몸': {'thrill': 0.21,
#   'fun': 0.46,
#   'enthusiasm': 0.05,
#   'happyness': 0.08,
#   'sadness': 0.13,
#   'anger': 0.05,
#   'lonely': 0.03},
#  '달': {'thrill': 0.38,
#   'love': 0.14,
#   'fun': 0.1,
#   'happyness': 0.14,
#   'sadness': 0.05,
#   'anger': 0.05,
#   'lonely': 0.05,
#   'longing': 0.05,
#   'fear': 0.05},
#  '잠시': {'thrill': 0.4,
#   'fun': 0.15,
#   'happyness': 0.05,
#   'sadness': 0.15,
#   'anger': 0.1,
#   'lonely': 0.1,
#   'longing': 0.05},
#  '비치다': {'thrill': 0.44, 'love': 0.06, 'sadness': 0.33, 'lonely': 0.17},
#  '우연히': {'thrill': 0.8, 'sadness': 0.1, 'longing': 0.1},
#  '거울': {'thrill': 0.44,
#   'love': 0.06,
#   'sadness': 0.17,
#   'anger': 0.06,
#   'lonely': 0.17,
#   'fear': 0.11},
#  '먼저': {'thrill': 0.26,
#   'love': 0.1,
#   'fun': 0.16,
#   'enthusiasm': 0.1,
#   'happyness': 0.03,
#   'sadness': 0.13,
#   'anger': 0.16,
#   'longing': 0.06},
#  '흐르다': {'thrill': 0.18,
#   'love': 0.05,
#   'fun': 0.07,
#   'sadness': 0.45,
#   'lonely': 0.02,
#   'longing': 0.23},
#  '날씨': {'thrill': 0.8, 'happyness': 0.2},
#  '남자': {'thrill': 0.31,
#   'love': 0.12,
#   'fun': 0.15,
#   'happyness': 0.04,
#   'sadness': 0.12,
#   'anger': 0.23,
#   'lonely': 0.04},
#  '귓가': {'thrill': 0.89, 'lonely': 0.11},
#  '얼마나': {'thrill': 0.32,
#   'love': 0.08,
#   'enthusiasm': 0.04,
#   'happyness': 0.04,
#   'sadness': 0.28,
#   'anger': 0.12,
#   'lonely': 0.04,
#   'longing': 0.04,
#   'fear': 0.04},
#  '바래다': {'thrill': 0.29,
#   'love': 0.07,
#   'fun': 0.11,
#   'enthusiasm': 0.07,
#   'happyness': 0.11,
#   'sadness': 0.11,
#   'anger': 0.11,
#   'lonely': 0.04,
#   'longing': 0.11},
#  '이상': {'thrill': 0.19,
#   'love': 0.05,
#   'fun': 0.05,
#   'enthusiasm': 0.02,
#   'happyness': 0.09,
#   'sadness': 0.16,
#   'anger': 0.4,
#   'lonely': 0.05},
#  '꾸다': {'thrill': 0.35, 'fun': 0.09, 'enthusiasm': 0.52, 'happyness': 0.04},
#  '살짝': {'thrill': 0.89, 'love': 0.11},
#  'pick': {'thrill': 0.62, 'fun': 0.15, 'sadness': 0.23},
#  '이루다': {'thrill': 0.5,
#   'love': 0.07,
#   'enthusiasm': 0.29,
#   'happyness': 0.07,
#   'sadness': 0.07},
#  'just': {'thrill': 0.41, 'love': 0.18, 'happyness': 0.18, 'lonely': 0.24},
#  '그대에게': {'thrill': 0.88, 'love': 0.12},
#  '좋아하다': {'thrill': 0.22,
#   'love': 0.69,
#   'happyness': 0.03,
#   'anger': 0.03,
#   'fear': 0.03},
#  '설레임': {'thrill': 1.0},
#  '약속': {'thrill': 0.35,
#   'love': 0.1,
#   'enthusiasm': 0.05,
#   'happyness': 0.05,
#   'sadness': 0.15,
#   'anger': 0.2,
#   'longing': 0.1},
#  'be': {'thrill': 0.41,
#   'love': 0.12,
#   'fun': 0.29,
#   'enthusiasm': 0.12,
#   'anger': 0.06},
#  '이서': {'thrill': 0.54, 'fun': 0.23, 'enthusiasm': 0.15, 'lonely': 0.08},
#  '보내다': {'thrill': 0.14,
#   'love': 0.1,
#   'fun': 0.06,
#   'enthusiasm': 0.08,
#   'happyness': 0.04,
#   'sadness': 0.2,
#   'lonely': 0.24,
#   'longing': 0.12},
#  '온통': {'thrill': 1.0},
#  '맴돌다': {'thrill': 0.47,
#   'love': 0.13,
#   'fun': 0.07,
#   'sadness': 0.13,
#   'lonely': 0.13,
#   'longing': 0.07},
#  '집': {'thrill': 0.23,
#   'fun': 0.23,
#   'enthusiasm': 0.03,
#   'happyness': 0.13,
#   'sadness': 0.1,
#   'anger': 0.07,
#   'lonely': 0.07,
#   'longing': 0.1,
#   'fear': 0.03},
#  '찾아오다': {'thrill': 0.64, 'love': 0.18, 'happyness': 0.09, 'anger': 0.09},
#  '줄다': {'thrill': 0.18,
#   'love': 0.46,
#   'enthusiasm': 0.03,
#   'happyness': 0.18,
#   'anger': 0.08,
#   'lonely': 0.05,
#   'longing': 0.03},
#  '생각나다': {'thrill': 0.44, 'happyness': 0.06, 'sadness': 0.25, 'longing': 0.25},
#  '준비': {'thrill': 0.47,
#   'love': 0.2,
#   'fun': 0.13,
#   'enthusiasm': 0.13,
#   'happyness': 0.07},
#  '꺼': {'thrill': 0.27,
#   'love': 0.15,
#   'fun': 0.12,
#   'enthusiasm': 0.12,
#   'happyness': 0.08,
#   'sadness': 0.12,
#   'longing': 0.15},
#  '쯤': {'thrill': 0.41,
#   'love': 0.06,
#   'fun': 0.06,
#   'happyness': 0.06,
#   'sadness': 0.35,
#   'lonely': 0.06},
#  '가장': {'thrill': 0.33,
#   'love': 0.24,
#   'fun': 0.1,
#   'sadness': 0.19,
#   'lonely': 0.05,
#   'longing': 0.05,
#   'fear': 0.05},
#  '귀': {'thrill': 0.47,
#   'fun': 0.13,
#   'happyness': 0.13,
#   'anger': 0.2,
#   'lonely': 0.07},
#  '파다': {'thrill': 0.64, 'enthusiasm': 0.09, 'happyness': 0.09, 'lonely': 0.18},
#  '걸음': {'thrill': 0.44,
#   'fun': 0.06,
#   'enthusiasm': 0.12,
#   'sadness': 0.12,
#   'lonely': 0.19,
#   'longing': 0.06},
#  '들어오다': {'thrill': 0.7, 'love': 0.1, 'anger': 0.1, 'lonely': 0.1},
#  '발': {'thrill': 0.47,
#   'love': 0.07,
#   'fun': 0.2,
#   'anger': 0.2,
#   'longing': 0.07},
#  '살며시': {'thrill': 0.75, 'love': 0.12, 'longing': 0.12},
#  '여자': {'thrill': 0.19,
#   'love': 0.25,
#   'fun': 0.19,
#   'enthusiasm': 0.03,
#   'happyness': 0.03,
#   'sadness': 0.03,
#   'anger': 0.19,
#   'lonely': 0.06,
#   'longing': 0.03},
#  '깨우다': {'thrill': 0.5,
#   'love': 0.08,
#   'fun': 0.25,
#   'happyness': 0.08,
#   'sadness': 0.08},
#  's': {'thrill': 0.17,
#   'love': 0.11,
#   'fun': 0.28,
#   'enthusiasm': 0.17,
#   'happyness': 0.08,
#   'sadness': 0.03,
#   'anger': 0.14,
#   'lonely': 0.03},
#  '빠지다': {'thrill': 0.2,
#   'love': 0.43,
#   'fun': 0.1,
#   'sadness': 0.07,
#   'anger': 0.13,
#   'longing': 0.03,
#   'fear': 0.03},
#  '어제': {'thrill': 0.29,
#   'love': 0.05,
#   'fun': 0.14,
#   'sadness': 0.14,
#   'anger': 0.1,
#   'lonely': 0.19,
#   'longing': 0.1},
#  '피다': {'thrill': 0.75, 'happyness': 0.12, 'fear': 0.12},
#  '언젠가': {'thrill': 0.23,
#   'love': 0.08,
#   'enthusiasm': 0.04,
#   'happyness': 0.08,
#   'sadness': 0.23,
#   'longing': 0.31,
#   'fear': 0.04},
#  '이리': {'thrill': 0.4, 'happyness': 0.07, 'sadness': 0.27, 'anger': 0.27},
#  '뒤': {'thrill': 0.19,
#   'love': 0.06,
#   'enthusiasm': 0.06,
#   'happyness': 0.03,
#   'sadness': 0.35,
#   'anger': 0.16,
#   'lonely': 0.06,
#   'longing': 0.06},
#  '바라다': {'thrill': 0.29,
#   'love': 0.24,
#   'fun': 0.1,
#   'happyness': 0.29,
#   'sadness': 0.1},
#  '밖': {'thrill': 0.4,
#   'love': 0.2,
#   'fun': 0.13,
#   'happyness': 0.07,
#   'anger': 0.13,
#   'lonely': 0.07},
#  '감정': {'thrill': 0.38, 'fun': 0.12, 'sadness': 0.38, 'anger': 0.12},
#  '시선': {'thrill': 0.5,
#   'enthusiasm': 0.08,
#   'happyness': 0.08,
#   'anger': 0.25,
#   'lonely': 0.08},
#  '제발': {'thrill': 0.15,
#   'love': 0.1,
#   'fun': 0.02,
#   'sadness': 0.12,
#   'anger': 0.39,
#   'lonely': 0.05,
#   'longing': 0.07,
#   'fear': 0.1},
#  '대만': {'thrill': 0.4, 'love': 0.4, 'anger': 0.07, 'longing': 0.13},
#  '밤하늘': {'thrill': 0.67, 'love': 0.22, 'happyness': 0.11},
#  '막': {'thrill': 0.35,
#   'fun': 0.18,
#   'enthusiasm': 0.06,
#   'sadness': 0.06,
#   'anger': 0.35},
#  'it': {'thrill': 0.11,
#   'love': 0.12,
#   'fun': 0.32,
#   'enthusiasm': 0.14,
#   'happyness': 0.09,
#   'anger': 0.16,
#   'lonely': 0.05},
#  '보고 싶다': {'thrill': 0.67, 'love': 0.33},
#  '손길': {'thrill': 0.86, 'happyness': 0.14},
#  '이미': {'thrill': 0.12,
#   'love': 0.13,
#   'fun': 0.1,
#   'enthusiasm': 0.08,
#   'happyness': 0.06,
#   'sadness': 0.15,
#   'anger': 0.15,
#   'lonely': 0.15,
#   'longing': 0.06},
#  '아무도': {'thrill': 0.2,
#   'love': 0.1,
#   'fun': 0.17,
#   'enthusiasm': 0.03,
#   'happyness': 0.03,
#   'sadness': 0.1,
#   'anger': 0.07,
#   'lonely': 0.27,
#   'longing': 0.03},
#  '전': {'thrill': 0.26,
#   'fun': 0.17,
#   'enthusiasm': 0.13,
#   'sadness': 0.09,
#   'anger': 0.17,
#   'lonely': 0.04,
#   'longing': 0.13},
#  '전화기': {'thrill': 0.75, 'anger': 0.25},
#  '이대로': {'thrill': 0.21,
#   'love': 0.14,
#   'happyness': 0.07,
#   'sadness': 0.17,
#   'anger': 0.24,
#   'lonely': 0.07,
#   'longing': 0.1},
#  '뻗다': {'thrill': 0.67, 'love': 0.11, 'enthusiasm': 0.22},
#  '설레이다': {'thrill': 1.0},
#  '불빛': {'thrill': 0.55,
#   'fun': 0.09,
#   'enthusiasm': 0.09,
#   'sadness': 0.18,
#   'lonely': 0.09},
#  '아래': {'thrill': 0.26,
#   'love': 0.13,
#   'fun': 0.17,
#   'happyness': 0.3,
#   'anger': 0.09,
#   'longing': 0.04},
#  'eh': {'thrill': 0.67, 'love': 0.11, 'anger': 0.22},
#  '묻다': {'thrill': 0.18,
#   'love': 0.18,
#   'fun': 0.06,
#   'enthusiasm': 0.09,
#   'happyness': 0.06,
#   'sadness': 0.12,
#   'anger': 0.21,
#   'longing': 0.09},
#  '채우다': {'thrill': 0.22,
#   'love': 0.15,
#   'fun': 0.15,
#   'enthusiasm': 0.11,
#   'happyness': 0.04,
#   'anger': 0.07,
#   'lonely': 0.26},
#  'boy': {'thrill': 0.26, 'love': 0.13, 'fun': 0.43, 'sadness': 0.17},
#  '이야기': {'thrill': 0.43,
#   'love': 0.14,
#   'enthusiasm': 0.14,
#   'happyness': 0.14,
#   'sadness': 0.14},
#  '혼자': {'thrill': 0.08,
#   'love': 0.03,
#   'happyness': 0.03,
#   'sadness': 0.11,
#   'anger': 0.07,
#   'lonely': 0.64,
#   'longing': 0.03,
#   'fear': 0.03},
#  '아니': {'thrill': 0.35,
#   'love': 0.18,
#   'happyness': 0.12,
#   'sadness': 0.12,
#   'anger': 0.18,
#   'longing': 0.06},
#  '게로': {'thrill': 0.38, 'love': 0.44, 'longing': 0.19},
#  '다가가다': {'thrill': 0.67, 'sadness': 0.22, 'longing': 0.11},
#  '딱': {'thrill': 0.35,
#   'love': 0.12,
#   'fun': 0.18,
#   'enthusiasm': 0.06,
#   'happyness': 0.18,
#   'sadness': 0.06,
#   'longing': 0.06},
#  '한번쯤': {'thrill': 0.75, 'enthusiasm': 0.12, 'anger': 0.12},
#  'up': {'thrill': 0.18,
#   'fun': 0.36,
#   'enthusiasm': 0.06,
#   'happyness': 0.03,
#   'anger': 0.36},
#  '조심': {'thrill': 1.0},
#  'with': {'thrill': 0.33,
#   'love': 0.13,
#   'fun': 0.33,
#   'enthusiasm': 0.07,
#   'happyness': 0.13},
#  '숨결': {'thrill': 0.83, 'love': 0.17},
#  '사라지다': {'thrill': 0.17,
#   'love': 0.03,
#   'enthusiasm': 0.03,
#   'sadness': 0.37,
#   'anger': 0.03,
#   'lonely': 0.17,
#   'longing': 0.13,
#   'fear': 0.07},
#  '귀엽다': {'thrill': 0.83, 'happyness': 0.17},
#  '표정': {'thrill': 0.28,
#   'fun': 0.06,
#   'sadness': 0.33,
#   'anger': 0.11,
#   'lonely': 0.11,
#   'fear': 0.11},
#  'a': {'thrill': 0.23,
#   'love': 0.14,
#   'fun': 0.23,
#   'enthusiasm': 0.18,
#   'sadness': 0.05,
#   'anger': 0.14,
#   'lonely': 0.05},
#  '변하다': {'thrill': 0.15,
#   'love': 0.18,
#   'fun': 0.06,
#   'enthusiasm': 0.12,
#   'happyness': 0.06,
#   'sadness': 0.18,
#   'anger': 0.12,
#   'lonely': 0.03,
#   'longing': 0.06,
#   'fear': 0.03},
#  '자리': {'thrill': 0.22,
#   'love': 0.09,
#   'fun': 0.26,
#   'sadness': 0.13,
#   'lonely': 0.09,
#   'longing': 0.22},
#  '손잡다': {'thrill': 0.56, 'love': 0.33, 'happyness': 0.11},
#  'night': {'thrill': 0.33,
#   'love': 0.07,
#   'fun': 0.33,
#   'happyness': 0.13,
#   'lonely': 0.07,
#   'longing': 0.07},
#  '해': {'thrill': 0.21,
#   'fun': 0.21,
#   'enthusiasm': 0.08,
#   'happyness': 0.08,
#   'anger': 0.17,
#   'lonely': 0.04,
#   'longing': 0.17,
#   'fear': 0.04},
#  '두근거리다': {'thrill': 0.83, 'love': 0.17},
#  '가지다': {'thrill': 0.14,
#   'love': 0.17,
#   'fun': 0.06,
#   'enthusiasm': 0.06,
#   'happyness': 0.11,
#   'sadness': 0.14,
#   'anger': 0.11,
#   'lonely': 0.11,
#   'fear': 0.09},
#  '옷': {'thrill': 0.83, 'happyness': 0.17},
#  '차': {'thrill': 0.22,
#   'fun': 0.17,
#   'enthusiasm': 0.17,
#   'happyness': 0.04,
#   'sadness': 0.13,
#   'anger': 0.22,
#   'longing': 0.04},
#  '전부': {'thrill': 0.13,
#   'love': 0.32,
#   'fun': 0.05,
#   'enthusiasm': 0.21,
#   'happyness': 0.03,
#   'sadness': 0.11,
#   'anger': 0.11,
#   'longing': 0.05},
#  'dooli': {'thrill': 1.0},
#  '그대와 함께': {'thrill': 0.83, 'longing': 0.17},
#  '바다': {'thrill': 0.36,
#   'love': 0.21,
#   'fun': 0.21,
#   'happyness': 0.14,
#   'longing': 0.07},
#  '완벽': {'thrill': 0.42,
#   'love': 0.17,
#   'fun': 0.17,
#   'enthusiasm': 0.17,
#   'happyness': 0.08},
#  '들키다': {'thrill': 1.0},
#  '테': {'thrill': 0.15,
#   'love': 0.12,
#   'fun': 0.18,
#   'enthusiasm': 0.15,
#   'happyness': 0.06,
#   'sadness': 0.24,
#   'anger': 0.03,
#   'lonely': 0.06},
#  '천사': {'thrill': 0.62, 'love': 0.12, 'happyness': 0.25},
#  '어서': {'thrill': 0.5, 'love': 0.3, 'fun': 0.2},
#  '춥다': {'thrill': 0.5, 'happyness': 0.1, 'anger': 0.1, 'lonely': 0.3},
#  '커지다': {'thrill': 0.36,
#   'love': 0.07,
#   'sadness': 0.21,
#   'anger': 0.21,
#   'lonely': 0.07,
#   'longing': 0.07},
#  '지나다': {'thrill': 0.1,
#   'love': 0.04,
#   'fun': 0.06,
#   'happyness': 0.1,
#   'sadness': 0.26,
#   'anger': 0.02,
#   'lonely': 0.08,
#   'longing': 0.34},
#  '짧다': {'thrill': 0.45,
#   'love': 0.18,
#   'fun': 0.18,
#   'sadness': 0.09,
#   'longing': 0.09},
#  '습관': {'thrill': 0.45, 'love': 0.09, 'sadness': 0.27, 'anger': 0.18},
#  '바라': {'thrill': 0.38,
#   'love': 0.15,
#   'fun': 0.31,
#   'happyness': 0.08,
#   'lonely': 0.08},
#  '잠깐': {'thrill': 0.71, 'love': 0.29},
#  '크다': {'thrill': 0.15,
#   'love': 0.06,
#   'fun': 0.29,
#   'enthusiasm': 0.18,
#   'happyness': 0.09,
#   'sadness': 0.12,
#   'anger': 0.06,
#   'longing': 0.03,
#   'fear': 0.03},
#  '힘': {'thrill': 0.18,
#   'love': 0.18,
#   'fun': 0.07,
#   'enthusiasm': 0.21,
#   'sadness': 0.18,
#   'anger': 0.11,
#   'lonely': 0.04,
#   'longing': 0.04},
#  '빛으로': {'thrill': 0.83, 'happyness': 0.17},
#  '데': {'thrill': 0.25,
#   'love': 0.1,
#   'happyness': 0.05,
#   'sadness': 0.3,
#   'anger': 0.2,
#   'lonely': 0.05,
#   'longing': 0.05},
#  '생기다': {'thrill': 0.28,
#   'fun': 0.06,
#   'enthusiasm': 0.06,
#   'sadness': 0.33,
#   'anger': 0.11,
#   'lonely': 0.06,
#   'fear': 0.11},
#  '달려가다': {'thrill': 0.28,
#   'love': 0.11,
#   'fun': 0.5,
#   'enthusiasm': 0.06,
#   'lonely': 0.06},
#  '남다': {'thrill': 0.13,
#   'love': 0.13,
#   'enthusiasm': 0.03,
#   'sadness': 0.18,
#   'lonely': 0.23,
#   'longing': 0.28,
#   'fear': 0.03},
#  '감싸다': {'thrill': 0.29,
#   'love': 0.35,
#   'fun': 0.12,
#   'sadness': 0.18,
#   'fear': 0.06},
#  '부시다': {'thrill': 0.56, 'happyness': 0.11, 'anger': 0.33},
#  '눕다': {'thrill': 0.5, 'happyness': 0.1, 'lonely': 0.3, 'longing': 0.1},
#  '중': {'thrill': 0.31,
#   'love': 0.25,
#   'fun': 0.25,
#   'happyness': 0.12,
#   'lonely': 0.06},
#  '대체': {'thrill': 0.45, 'anger': 0.45, 'lonely': 0.09},
#  '때문': {'thrill': 0.29,
#   'love': 0.18,
#   'happyness': 0.06,
#   'sadness': 0.24,
#   'anger': 0.12,
#   'lonely': 0.06,
#   'longing': 0.06},
#  '마음속': {'thrill': 0.5,
#   'love': 0.1,
#   'happyness': 0.1,
#   'sadness': 0.2,
#   'longing': 0.1},
#  '머물다': {'thrill': 0.45,
#   'love': 0.27,
#   'sadness': 0.09,
#   'lonely': 0.09,
#   'longing': 0.09},
#  '흘러가다': {'thrill': 0.36,
#   'fun': 0.14,
#   'sadness': 0.14,
#   'lonely': 0.07,
#   'longing': 0.14,
#   'fear': 0.14},
#  '지내다': {'thrill': 0.22,
#   'love': 0.13,
#   'fun': 0.09,
#   'enthusiasm': 0.04,
#   'happyness': 0.09,
#   'sadness': 0.17,
#   'lonely': 0.04,
#   'longing': 0.22},
#  '물들다': {'thrill': 0.45,
#   'love': 0.09,
#   'happyness': 0.09,
#   'sadness': 0.18,
#   'anger': 0.09,
#   'longing': 0.09},
#  '만남': {'thrill': 0.83, 'happyness': 0.17},
#  '물어보다': {'thrill': 1.0},
#  '지': {'thrill': 0.22,
#   'fun': 0.09,
#   'enthusiasm': 0.04,
#   'happyness': 0.09,
#   'sadness': 0.35,
#   'anger': 0.17,
#   'lonely': 0.04},
#  '들어가다': {'thrill': 0.83, 'love': 0.17},
#  'do': {'thrill': 0.44, 'love': 0.11, 'enthusiasm': 0.33, 'lonely': 0.11},
#  '문득': {'thrill': 0.8, 'sadness': 0.2},
#  '지나치다': {'thrill': 0.57, 'lonely': 0.14, 'longing': 0.29},
#  'get': {'thrill': 0.24,
#   'fun': 0.24,
#   'enthusiasm': 0.12,
#   'anger': 0.18,
#   'lonely': 0.24},
#  '뛰다': {'thrill': 0.21, 'love': 0.21, 'fun': 0.42, 'enthusiasm': 0.16},
#  '풍경': {'thrill': 0.67, 'love': 0.17, 'happyness': 0.17},
#  '불다': {'thrill': 0.33,
#   'fun': 0.17,
#   'enthusiasm': 0.08,
#   'anger': 0.17,
#   'lonely': 0.17,
#   'longing': 0.08},
#  '숨소리': {'thrill': 0.57, 'love': 0.14, 'fun': 0.14, 'sadness': 0.14},
#  '맑다': {'thrill': 0.5, 'happyness': 0.5},
#  '눈동자': {'thrill': 1.0},
#  '태양': {'thrill': 0.5, 'love': 0.12, 'enthusiasm': 0.12, 'happyness': 0.25},
#  '이끌다': {'thrill': 0.8, 'enthusiasm': 0.2},
#  '팔다': {'thrill': 0.44, 'fun': 0.22, 'enthusiasm': 0.11, 'anger': 0.22},
#  '꿈꾸다': {'thrill': 0.24,
#   'enthusiasm': 0.47,
#   'happyness': 0.12,
#   'sadness': 0.06,
#   'lonely': 0.12},
#  '접다': {'thrill': 1.0},
#  '터지다': {'thrill': 0.27,
#   'love': 0.2,
#   'fun': 0.2,
#   'enthusiasm': 0.13,
#   'happyness': 0.13,
#   'sadness': 0.07},
#  '싫다': {'thrill': 0.06,
#   'love': 0.03,
#   'sadness': 0.1,
#   'anger': 0.76,
#   'lonely': 0.06},
#  '풀다': {'thrill': 0.67, 'happyness': 0.33},
#  '감추다': {'thrill': 0.25,
#   'love': 0.19,
#   'fun': 0.06,
#   'sadness': 0.19,
#   'anger': 0.12,
#   'lonely': 0.06,
#   'longing': 0.06,
#   'fear': 0.06},
#  '오직': {'thrill': 0.25,
#   'love': 0.5,
#   'fun': 0.06,
#   'enthusiasm': 0.12,
#   'happyness': 0.06},
#  '운명': {'thrill': 0.22,
#   'love': 0.39,
#   'enthusiasm': 0.06,
#   'sadness': 0.17,
#   'anger': 0.11,
#   'lonely': 0.06},
#  '새다': {'thrill': 0.5, 'fun': 0.25, 'happyness': 0.25},
#  'don': {'thrill': 0.14,
#   'love': 0.04,
#   'fun': 0.11,
#   'enthusiasm': 0.11,
#   'happyness': 0.04,
# ...
#  '하나': {'thrill': 0.5, 'love': 0.25, 'fun': 0.25},
#  '추억': {'thrill': 0.03,
#   'love': 0.06,
#   'fun': 0.04,
#   'happyness': 0.01,
#   'sadness': 0.09,
#   'anger': 0.03,
#   'lonely': 0.03,
#   'longing': 0.7},
#  '별처럼': {'thrill': 0.5, 'fun': 0.5},
#  'in': {'thrill': 0.09,
#   'love': 0.23,
#   'fun': 0.32,
#   'enthusiasm': 0.18,
#   'anger': 0.09,
#   'lonely': 0.05,
#   'longing': 0.05},
#  '마지막': {'thrill': 0.06,
#   'love': 0.29,
#   'fun': 0.1,
#   'enthusiasm': 0.16,
#   'sadness': 0.19,
#   'anger': 0.03,
#   'lonely': 0.06,
#   'longing': 0.1},
#  '노력': {'thrill': 0.25, 'sadness': 0.5, 'lonely': 0.12, 'longing': 0.12},
#  '반쪽': {'thrill': 1.0},
#  '크리스마스': {'thrill': 0.67, 'love': 0.33},
#  'm': {'thrill': 0.07,
#   'fun': 0.2,
#   'enthusiasm': 0.13,
#   'happyness': 0.1,
#   'sadness': 0.23,
#   'anger': 0.17,
#   'lonely': 0.03,
#   'fear': 0.07},
#  'hey': {'thrill': 0.12, 'love': 0.31, 'fun': 0.56},
#  '대지': {'thrill': 1.0},
#  'right': {'thrill': 0.14,
#   'love': 0.21,
#   'fun': 0.43,
#   'enthusiasm': 0.07,
#   'fear': 0.14},
#  'now': {'thrill': 0.17,
#   'love': 0.17,
#   'fun': 0.42,
#   'enthusiasm': 0.08,
#   'anger': 0.17},
#  '아깝다': {'thrill': 0.4, 'love': 0.4, 'anger': 0.2},
#  '멎다': {'thrill': 0.67, 'lonely': 0.33},
#  '힐끗': {'thrill': 1.0},
#  'wait': {'thrill': 0.67, 'happyness': 0.33},
#  '해지': {'thrill': 1.0},
#  '나무': {'thrill': 0.67, 'happyness': 0.33},
#  '뭐': {'thrill': 0.25,
#   'love': 0.25,
#   'sadness': 0.12,
#   'anger': 0.25,
#   'lonely': 0.12},
#  '고백': {'thrill': 0.15, 'love': 0.77, 'sadness': 0.08},
#  '기운': {'thrill': 0.67, 'sadness': 0.33},
#  '법': {'thrill': 0.17,
#   'love': 0.08,
#   'enthusiasm': 0.17,
#   'happyness': 0.08,
#   'sadness': 0.25,
#   'anger': 0.17,
#   'longing': 0.08},
#  '믿기다': {'thrill': 1.0},
#  '부담': {'thrill': 0.5, 'love': 0.25, 'happyness': 0.25},
#  '라': {'thrill': 0.29, 'fun': 0.57, 'happyness': 0.14},
#  '떼': {'thrill': 1.0},
#  '따위': {'thrill': 0.13, 'happyness': 0.07, 'sadness': 0.13, 'anger': 0.67},
#  '온기': {'thrill': 0.4, 'love': 0.2, 'happyness': 0.4},
#  '모아': {'thrill': 0.4, 'happyness': 0.2, 'sadness': 0.4},
#  '갈다': {'thrill': 0.33, 'fun': 0.33, 'longing': 0.33},
#  '켠': {'thrill': 0.67, 'longing': 0.33},
#  '만약': {'thrill': 0.67, 'love': 0.33},
#  'tonight': {'thrill': 0.14, 'fun': 0.64, 'sadness': 0.14, 'longing': 0.07},
#  '바램': {'thrill': 0.33, 'love': 0.17, 'sadness': 0.33, 'longing': 0.17},
#  '의미': {'thrill': 0.1,
#   'love': 0.1,
#   'sadness': 0.1,
#   'anger': 0.33,
#   'lonely': 0.29,
#   'fear': 0.1},
#  '곤히': {'thrill': 1.0},
#  '너무나': {'thrill': 0.09,
#   'love': 0.27,
#   'enthusiasm': 0.05,
#   'happyness': 0.05,
#   'sadness': 0.18,
#   'anger': 0.23,
#   'lonely': 0.05,
#   'longing': 0.05,
#   'fear': 0.05},
#  '들뜨다': {'thrill': 1.0},
#  '담기다': {'thrill': 0.5, 'sadness': 0.25, 'longing': 0.25},
#  '삶': {'thrill': 0.08,
#   'love': 0.08,
#   'fun': 0.08,
#   'enthusiasm': 0.33,
#   'happyness': 0.12,
#   'sadness': 0.12,
#   'anger': 0.08,
#   'lonely': 0.08},
#  '띄우다': {'thrill': 1.0},
#  '홀리다': {'thrill': 1.0},
#  'yay': {'thrill': 1.0},
#  '여름': {'thrill': 0.4, 'fun': 0.4, 'happyness': 0.2},
#  '넘기다': {'thrill': 0.33, 'love': 0.17, 'anger': 0.5},
#  '눈꽃': {'thrill': 0.67, 'lonely': 0.33},
#  'body': {'thrill': 1.0},
#  '끌어당기다': {'thrill': 1.0},
#  '흰': {'thrill': 0.67, 'happyness': 0.33},
#  '이상해': {'thrill': 0.5, 'sadness': 0.25, 'anger': 0.25},
#  '훔쳐보다': {'thrill': 1.0},
#  '혹시나': {'thrill': 0.25,
#   'sadness': 0.38,
#   'lonely': 0.12,
#   'longing': 0.12,
#   'fear': 0.12},
#  '맛보다': {'thrill': 0.67, 'happyness': 0.33},
#  '눕히다': {'thrill': 1.0},
#  'want': {'thrill': 0.33, 'love': 0.5, 'fun': 0.17},
#  '어젯밤': {'thrill': 0.67, 'longing': 0.33},
#  '꽃향기': {'thrill': 1.0},
#  '저렇다': {'thrill': 1.0},
#  '남은': {'thrill': 0.2,
#   'love': 0.2,
#   'enthusiasm': 0.1,
#   'lonely': 0.3,
#   'longing': 0.2},
#  '아기': {'thrill': 1.0},
#  '서툴다': {'thrill': 0.67, 'sadness': 0.33},
#  '화장': {'thrill': 1.0},
#  '감성': {'thrill': 1.0},
#  '지금껏': {'thrill': 0.4, 'enthusiasm': 0.4, 'longing': 0.2},
#  '꺼지다': {'thrill': 0.22,
#   'fun': 0.22,
#   'anger': 0.33,
#   'lonely': 0.11,
#   'fear': 0.11},
#  '우연': {'thrill': 1.0},
#  '진짜': {'thrill': 0.12,
#   'love': 0.19,
#   'enthusiasm': 0.25,
#   'sadness': 0.19,
#   'anger': 0.25},
#  '떼다': {'thrill': 0.5, 'love': 0.25, 'enthusiasm': 0.25},
#  'paradise': {'thrill': 0.5, 'happyness': 0.5},
#  '술김': {'thrill': 1.0},
#  '읽다': {'thrill': 1.0},
#  '넘어지다': {'thrill': 1.0},
#  'bebe': {'thrill': 0.5, 'fun': 0.5},
#  '코끝': {'thrill': 1.0},
#  '헤매이다': {'thrill': 0.5, 'lonely': 0.25, 'fear': 0.25},
#  '여리다': {'thrill': 0.33, 'sadness': 0.5, 'lonely': 0.17},
#  'love': {'thrill': 0.03,
#   'love': 0.84,
#   'happyness': 0.03,
#   'sadness': 0.05,
#   'lonely': 0.05},
#  '그늘': {'thrill': 1.0},
#  '폭': {'thrill': 1.0},
#  '꾹': {'thrill': 1.0},
#  '가르치다': {'thrill': 0.33, 'love': 0.33, 'anger': 0.17, 'fear': 0.17},
#  '사로잡다': {'thrill': 1.0},
#  '뜬눈': {'thrill': 1.0},
#  '숨다': {'thrill': 0.22,
#   'love': 0.11,
#   'enthusiasm': 0.11,
#   'happyness': 0.11,
#   'sadness': 0.22,
#   'lonely': 0.11,
#   'fear': 0.11},
#  '장면': {'thrill': 1.0},
#  '반복': {'thrill': 0.17,
#   'love': 0.17,
#   'fun': 0.17,
#   'anger': 0.33,
#   'lonely': 0.08,
#   'longing': 0.08},
#  '오빠': {'thrill': 0.4, 'happyness': 0.2, 'anger': 0.4},
#  '카페': {'thrill': 0.67, 'longing': 0.33},
#  '한송이': {'thrill': 1.0},
#  '피우다': {'thrill': 0.5, 'sadness': 0.5},
#  '태어나다': {'thrill': 0.25, 'enthusiasm': 0.62, 'happyness': 0.12},
#  '멋있다': {'thrill': 0.5, 'enthusiasm': 0.25, 'happyness': 0.25},
#  '꾸미다': {'thrill': 0.5, 'love': 0.25, 'anger': 0.25},
#  'Come on': {'thrill': 0.5, 'fun': 0.25, 'anger': 0.25},
#  '꽤': {'thrill': 0.29, 'enthusiasm': 0.43, 'happyness': 0.14, 'anger': 0.14},
#  '그래요': {'thrill': 0.29, 'sadness': 0.43, 'lonely': 0.14, 'longing': 0.14},
#  '만큼': {'thrill': 0.09,
#   'love': 0.22,
#   'enthusiasm': 0.13,
#   'happyness': 0.13,
#   'sadness': 0.39,
#   'lonely': 0.04},
#  'u': {'thrill': 0.15,
#   'love': 0.08,
#   'fun': 0.23,
#   'enthusiasm': 0.08,
#   'happyness': 0.15,
#   'anger': 0.31},
#  'or': {'thrill': 1.0},
#  '서성거리다': {'thrill': 1.0},
#  '반짝이다': {'thrill': 0.33, 'fun': 0.5, 'happyness': 0.17},
#  '움직이다': {'thrill': 0.15, 'fun': 0.46, 'enthusiasm': 0.31, 'happyness': 0.08},
#  '와인': {'thrill': 1.0},
#  'see': {'thrill': 0.5, 'love': 0.25, 'happyness': 0.25},
#  '당장': {'thrill': 0.5, 'anger': 0.5},
#  '부족': {'thrill': 0.25, 'happyness': 0.12, 'sadness': 0.5, 'anger': 0.12},
#  '글': {'thrill': 0.33, 'love': 0.33, 'fun': 0.17, 'longing': 0.17},
#  '헤아리다': {'thrill': 0.67, 'lonely': 0.33},
#  '일부': {'thrill': 0.67, 'love': 0.33},
#  '눈감다': {'thrill': 1.0},
#  '무지개': {'thrill': 1.0},
#  '문': {'thrill': 0.5, 'happyness': 0.25, 'lonely': 0.25},
#  '발걸음': {'thrill': 0.4, 'happyness': 0.4, 'lonely': 0.2},
#  '알리다': {'thrill': 0.4, 'enthusiasm': 0.4, 'sadness': 0.2},
#  '외롭다': {'thrill': 0.05, 'happyness': 0.08, 'sadness': 0.05, 'lonely': 0.82},
#  '오늘 같은 밤': {'thrill': 1.0},
#  '똑바로': {'thrill': 1.0},
#  '발끝': {'thrill': 0.5, 'love': 0.25, 'happyness': 0.25},
#  '하루만': {'thrill': 1.0},
#  '그만큼': {'thrill': 0.4, 'love': 0.6},
#  'bounce': {'thrill': 1.0},
#  '주체': {'thrill': 1.0},
#  '비싸다': {'thrill': 0.67, 'anger': 0.33},
#  '파도': {'thrill': 0.29, 'fun': 0.57, 'longing': 0.14},
#  '환히': {'thrill': 1.0},
#  '선': {'thrill': 0.5, 'fun': 0.25, 'happyness': 0.25},
#  '붙이다': {'thrill': 0.33, 'fun': 0.33, 'enthusiasm': 0.17, 'anger': 0.17},
#  '진실': {'thrill': 0.4, 'love': 0.2, 'anger': 0.4},
#  '미': {'thrill': 0.29, 'fun': 0.57, 'enthusiasm': 0.14},
#  '의심': {'thrill': 0.29, 'enthusiasm': 0.29, 'sadness': 0.14, 'anger': 0.29},
#  '고양이': {'thrill': 1.0},
#  '다가서다': {'thrill': 1.0},
#  '주변': {'thrill': 0.4, 'happyness': 0.2, 'sadness': 0.2, 'anger': 0.2},
#  '입가': {'thrill': 0.5, 'sadness': 0.5},
#  '손짓': {'thrill': 0.5, 'enthusiasm': 0.25, 'longing': 0.25},
#  '무너지다': {'thrill': 0.14, 'sadness': 0.5, 'anger': 0.21, 'fear': 0.14},
#  'come': {'thrill': 0.15, 'love': 0.38, 'fun': 0.31, 'anger': 0.15},
#  'woo': {'thrill': 0.14,
#   'love': 0.07,
#   'fun': 0.36,
#   'happyness': 0.07,
#   'sadness': 0.14,
#   'anger': 0.14,
#   'lonely': 0.07},
#  '헷갈리다': {'thrill': 0.67, 'enthusiasm': 0.33},
#  '똑같다': {'thrill': 0.25, 'anger': 0.62, 'longing': 0.12},
#  '숙이다': {'thrill': 0.67, 'love': 0.33},
#  '나서다': {'thrill': 0.2,
#   'fun': 0.1,
#   'sadness': 0.4,
#   'anger': 0.1,
#   'longing': 0.2},
#  'bling': {'thrill': 0.67, 'happyness': 0.33},
#  '뜨겁다': {'thrill': 0.1,
#   'love': 0.19,
#   'fun': 0.43,
#   'enthusiasm': 0.14,
#   'happyness': 0.05,
#   'anger': 0.1},
#  '매력': {'thrill': 0.67, 'fun': 0.33},
#  '이란': {'thrill': 0.33, 'love': 0.17, 'happyness': 0.33, 'sadness': 0.17},
#  'yeh': {'thrill': 0.4, 'fun': 0.4, 'enthusiasm': 0.2},
#  '굳다': {'thrill': 0.29, 'sadness': 0.57, 'lonely': 0.14},
#  '머무르다': {'thrill': 0.22, 'love': 0.56, 'happyness': 0.11, 'lonely': 0.11},
#  '침대': {'thrill': 0.5, 'lonely': 0.5},
#  '팬티': {'thrill': 1.0},
#  '어김없이': {'thrill': 1.0},
#  '원': {'thrill': 0.08,
#   'love': 0.17,
#   'fun': 0.25,
#   'enthusiasm': 0.25,
#   'happyness': 0.04,
#   'sadness': 0.08,
#   'anger': 0.08,
#   'lonely': 0.04},
#  '당기다': {'thrill': 0.67, 'love': 0.33},
#  '토': {'thrill': 0.67, 'fun': 0.33},
#  '동안': {'thrill': 0.2,
#   'love': 0.2,
#   'sadness': 0.3,
#   'anger': 0.2,
#   'longing': 0.1},
#  '착각': {'thrill': 0.67, 'anger': 0.33},
#  '붉다': {'thrill': 0.29, 'love': 0.14, 'enthusiasm': 0.14, 'happyness': 0.43},
#  '나': {'thrill': 0.4, 'fun': 0.4, 'lonely': 0.2},
#  'hold': {'thrill': 1.0},
#  'at': {'thrill': 1.0},
#  '건너다': {'thrill': 0.4, 'love': 0.4, 'lonely': 0.2},
#  '자신': {'thrill': 0.09,
#   'enthusiasm': 0.27,
#   'sadness': 0.36,
#   'anger': 0.23,
#   'longing': 0.05},
#  '뺨': {'thrill': 0.67, 'love': 0.33},
#  '타다': {'thrill': 0.09,
#   'fun': 0.5,
#   'enthusiasm': 0.14,
#   'happyness': 0.05,
#   'anger': 0.09,
#   'lonely': 0.09,
#   'fear': 0.05},
#  '풀리다': {'thrill': 0.33, 'fun': 0.33, 'sadness': 0.17, 'lonely': 0.17},
#  '어둡다': {'thrill': 0.12,
#   'fun': 0.12,
#   'enthusiasm': 0.06,
#   'lonely': 0.29,
#   'fear': 0.41},
#  '그대 목소리': {'thrill': 1.0},
#  '돌아보다': {'thrill': 0.29, 'sadness': 0.29, 'anger': 0.14, 'lonely': 0.29},
#  '초가': {'thrill': 1.0},
#  '새하얗다': {'thrill': 0.67, 'happyness': 0.33},
#  '유리창': {'thrill': 1.0},
#  '가슴속': {'thrill': 0.22,
#   'love': 0.33,
#   'sadness': 0.11,
#   'lonely': 0.22,
#   'fear': 0.11},
#  '데리다': {'thrill': 0.4, 'happyness': 0.2, 'lonely': 0.4},
#  '뒷모습': {'thrill': 0.14, 'sadness': 0.36, 'lonely': 0.29, 'longing': 0.21},
#  '웃음': {'thrill': 0.1, 'fun': 0.1, 'happyness': 0.71, 'sadness': 0.1},
#  '인생': {'thrill': 0.05,
#   'love': 0.11,
#   'fun': 0.11,
#   'enthusiasm': 0.29,
#   'happyness': 0.18,
#   'sadness': 0.08,
#   'anger': 0.13,
#   'lonely': 0.03,
#   'longing': 0.03},
#  '또다시': {'thrill': 0.4, 'anger': 0.2, 'lonely': 0.2, 'longing': 0.2},
#  '틀': {'thrill': 0.29,
#   'enthusiasm': 0.14,
#   'happyness': 0.14,
#   'anger': 0.29,
#   'fear': 0.14},
#  '따라가다': {'thrill': 0.4, 'fun': 0.4, 'enthusiasm': 0.2},
#  '송이': {'thrill': 0.67, 'sadness': 0.33},
#  '색': {'thrill': 1.0},
#  '짙은': {'thrill': 0.4, 'lonely': 0.2, 'fear': 0.4},
#  '하나하나': {'thrill': 0.5, 'anger': 0.25, 'longing': 0.25},
#  '까맣다': {'thrill': 0.29,
#   'love': 0.14,
#   'happyness': 0.29,
#   'anger': 0.14,
#   'lonely': 0.14},
#  '알아주다': {'thrill': 0.5, 'love': 0.5},
#  'ey': {'thrill': 1.0},
#  '색깔': {'thrill': 0.5, 'fun': 0.5},
#  '안고': {'thrill': 0.13, 'love': 0.67, 'enthusiasm': 0.07, 'sadness': 0.13},
#  '어지럽다': {'thrill': 0.4, 'sadness': 0.6},
#  '간직': {'thrill': 0.29, 'love': 0.43, 'enthusiasm': 0.14, 'longing': 0.14},
#  '빨개지다': {'thrill': 1.0},
#  '끝내': {'thrill': 0.33, 'sadness': 0.5, 'lonely': 0.17},
#  '발짝': {'thrill': 1.0},
#  '행복': {'thrill': 0.02,
#   'love': 0.12,
#   'happyness': 0.68,
#   'sadness': 0.11,
#   'anger': 0.03,
#   'lonely': 0.02,
#   'longing': 0.02},
#  '맨날': {'thrill': 0.5, 'anger': 0.5},
#  '젖다': {'thrill': 0.18,
#   'fun': 0.09,
#   'enthusiasm': 0.09,
#   'happyness': 0.09,
#   'sadness': 0.18,
#   'lonely': 0.09,
#   'longing': 0.27},
#  '흩날리다': {'thrill': 0.67, 'love': 0.33},
#  '땜': {'thrill': 0.22,
#   'love': 0.11,
#   'enthusiasm': 0.22,
#   'happyness': 0.11,
#   'sadness': 0.22,
#   'anger': 0.11},
#  '어쩌면': {'thrill': 0.29,
#   'love': 0.14,
#   'fun': 0.14,
#   'lonely': 0.29,
#   'fear': 0.14},
#  'say': {'thrill': 0.14,
#   'love': 0.14,
#   'fun': 0.29,
#   'enthusiasm': 0.07,
#   'happyness': 0.07,
#   'sadness': 0.29},
#  '투명': {'thrill': 0.4, 'enthusiasm': 0.2, 'happyness': 0.4},
#  '거란': {'thrill': 0.4, 'sadness': 0.2, 'lonely': 0.4},
#  'someday': {'thrill': 0.67, 'love': 0.33},
#  '나란히': {'thrill': 1.0},
#  '우': {'thrill': 0.1,
#   'fun': 0.19,
#   'enthusiasm': 0.14,
#   'happyness': 0.05,
#   'sadness': 0.05,
#   'anger': 0.1,
#   'lonely': 0.24,
#   'longing': 0.1,
#   'fear': 0.05},
#  '장미': {'thrill': 0.67, 'love': 0.33},
#  '온': {'thrill': 1.0},
#  '이성': {'thrill': 0.29, 'sadness': 0.29, 'anger': 0.29, 'lonely': 0.14},
#  '아리다': {'thrill': 1.0},
#  '어떡하다': {'thrill': 1.0},
#  '넋': {'thrill': 0.67, 'sadness': 0.33},
#  '다짐': {'thrill': 0.29, 'enthusiasm': 0.43, 'sadness': 0.29},
#  'nothing': {'thrill': 0.67, 'lonely': 0.33},
#  '돌고': {'thrill': 0.29,
#   'enthusiasm': 0.14,
#   'happyness': 0.14,
#   'sadness': 0.29,
#   'longing': 0.14},
#  '짓': {'thrill': 0.5, 'anger': 0.5},
#  '행동': {'thrill': 0.67, 'anger': 0.33},
#  '인해': {'thrill': 0.67, 'love': 0.33},
#  '밀어': {'thrill': 1.0},
#  '높다': {'thrill': 0.13,
#   'love': 0.07,
#   'fun': 0.53,
#   'enthusiasm': 0.07,
#   'happyness': 0.2},
#  '계획': {'thrill': 0.67, 'sadness': 0.33},
#  '띄다': {'thrill': 1.0},
#  '매번': {'thrill': 1.0},
#  '거짓말': {'thrill': 0.06,
#   'fun': 0.03,
#   'happyness': 0.03,
#   'anger': 0.83,
#   'lonely': 0.06},
#  '맛': {'thrill': 0.15,
#   'love': 0.08,
#   'fun': 0.38,
#   'happyness': 0.31,
#   'anger': 0.08},
#  '부신': {'thrill': 1.0},
#  '빠': {'thrill': 0.2, 'love': 0.4, 'fun': 0.2, 'longing': 0.2},
#  '편지': {'thrill': 1.0},
#  'yes': {'thrill': 0.4, 'love': 0.2, 'enthusiasm': 0.2, 'happyness': 0.2},
#  '손끝': {'thrill': 1.0},
#  '어렵다': {'thrill': 0.25, 'sadness': 0.5, 'anger': 0.25},
#  '이후': {'thrill': 0.33, 'sadness': 0.33, 'anger': 0.17, 'lonely': 0.17},
#  '매다': {'thrill': 0.5, 'love': 0.25, 'enthusiasm': 0.25},
#  '돌아오다': {'thrill': 0.05,
#   'love': 0.03,
#   'enthusiasm': 0.08,
#   'happyness': 0.03,
#   'sadness': 0.03,
#   'anger': 0.03,
#   'lonely': 0.11,
#   'longing': 0.63,
#   'fear': 0.03},
#  '날아가다': {'thrill': 0.15,
#   'fun': 0.46,
#   'enthusiasm': 0.08,
#   'anger': 0.15,
#   'longing': 0.15},
#  'treasure': {'thrill': 0.5, 'love': 0.5},
#  '공간': {'thrill': 0.25, 'love': 0.12, 'fun': 0.5, 'anger': 0.12},
#  '음': {'thrill': 0.14,
#   'love': 0.14,
#   'fun': 0.21,
#   'enthusiasm': 0.07,
#   'happyness': 0.14,
#   'sadness': 0.07,
#   'lonely': 0.07,
#   'longing': 0.14},
#  '바': {'thrill': 0.13, 'love': 0.07, 'fun': 0.6, 'anger': 0.2},
#  '갖다': {'thrill': 0.33, 'happyness': 0.17, 'anger': 0.5},
#  'ring': {'thrill': 0.67, 'fun': 0.33},
#  'ok': {'thrill': 0.67, 'happyness': 0.33},
#  'why': {'thrill': 0.5, 'anger': 0.5},
#  'alright': {'thrill': 0.29, 'fun': 0.43, 'enthusiasm': 0.14, 'fear': 0.14},
#  '케미': {'thrill': 1.0},
#  '가을': {'thrill': 0.33, 'longing': 0.67},
#  '귀하다': {'thrill': 0.5, 'love': 0.5},
#  '힘겹다': {'thrill': 0.14, 'sadness': 0.86},
#  '내딛다': {'thrill': 0.5, 'sadness': 0.5},
#  '택하다': {'thrill': 0.5, 'lonely': 0.5},
#  '미래': {'thrill': 0.05,
#   'fun': 0.14,
#   'enthusiasm': 0.43,
#   'happyness': 0.14,
#   'anger': 0.19,
#   'fear': 0.05},
#  '시가': {'thrill': 0.5, 'enthusiasm': 0.5},
#  'drive': {'thrill': 0.17, 'fun': 0.83},
#  '거지': {'thrill': 0.12,
#   'love': 0.12,
#   'fun': 0.25,
#   'happyness': 0.25,
#   'anger': 0.12,
#   'fear': 0.12},
#  'yea': {'thrill': 0.2, 'fun': 0.4, 'anger': 0.4},
#  '색다르다': {'thrill': 0.5, 'enthusiasm': 0.5},
#  'remember': {'thrill': 1.0},
#  'creative': {'thrill': 1.0},
#  'ye': {'thrill': 0.08, 'love': 0.15, 'fun': 0.69, 'sadness': 0.08},
#  '폰': {'thrill': 1.0},
#  '알람': {'thrill': 0.33, 'fun': 0.67},
#  '너만이': {'thrill': 0.33, 'love': 0.67},
#  '만족': {'thrill': 0.33, 'happyness': 0.33, 'sadness': 0.33},
#  '기준': {'thrill': 1.0},
#  '발길': {'thrill': 0.33, 'enthusiasm': 0.33, 'longing': 0.33},
#  '입맞춤': {'thrill': 0.33, 'love': 0.67},
#  'busy': {'thrill': 0.5, 'happyness': 0.5},
#  '주인공': {'thrill': 0.12, 'fun': 0.5, 'happyness': 0.12, 'sadness': 0.25},
#  '춤추다': {'thrill': 0.1, 'love': 0.1, 'fun': 0.8},
#  '조이다': {'thrill': 0.5, 'lonely': 0.5},
#  '눈사람': {'thrill': 1.0},
#  '충동': {'thrill': 0.5, 'enthusiasm': 0.5},
#  '아이쿠': {'thrill': 1.0},
#  'of': {'thrill': 0.17, 'love': 0.33, 'fun': 0.33, 'anger': 0.17},
#  'us': {'thrill': 0.25, 'love': 0.25, 'anger': 0.5},
#  'ah': {'thrill': 0.25, 'fun': 0.5, 'fear': 0.25},
#  'outfit': {'thrill': 0.33, 'enthusiasm': 0.67},
#  'look': {'thrill': 1.0},
#  ...}

# %%
def lexicon_emotion_clf(sentence):
    temp = Counter()
    for word in emotion_tokenizer(sentence):
        try:
            temp = temp + Counter(vocab[word])
        except KeyError:
            pass
    emotion = list(temp.keys())
    score = list(temp.values())
    
    plt.pie(score, labels=emotion, autopct='%.1f%%')
    plt.show()
    
    return [k for k,v in dict(temp).items() if max(dict(temp).values()) == v]

# %%
lexicon_emotion_clf("니 모습이 너무 그리워")
# Out:
# ['longing']

# %%
#단어사전 저장
np.save('emotion_vocab_12class.npy', vocab)
