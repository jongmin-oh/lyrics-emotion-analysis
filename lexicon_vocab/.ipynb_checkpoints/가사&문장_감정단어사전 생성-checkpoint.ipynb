# %%
import re
import pandas as pd
import numpy as np
from collections import Counter
import nltk
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('english'))

# %%
from konlpy.tag import Komoran , Okt

# %%
kmoran = Komoran()

# %%
def lyrics_to_corpus(lyrics):
    lyrics = re.split('\r\n|\n',lyrics)
    #중복제거
    corpus = list(set(lyrics))
    result = " ".join(corpus)
    return result

# %%
def lexicon_tokenizer_komoran(corpus,kmoran):
    temp = []
    for i in kmoran.pos(corpus):
        if (i[1] == 'NNG' or i[1] == 'NNP'):
            temp.append(i[0])
        elif (i[1] == 'VV' or i[1] == 'VA'):
            temp.append(i[0] + "다")
        elif (i[1] == "SL"):
            if i[0].lower() not in stop_words:
                temp.append(i[0].lower())
    return temp

# %%
data = pd.read_excel('./감정별_가사_정리_10class.xlsx')
del data['Unnamed: 0']

# %%
sentence_data = pd.read_excel('../preprocessing/emotion_labels(ko).xlsb.xlsx')

# %%
data['sentence_len'] = data['가사'].map(lambda x : len(list(set(re.split('\r\n|\n',x)))))

# %%
def df_to_emotion_corpus(df , emotion):
    emotion_df = df[df['감정'] == emotion]
    # 문장 분리 중복제거
    emotion_df['가사'] = emotion_df['가사'].map(lambda x : lyrics_to_corpus(x))
    # 특수문자 제거
    emotion_df['가사'] = emotion_df['가사'].str.replace(pat=r'[^\w]', repl=r' ', regex=True)
    
    corpus = " ".join(emotion_df['가사'].to_list())
    return corpus

# %%
love_corpus = df_to_emotion_corpus(data , '사랑')
happyness_corpus = df_to_emotion_corpus(data , '행복')
fun_corpus = df_to_emotion_corpus(data , '신나는')
enthusiasm_corpus = df_to_emotion_corpus(data , '열정')
sadness_corpus = df_to_emotion_corpus(data , '슬픔')
anger_corpus = df_to_emotion_corpus(data , '분노')
longing_corpus = df_to_emotion_corpus(data , '그리움')
lonely_corpus = df_to_emotion_corpus(data , '외로움')
fear_corpus = df_to_emotion_corpus(data , '두려움')
# Out:
# <ipython-input-94-53b9105c66ff>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emotion_df['가사'] = emotion_df['가사'].map(lambda x : lyrics_to_corpus(x))
# <ipython-input-94-53b9105c66ff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emotion_df['가사'] = emotion_df['가사'].str.replace(pat=r'[^\w]', repl=r' ', regex=True)

# %%
emotion = {"love" : love_corpus ,
          "happyness" : happyness_corpus,
          "fun" : fun_corpus,
          "enthusiasm" : enthusiasm_corpus,
          "sadness" : sadness_corpus,
          "anger" : anger_corpus,
          "longing" : longing_corpus,
          "lonely" : lonely_corpus,
          "fear" : fear_corpus}

# %%
emotion_count = {}
vocab = {}
for i in range(len(emotion)):
    emotion_key = list(emotion.keys())[i]
    emotion_count[emotion_key] = Counter(lexicon_tokenizer_komoran(emotion[emotion_key],kmoran)).most_common(300)
    for words , counts in emotion_count[emotion_key]:
        if words in list(vocab.keys()):
            vocab[words][emotion_key] = counts
        else:
            vocab[words] = {emotion_key : counts }

# %%
emotion_keys = list(emotion.keys())
for word in list(vocab.keys()):
    total = sum(vocab[word].values())
    for keys in emotion_keys:
        try:
            vocab[word][keys] = round( (vocab[word][keys]  / total) , 2 )
        except KeyError:
            pass

# %%
# # 상위 3개 까지만 감정 점수에 포함
# for keys in vocab.keys():
#     vocab[keys] = dict(sorted(vocab[keys].items(), key=lambda x: x[1], reverse=True))
#     try :
#         for remove_emotion in list(vocab[keys].keys())[3:]:
#             vocab[keys].pop(remove_emotion)
#     except:
#         pass

# %%
vocab
# Out:
# {'하다': {'love': 0.12,
#   'happyness': 0.07,
#   'fun': 0.06,
#   'enthusiasm': 0.2,
#   'sadness': 0.12,
#   'anger': 0.16,
#   'longing': 0.07,
#   'lonely': 0.08,
#   'fear': 0.11},
#  '있다': {'love': 0.17,
#   'happyness': 0.11,
#   'fun': 0.04,
#   'enthusiasm': 0.17,
#   'sadness': 0.09,
#   'anger': 0.09,
#   'longing': 0.07,
#   'lonely': 0.18,
#   'fear': 0.1},
#  '사랑': {'love': 0.26,
#   'happyness': 0.03,
#   'enthusiasm': 0.02,
#   'sadness': 0.18,
#   'anger': 0.15,
#   'longing': 0.18,
#   'lonely': 0.11,
#   'fear': 0.06},
#  '말': {'love': 0.15,
#   'happyness': 0.04,
#   'fun': 0.04,
#   'enthusiasm': 0.16,
#   'sadness': 0.21,
#   'anger': 0.15,
#   'longing': 0.08,
#   'lonely': 0.07,
#   'fear': 0.09},
#  '나다': {'love': 0.1,
#   'happyness': 0.05,
#   'fun': 0.06,
#   'enthusiasm': 0.23,
#   'sadness': 0.13,
#   'anger': 0.13,
#   'longing': 0.08,
#   'lonely': 0.11,
#   'fear': 0.13},
#  '보다': {'love': 0.1,
#   'happyness': 0.07,
#   'fun': 0.07,
#   'enthusiasm': 0.11,
#   'sadness': 0.1,
#   'anger': 0.15,
#   'longing': 0.11,
#   'lonely': 0.2,
#   'fear': 0.09},
#  '날': {'love': 0.15,
#   'happyness': 0.06,
#   'fun': 0.02,
#   'enthusiasm': 0.12,
#   'sadness': 0.1,
#   'anger': 0.12,
#   'longing': 0.16,
#   'lonely': 0.12,
#   'fear': 0.15},
#  '없다': {'love': 0.1,
#   'happyness': 0.04,
#   'fun': 0.05,
#   'enthusiasm': 0.2,
#   'sadness': 0.11,
#   'anger': 0.13,
#   'longing': 0.1,
#   'lonely': 0.17,
#   'fear': 0.1},
#  '때': {'love': 0.17,
#   'happyness': 0.13,
#   'fun': 0.1,
#   'enthusiasm': 0.15,
#   'sadness': 0.03,
#   'anger': 0.12,
#   'longing': 0.06,
#   'lonely': 0.1,
#   'fear': 0.14},
#  'oh': {'love': 0.23,
#   'happyness': 0.04,
#   'fun': 0.21,
#   'enthusiasm': 0.1,
#   'anger': 0.25,
#   'longing': 0.02,
#   'lonely': 0.05,
#   'fear': 0.11},
#  '마음': {'love': 0.29,
#   'happyness': 0.11,
#   'fun': 0.08,
#   'enthusiasm': 0.08,
#   'sadness': 0.12,
#   'longing': 0.1,
#   'lonely': 0.12,
#   'fear': 0.08},
#  '사람': {'love': 0.18,
#   'happyness': 0.1,
#   'enthusiasm': 0.16,
#   'sadness': 0.09,
#   'anger': 0.09,
#   'longing': 0.09,
#   'lonely': 0.16,
#   'fear': 0.12},
#  '좋다': {'love': 0.22,
#   'happyness': 0.19,
#   'fun': 0.04,
#   'enthusiasm': 0.13,
#   'sadness': 0.06,
#   'anger': 0.12,
#   'longing': 0.14,
#   'lonely': 0.03,
#   'fear': 0.06},
#  'girl': {'love': 1.0},
#  '맘': {'love': 0.26,
#   'happyness': 0.07,
#   'fun': 0.05,
#   'enthusiasm': 0.11,
#   'sadness': 0.05,
#   'anger': 0.08,
#   'longing': 0.15,
#   'lonely': 0.08,
#   'fear': 0.14},
#  '알다': {'love': 0.2,
#   'happyness': 0.03,
#   'fun': 0.02,
#   'enthusiasm': 0.13,
#   'sadness': 0.11,
#   'anger': 0.18,
#   'longing': 0.1,
#   'lonely': 0.09,
#   'fear': 0.14},
#  '같다': {'love': 0.13,
#   'happyness': 0.1,
#   'fun': 0.02,
#   'enthusiasm': 0.06,
#   'sadness': 0.14,
#   'anger': 0.14,
#   'longing': 0.08,
#   'lonely': 0.17,
#   'fear': 0.16},
#  '너를 사랑해': {'love': 1.0},
#  '사랑해': {'love': 0.57,
#   'sadness': 0.1,
#   'anger': 0.1,
#   'longing': 0.07,
#   'fear': 0.17},
#  '넌': {'love': 0.14,
#   'happyness': 0.06,
#   'fun': 0.07,
#   'enthusiasm': 0.14,
#   'sadness': 0.1,
#   'anger': 0.32,
#   'longing': 0.04,
#   'lonely': 0.04,
#   'fear': 0.09},
#  '되다': {'love': 0.08,
#   'happyness': 0.1,
#   'fun': 0.1,
#   'enthusiasm': 0.26,
#   'sadness': 0.07,
#   'anger': 0.13,
#   'longing': 0.08,
#   'lonely': 0.05,
#   'fear': 0.13},
#  '내다': {'love': 0.13,
#   'happyness': 0.11,
#   'fun': 0.03,
#   'enthusiasm': 0.08,
#   'sadness': 0.11,
#   'anger': 0.2,
#   'longing': 0.1,
#   'lonely': 0.08,
#   'fear': 0.15},
#  '행복': {'love': 0.23,
#   'happyness': 0.21,
#   'fun': 0.08,
#   'enthusiasm': 0.1,
#   'sadness': 0.07,
#   'anger': 0.11,
#   'longing': 0.08,
#   'lonely': 0.11},
#  '눈': {'love': 0.14,
#   'happyness': 0.05,
#   'fun': 0.06,
#   'enthusiasm': 0.27,
#   'sadness': 0.12,
#   'anger': 0.12,
#   'longing': 0.05,
#   'lonely': 0.11,
#   'fear': 0.08},
#  '손': {'love': 0.23,
#   'happyness': 0.09,
#   'fun': 0.08,
#   'enthusiasm': 0.11,
#   'sadness': 0.08,
#   'anger': 0.15,
#   'longing': 0.04,
#   'lonely': 0.06,
#   'fear': 0.17},
#  'yeah': {'love': 0.12,
#   'happyness': 0.08,
#   'fun': 0.39,
#   'enthusiasm': 0.2,
#   'anger': 0.11,
#   'fear': 0.09},
#  '모르다': {'love': 0.11,
#   'happyness': 0.05,
#   'fun': 0.07,
#   'enthusiasm': 0.19,
#   'sadness': 0.12,
#   'anger': 0.1,
#   'longing': 0.12,
#   'lonely': 0.06,
#   'fear': 0.16},
#  '하늘': {'love': 0.26,
#   'happyness': 0.17,
#   'fun': 0.14,
#   'enthusiasm': 0.19,
#   'longing': 0.07,
#   'lonely': 0.07,
#   'fear': 0.1},
#  '이렇다': {'love': 0.14,
#   'happyness': 0.08,
#   'enthusiasm': 0.08,
#   'sadness': 0.2,
#   'anger': 0.19,
#   'longing': 0.11,
#   'lonely': 0.1,
#   'fear': 0.1},
#  'beautiful': {'love': 1.0},
#  '예쁘다': {'love': 0.69, 'fun': 0.19, 'longing': 0.12},
#  '세상': {'love': 0.22,
#   'happyness': 0.04,
#   'fun': 0.11,
#   'enthusiasm': 0.17,
#   'sadness': 0.07,
#   'longing': 0.2,
#   'lonely': 0.09,
#   'fear': 0.11},
#  '걸다': {'love': 0.08,
#   'happyness': 0.05,
#   'fun': 0.11,
#   'enthusiasm': 0.17,
#   'sadness': 0.11,
#   'anger': 0.15,
#   'longing': 0.08,
#   'lonely': 0.15,
#   'fear': 0.11},
#  '고백': {'love': 0.91, 'longing': 0.09},
#  '아름답다': {'love': 0.71, 'longing': 0.29},
#  '밤': {'love': 0.11,
#   'happyness': 0.03,
#   'fun': 0.3,
#   'enthusiasm': 0.12,
#   'sadness': 0.02,
#   'anger': 0.05,
#   'longing': 0.03,
#   'lonely': 0.18,
#   'fear': 0.15},
#  '오늘': {'love': 0.09,
#   'happyness': 0.24,
#   'fun': 0.18,
#   'enthusiasm': 0.08,
#   'sadness': 0.11,
#   'anger': 0.06,
#   'longing': 0.09,
#   'lonely': 0.07,
#   'fear': 0.07},
#  '느끼다': {'love': 0.32,
#   'fun': 0.11,
#   'enthusiasm': 0.18,
#   'sadness': 0.07,
#   'anger': 0.11,
#   'lonely': 0.11,
#   'fear': 0.11},
#  '오다': {'love': 0.16,
#   'happyness': 0.03,
#   'fun': 0.12,
#   'enthusiasm': 0.16,
#   'sadness': 0.03,
#   'anger': 0.12,
#   'longing': 0.14,
#   'lonely': 0.19,
#   'fear': 0.05},
#  '가슴': {'love': 0.16,
#   'fun': 0.09,
#   'sadness': 0.21,
#   'anger': 0.09,
#   'longing': 0.18,
#   'lonely': 0.19,
#   'fear': 0.09},
#  '줄다': {'love': 0.33, 'fun': 0.21, 'anger': 0.25, 'fear': 0.21},
#  '가다': {'love': 0.06,
#   'happyness': 0.13,
#   'fun': 0.15,
#   'enthusiasm': 0.17,
#   'sadness': 0.06,
#   'anger': 0.08,
#   'longing': 0.15,
#   'lonely': 0.14,
#   'fear': 0.07},
#  '미소': {'love': 0.5, 'longing': 0.19, 'lonely': 0.31},
#  '사랑해 사랑해': {'love': 0.89, 'longing': 0.11},
#  '시간': {'love': 0.09,
#   'happyness': 0.12,
#   'fun': 0.09,
#   'enthusiasm': 0.16,
#   'sadness': 0.06,
#   'anger': 0.13,
#   'longing': 0.13,
#   'lonely': 0.09,
#   'fear': 0.12},
#  'u': {'love': 0.25,
#   'happyness': 0.19,
#   'fun': 0.12,
#   'enthusiasm': 0.22,
#   'anger': 0.22},
#  '보이다': {'love': 0.12,
#   'happyness': 0.07,
#   'fun': 0.12,
#   'enthusiasm': 0.28,
#   'sadness': 0.05,
#   'anger': 0.09,
#   'longing': 0.1,
#   'lonely': 0.1,
#   'fear': 0.07},
#  '게': {'love': 0.08,
#   'happyness': 0.02,
#   'fun': 0.03,
#   'enthusiasm': 0.21,
#   'sadness': 0.13,
#   'anger': 0.21,
#   'longing': 0.05,
#   'lonely': 0.11,
#   'fear': 0.15},
#  'try': {'love': 1.0},
#  '속': {'love': 0.07,
#   'happyness': 0.04,
#   'fun': 0.04,
#   'enthusiasm': 0.12,
#   'sadness': 0.1,
#   'anger': 0.14,
#   'longing': 0.08,
#   'lonely': 0.17,
#   'fear': 0.23},
#  '너에게': {'love': 0.23,
#   'happyness': 0.2,
#   'enthusiasm': 0.13,
#   'anger': 0.17,
#   'longing': 0.03,
#   'lonely': 0.1,
#   'fear': 0.13},
#  '눈물': {'love': 0.12,
#   'happyness': 0.05,
#   'sadness': 0.43,
#   'anger': 0.05,
#   'longing': 0.22,
#   'lonely': 0.03,
#   'fear': 0.09},
#  '웃다': {'love': 0.1,
#   'happyness': 0.07,
#   'fun': 0.03,
#   'enthusiasm': 0.07,
#   'sadness': 0.36,
#   'anger': 0.09,
#   'longing': 0.12,
#   'lonely': 0.13,
#   'fear': 0.03},
#  '설레다': {'love': 0.47, 'happyness': 0.13, 'longing': 0.2, 'lonely': 0.2},
#  'love': {'love': 0.23,
#   'fun': 0.1,
#   'enthusiasm': 0.17,
#   'anger': 0.17,
#   'longing': 0.2,
#   'fear': 0.13},
#  '푸른': {'love': 0.7, 'fun': 0.3},
#  '너만이': {'love': 1.0},
#  '좋은 날': {'love': 1.0},
#  '잡다': {'love': 0.22,
#   'happyness': 0.06,
#   'fun': 0.22,
#   'enthusiasm': 0.12,
#   'sadness': 0.06,
#   'anger': 0.09,
#   'fear': 0.22},
#  '친구': {'love': 0.28,
#   'happyness': 0.04,
#   'fun': 0.12,
#   'enthusiasm': 0.28,
#   'sadness': 0.04,
#   'anger': 0.16,
#   'lonely': 0.08},
#  '안기다': {'love': 0.54, 'happyness': 0.23, 'sadness': 0.08, 'longing': 0.15},
#  '겨울': {'love': 1.0},
#  '그러다': {'love': 0.14,
#   'enthusiasm': 0.12,
#   'sadness': 0.14,
#   'anger': 0.19,
#   'longing': 0.02,
#   'lonely': 0.24,
#   'fear': 0.14},
#  '이제': {'love': 0.07,
#   'happyness': 0.06,
#   'fun': 0.08,
#   'enthusiasm': 0.09,
#   'sadness': 0.18,
#   'anger': 0.23,
#   'longing': 0.18,
#   'lonely': 0.07,
#   'fear': 0.05},
#  '오': {'love': 0.23, 'happyness': 0.31, 'sadness': 0.31, 'longing': 0.15},
#  '많다': {'love': 0.12,
#   'happyness': 0.14,
#   'enthusiasm': 0.39,
#   'sadness': 0.14,
#   'anger': 0.08,
#   'longing': 0.02,
#   'lonely': 0.04,
#   'fear': 0.08},
#  '앞': {'love': 0.16,
#   'happyness': 0.05,
#   'enthusiasm': 0.26,
#   'sadness': 0.08,
#   'anger': 0.29,
#   'longing': 0.08,
#   'fear': 0.08},
#  'baby': {'love': 0.12,
#   'happyness': 0.04,
#   'fun': 0.17,
#   'enthusiasm': 0.15,
#   'anger': 0.15,
#   'longing': 0.12,
#   'lonely': 0.13,
#   'fear': 0.12},
#  '곁': {'love': 0.32, 'longing': 0.32, 'lonely': 0.26, 'fear': 0.11},
#  '서로': {'love': 0.46, 'sadness': 0.15, 'longing': 0.31, 'lonely': 0.08},
#  '꿈': {'love': 0.08,
#   'happyness': 0.04,
#   'enthusiasm': 0.58,
#   'sadness': 0.04,
#   'anger': 0.08,
#   'lonely': 0.08,
#   'fear': 0.11},
#  '너와 나': {'love': 0.29,
#   'fun': 0.19,
#   'sadness': 0.1,
#   'anger': 0.29,
#   'longing': 0.05,
#   'lonely': 0.1},
#  '숨기다': {'love': 0.46, 'lonely': 0.23, 'fear': 0.31},
#  '느낌': {'love': 0.38, 'happyness': 0.12, 'fun': 0.5},
#  '생각': {'love': 0.08,
#   'happyness': 0.04,
#   'enthusiasm': 0.16,
#   'sadness': 0.09,
#   'anger': 0.23,
#   'longing': 0.13,
#   'lonely': 0.11,
#   'fear': 0.16},
#  '모습': {'love': 0.11,
#   'happyness': 0.11,
#   'fun': 0.06,
#   'enthusiasm': 0.13,
#   'sadness': 0.13,
#   'anger': 0.11,
#   'longing': 0.15,
#   'lonely': 0.17,
#   'fear': 0.04},
#  '약속': {'love': 0.67, 'longing': 0.33},
#  '만나다': {'love': 0.12,
#   'happyness': 0.1,
#   'sadness': 0.17,
#   'anger': 0.21,
#   'longing': 0.06,
#   'lonely': 0.23,
#   'fear': 0.1},
#  '품': {'love': 0.67, 'happyness': 0.22, 'longing': 0.11},
#  '사랑해요': {'love': 0.5, 'sadness': 0.17, 'longing': 0.33},
#  '엄지': {'love': 1.0},
#  '집': {'love': 0.12,
#   'happyness': 0.05,
#   'fun': 0.12,
#   'enthusiasm': 0.2,
#   'sadness': 0.05,
#   'anger': 0.23,
#   'lonely': 0.23},
#  '내리다': {'love': 0.22,
#   'happyness': 0.09,
#   'enthusiasm': 0.48,
#   'longing': 0.09,
#   'lonely': 0.13},
#  '고맙다': {'love': 0.38, 'sadness': 0.15, 'longing': 0.38, 'lonely': 0.08},
#  '이유': {'love': 0.31, 'happyness': 0.12, 'anger': 0.25, 'lonely': 0.31},
#  '변하다': {'love': 0.12,
#   'fun': 0.05,
#   'enthusiasm': 0.12,
#   'sadness': 0.12,
#   'anger': 0.12,
#   'longing': 0.24,
#   'lonely': 0.07,
#   'fear': 0.15},
#  '안다': {'love': 0.56, 'sadness': 0.22, 'fear': 0.22},
#  '기분': {'love': 0.16,
#   'happyness': 0.23,
#   'fun': 0.16,
#   'enthusiasm': 0.13,
#   'anger': 0.19,
#   'lonely': 0.13},
#  '얼굴': {'love': 0.24,
#   'sadness': 0.19,
#   'anger': 0.14,
#   'lonely': 0.14,
#   'fear': 0.29},
#  '감다': {'love': 0.28,
#   'happyness': 0.11,
#   'enthusiasm': 0.17,
#   'sadness': 0.17,
#   'anger': 0.22,
#   'longing': 0.06},
#  '햇살': {'love': 0.45, 'happyness': 0.36, 'sadness': 0.18},
#  '지나다': {'love': 0.13,
#   'happyness': 0.11,
#   'fun': 0.05,
#   'enthusiasm': 0.11,
#   'sadness': 0.11,
#   'anger': 0.05,
#   'longing': 0.21,
#   'lonely': 0.13,
#   'fear': 0.11},
#  '들다': {'love': 0.1,
#   'happyness': 0.17,
#   'fun': 0.15,
#   'enthusiasm': 0.23,
#   'sadness': 0.02,
#   'anger': 0.15,
#   'longing': 0.02,
#   'lonely': 0.04,
#   'fear': 0.12},
#  'make': {'love': 0.31, 'fun': 0.25, 'enthusiasm': 0.31, 'anger': 0.12},
#  '기억': {'love': 0.07,
#   'fun': 0.03,
#   'enthusiasm': 0.08,
#   'sadness': 0.07,
#   'anger': 0.11,
#   'longing': 0.33,
#   'lonely': 0.14,
#   'fear': 0.17},
#  '미치다': {'love': 0.11,
#   'happyness': 0.04,
#   'fun': 0.4,
#   'enthusiasm': 0.07,
#   'anger': 0.16,
#   'longing': 0.18,
#   'lonely': 0.04},
#  '로맨틱': {'love': 1.0},
#  '그때': {'love': 0.12,
#   'sadness': 0.12,
#   'anger': 0.12,
#   'longing': 0.53,
#   'fear': 0.12},
#  '노래': {'love': 0.12,
#   'happyness': 0.12,
#   'fun': 0.34,
#   'enthusiasm': 0.09,
#   'sadness': 0.09,
#   'anger': 0.19,
#   'longing': 0.03},
#  '위하다': {'love': 0.17,
#   'happyness': 0.21,
#   'enthusiasm': 0.46,
#   'longing': 0.04,
#   'fear': 0.12},
#  '살아가다': {'love': 0.31, 'anger': 0.15, 'longing': 0.15, 'fear': 0.38},
#  '옆': {'love': 0.33, 'sadness': 0.17, 'anger': 0.25, 'lonely': 0.25},
#  '살다': {'love': 0.05,
#   'happyness': 0.03,
#   'fun': 0.1,
#   'enthusiasm': 0.32,
#   'sadness': 0.05,
#   'anger': 0.08,
#   'longing': 0.14,
#   'lonely': 0.17,
#   'fear': 0.06},
#  '하루': {'love': 0.08,
#   'happyness': 0.15,
#   'fun': 0.06,
#   'enthusiasm': 0.06,
#   'sadness': 0.17,
#   'anger': 0.06,
#   'longing': 0.19,
#   'lonely': 0.15,
#   'fear': 0.08},
#  '삶': {'love': 0.14,
#   'happyness': 0.04,
#   'enthusiasm': 0.36,
#   'lonely': 0.07,
#   'fear': 0.39},
#  '지키다': {'love': 0.57, 'enthusiasm': 0.43},
#  '지금': {'love': 0.15,
#   'happyness': 0.11,
#   'fun': 0.26,
#   'enthusiasm': 0.26,
#   'sadness': 0.11,
#   'longing': 0.11},
#  '그렇다': {'love': 0.06,
#   'happyness': 0.03,
#   'enthusiasm': 0.14,
#   'sadness': 0.1,
#   'anger': 0.15,
#   'longing': 0.24,
#   'lonely': 0.15,
#   'fear': 0.13},
#  '비추다': {'love': 1.0},
#  '꾸다': {'love': 0.13,
#   'happyness': 0.07,
#   'fun': 0.1,
#   'enthusiasm': 0.5,
#   'sadness': 0.03,
#   'anger': 0.07,
#   'fear': 0.1},
#  '서다': {'love': 0.36, 'anger': 0.18, 'lonely': 0.27, 'fear': 0.18},
#  '바다': {'love': 0.57, 'fun': 0.43},
#  '아끼다': {'love': 1.0},
#  '입술': {'love': 0.44, 'sadness': 0.22, 'anger': 0.33},
#  '제일': {'love': 0.44, 'happyness': 0.33, 'sadness': 0.11, 'longing': 0.11},
#  '믿다': {'love': 0.08,
#   'happyness': 0.06,
#   'enthusiasm': 0.4,
#   'sadness': 0.08,
#   'anger': 0.14,
#   'longing': 0.1,
#   'fear': 0.14},
#  '깊다': {'love': 0.25,
#   'enthusiasm': 0.25,
#   'sadness': 0.12,
#   'longing': 0.12,
#   'lonely': 0.12,
#   'fear': 0.12},
#  '웃음': {'love': 0.36, 'happyness': 0.36, 'sadness': 0.09, 'anger': 0.18},
#  '피하다': {'love': 0.5, 'longing': 0.12, 'fear': 0.38},
#  'ye': {'love': 0.29, 'fun': 0.71},
#  'babe': {'love': 1.0},
#  '여자': {'love': 0.4, 'sadness': 0.3, 'anger': 0.3},
#  '사이': {'love': 0.33, 'happyness': 0.17, 'anger': 0.42, 'longing': 0.08},
#  '내일': {'love': 0.14,
#   'happyness': 0.14,
#   'fun': 0.28,
#   'enthusiasm': 0.28,
#   'lonely': 0.1,
#   'fear': 0.07},
#  '영원': {'love': 0.5, 'fun': 0.25, 'fear': 0.25},
#  '나오다': {'love': 0.11,
#   'happyness': 0.08,
#   'fun': 0.36,
#   'enthusiasm': 0.14,
#   'sadness': 0.06,
#   'anger': 0.17,
#   'lonely': 0.08},
#  '떨어지다': {'love': 1.0},
#  '사실': {'love': 0.19,
#   'happyness': 0.24,
#   'enthusiasm': 0.14,
#   'anger': 0.1,
#   'lonely': 0.14,
#   'fear': 0.19},
#  '누가': {'love': 1.0},
#  'nothing': {'love': 1.0},
#  'better': {'love': 0.5, 'enthusiasm': 0.5},
#  'listen': {'love': 1.0},
#  '고마워요': {'love': 1.0},
#  '어떻다': {'love': 0.09,
#   'happyness': 0.06,
#   'fun': 0.18,
#   'enthusiasm': 0.12,
#   'sadness': 0.06,
#   'anger': 0.21,
#   'longing': 0.18,
#   'lonely': 0.06,
#   'fear': 0.06},
#  '남다': {'love': 0.15,
#   'anger': 0.15,
#   'longing': 0.4,
#   'lonely': 0.2,
#   'fear': 0.1},
#  '기쁘다': {'love': 1.0},
#  '고민': {'love': 0.27, 'happyness': 0.27, 'enthusiasm': 0.45},
#  '흔들다': {'love': 0.43, 'fun': 0.57},
#  '끊다': {'love': 0.6, 'anger': 0.4},
#  '대신': {'love': 0.3, 'enthusiasm': 0.4, 'longing': 0.1, 'fear': 0.2},
#  '짓다': {'love': 0.23, 'happyness': 0.15, 'fun': 0.38, 'anger': 0.23},
#  '맞다': {'love': 0.12,
#   'happyness': 0.08,
#   'fun': 0.12,
#   'enthusiasm': 0.12,
#   'sadness': 0.12,
#   'anger': 0.19,
#   'lonely': 0.12,
#   'fear': 0.15},
#  '내 사랑': {'love': 0.43, 'longing': 0.29, 'fear': 0.29},
#  '벅차다': {'love': 1.0},
#  '감사': {'love': 1.0},
#  '뛰다': {'love': 0.12, 'fun': 0.79, 'longing': 0.08},
#  '심장': {'love': 0.14,
#   'fun': 0.27,
#   'sadness': 0.23,
#   'anger': 0.18,
#   'fear': 0.18},
#  '어깨': {'love': 0.27, 'happyness': 0.45, 'enthusiasm': 0.27},
#  '향하다': {'love': 0.2, 'fun': 0.13, 'enthusiasm': 0.53, 'anger': 0.13},
#  '힘들다': {'love': 0.07,
#   'happyness': 0.12,
#   'fun': 0.05,
#   'enthusiasm': 0.21,
#   'sadness': 0.19,
#   'longing': 0.02,
#   'lonely': 0.21,
#   'fear': 0.12},
#  '끝': {'love': 0.07,
#   'happyness': 0.07,
#   'enthusiasm': 0.19,
#   'sadness': 0.12,
#   'anger': 0.23,
#   'lonely': 0.14,
#   'fear': 0.19},
#  '모두': {'love': 0.23, 'enthusiasm': 0.62, 'fear': 0.15},
#  '빛': {'love': 0.15, 'enthusiasm': 0.6, 'fear': 0.25},
#  '열리다': {'love': 1.0},
#  '순간': {'love': 0.07,
#   'happyness': 0.17,
#   'fun': 0.1,
#   'enthusiasm': 0.1,
#   'sadness': 0.17,
#   'anger': 0.17,
#   'longing': 0.05,
#   'lonely': 0.1,
#   'fear': 0.07},
#  '환하다': {'love': 1.0},
#  '바람': {'love': 0.11,
#   'happyness': 0.25,
#   'fun': 0.21,
#   'sadness': 0.11,
#   'anger': 0.11,
#   'lonely': 0.07,
#   'fear': 0.14},
#  '다가오다': {'love': 0.5, 'fear': 0.5},
#  '전부': {'love': 0.27, 'anger': 0.27, 'longing': 0.27, 'lonely': 0.18},
#  '참다': {'love': 0.15,
#   'sadness': 0.1,
#   'anger': 0.3,
#   'longing': 0.1,
#   'lonely': 0.15,
#   'fear': 0.2},
#  '대답': {'love': 0.33, 'anger': 0.22, 'lonely': 0.22, 'fear': 0.22},
#  '멋지다': {'love': 0.25, 'happyness': 0.5, 'fun': 0.25},
#  '쉽다': {'love': 0.2, 'enthusiasm': 0.4, 'sadness': 0.2, 'longing': 0.2},
#  'day': {'love': 0.12,
#   'happyness': 0.35,
#   'fun': 0.27,
#   'anger': 0.15,
#   'longing': 0.12},
#  '바라보다': {'love': 0.19,
#   'happyness': 0.12,
#   'sadness': 0.19,
#   'longing': 0.06,
#   'lonely': 0.31,
#   'fear': 0.12},
#  '운명': {'love': 1.0},
#  '기다리다': {'love': 0.13,
#   'happyness': 0.13,
#   'sadness': 0.17,
#   'longing': 0.26,
#   'lonely': 0.22,
#   'fear': 0.09},
#  '날아가다': {'love': 0.43, 'happyness': 0.29, 'fear': 0.29},
#  '쓰다': {'love': 0.14,
#   'enthusiasm': 0.36,
#   'sadness': 0.18,
#   'anger': 0.14,
#   'longing': 0.09,
#   'fear': 0.09},
#  '입다': {'love': 0.2, 'happyness': 0.13, 'fun': 0.33, 'enthusiasm': 0.33},
#  '머리': {'love': 0.12,
#   'happyness': 0.16,
#   'fun': 0.12,
#   'enthusiasm': 0.24,
#   'anger': 0.12,
#   'longing': 0.12,
#   'lonely': 0.12},
#  '설레임': {'love': 1.0},
#  '이번': {'love': 0.43, 'fun': 0.29, 'anger': 0.29},
#  '만들다': {'love': 0.16,
#   'fun': 0.11,
#   'enthusiasm': 0.26,
#   'anger': 0.42,
#   'longing': 0.05},
#  '크다': {'love': 0.11,
#   'happyness': 0.04,
#   'fun': 0.26,
#   'enthusiasm': 0.26,
#   'sadness': 0.11,
#   'anger': 0.07,
#   'lonely': 0.07,
#   'fear': 0.07},
#  '바꾸다': {'love': 1.0},
#  '봄': {'love': 1.0},
#  '꽃': {'love': 1.0},
#  '봄이': {'love': 1.0},
#  '빛나다': {'love': 0.43, 'happyness': 0.57},
#  '바래다': {'love': 0.12,
#   'fun': 0.08,
#   'enthusiasm': 0.36,
#   'longing': 0.28,
#   'lonely': 0.16},
#  '변함없다': {'love': 1.0},
#  '애인': {'love': 1.0},
#  'night': {'love': 0.16, 'fun': 0.79, 'lonely': 0.05},
#  '걷다': {'love': 0.07,
#   'happyness': 0.11,
#   'fun': 0.11,
#   'enthusiasm': 0.24,
#   'sadness': 0.04,
#   'lonely': 0.33,
#   'fear': 0.09},
#  '아무도': {'love': 0.13,
#   'fun': 0.22,
#   'enthusiasm': 0.35,
#   'sadness': 0.09,
#   'lonely': 0.09,
#   'fear': 0.13},
#  '달빛': {'love': 1.0},
#  '처음': {'love': 0.13,
#   'enthusiasm': 0.26,
#   'sadness': 0.13,
#   'longing': 0.22,
#   'lonely': 0.09,
#   'fear': 0.17},
#  '사방': {'love': 1.0},
#  '불': {'love': 0.33, 'fun': 0.67},
#  '밝히다': {'love': 1.0},
#  '트리': {'love': 1.0},
#  '장면': {'love': 1.0},
#  '라': {'love': 1.0},
#  '취하다': {'love': 0.25, 'fun': 0.25, 'sadness': 0.25, 'lonely': 0.25},
#  '이쁘다': {'love': 1.0},
#  '뒤돌다': {'love': 0.5, 'happyness': 0.33, 'lonely': 0.17},
#  '남자': {'love': 0.33, 'lonely': 0.44, 'fear': 0.22},
#  '잠': {'love': 0.15,
#   'happyness': 0.3,
#   'enthusiasm': 0.3,
#   'anger': 0.2,
#   'lonely': 0.05},
#  '찾다': {'love': 0.1,
#   'happyness': 0.06,
#   'sadness': 0.06,
#   'anger': 0.32,
#   'longing': 0.1,
#   'lonely': 0.19,
#   'fear': 0.16},
#  '아프다': {'love': 0.04,
#   'sadness': 0.32,
#   'anger': 0.09,
#   'longing': 0.4,
#   'lonely': 0.05,
#   'fear': 0.1},
#  'sure': {'love': 1.0},
#  'anymore': {'love': 1.0},
#  '달라': {'love': 1.0},
#  '다르다': {'love': 0.29, 'enthusiasm': 0.57, 'lonely': 0.14},
#  '펼쳐지다': {'love': 1.0},
#  '그림': {'love': 0.5, 'happyness': 0.5},
#  '방': {'love': 0.1, 'enthusiasm': 0.2, 'lonely': 0.35, 'fear': 0.35},
#  '부르다': {'love': 0.1,
#   'fun': 0.2,
#   'sadness': 0.25,
#   'longing': 0.25,
#   'fear': 0.2},
#  '밤새': {'love': 0.29, 'fun': 0.43, 'longing': 0.29},
#  '맞추다': {'love': 0.5, 'happyness': 0.5},
#  '후회': {'love': 0.09,
#   'happyness': 0.09,
#   'sadness': 0.13,
#   'anger': 0.26,
#   'lonely': 0.13,
#   'fear': 0.3},
#  '채우다': {'love': 0.29, 'lonely': 0.43, 'fear': 0.29},
#  '아침': {'love': 0.08, 'happyness': 0.58, 'sadness': 0.08, 'lonely': 0.25},
#  '기대다': {'love': 0.5, 'happyness': 0.5},
#  '사라지다': {'love': 0.09,
#   'fun': 0.22,
#   'anger': 0.22,
#   'lonely': 0.17,
#   'fear': 0.3},
#  'um': {'love': 1.0},
#  '혼자': {'love': 0.03,
#   'happyness': 0.06,
#   'enthusiasm': 0.09,
#   'sadness': 0.14,
#   'anger': 0.04,
#   'longing': 0.06,
#   'lonely': 0.47,
#   'fear': 0.1},
#  '태양': {'love': 0.33, 'happyness': 0.33, 'fun': 0.33},
#  '아래': {'love': 0.4, 'fun': 0.6},
#  '파란': {'love': 0.5, 'happyness': 0.5},
#  '이상': {'love': 0.12, 'enthusiasm': 0.24, 'anger': 0.29, 'lonely': 0.35},
#  '기적': {'love': 1.0},
#  '울다': {'love': 0.04,
#   'sadness': 0.47,
#   'anger': 0.09,
#   'longing': 0.13,
#   'lonely': 0.21,
#   'fear': 0.06},
#  '결국': {'love': 1.0},
#  '꾸미다': {'love': 1.0},
#  '모자라다': {'love': 1.0},
#  '즐겁다': {'love': 0.67, 'happyness': 0.33},
#  '적시다': {'love': 1.0},
#  '흐르다': {'love': 0.2, 'happyness': 0.2, 'longing': 0.3, 'fear': 0.3},
#  '가슴속': {'love': 1.0},
#  '곳': {'love': 0.11,
#   'happyness': 0.11,
#   'enthusiasm': 0.22,
#   'longing': 0.17,
#   'lonely': 0.17,
#   'fear': 0.22},
#  '근대': {'love': 1.0},
#  '부럽다': {'love': 1.0},
#  '해': {'love': 0.22, 'happyness': 0.22, 'fun': 0.33, 'lonely': 0.22},
#  '잊다': {'love': 0.03,
#   'happyness': 0.08,
#   'fun': 0.11,
#   'enthusiasm': 0.07,
#   'sadness': 0.12,
#   'anger': 0.04,
#   'longing': 0.37,
#   'lonely': 0.15,
#   'fear': 0.04},
#  '수록': {'love': 1.0},
#  '향기': {'love': 0.4, 'happyness': 0.4, 'longing': 0.2},
#  '아픔': {'love': 0.25, 'sadness': 0.25, 'longing': 0.5},
#  '지내다': {'love': 0.17, 'sadness': 0.17, 'longing': 0.5, 'lonely': 0.17},
#  '떨리다': {'love': 0.5, 'sadness': 0.5},
#  '수도': {'love': 1.0},
#  'every': {'love': 0.2, 'happyness': 0.4, 'anger': 0.3, 'lonely': 0.1},
#  'lucky': {'love': 1.0},
#  '신경': {'love': 0.29, 'enthusiasm': 0.43, 'sadness': 0.29},
#  '얘기': {'love': 0.08,
#   'happyness': 0.16,
#   'enthusiasm': 0.12,
#   'sadness': 0.28,
#   'anger': 0.24,
#   'longing': 0.04,
#   'lonely': 0.08},
#  '고개': {'love': 0.33, 'happyness': 0.33, 'fear': 0.33},
#  '거절': {'love': 1.0},
#  'rap': {'love': 1.0},
#  '나서다': {'love': 0.33, 'happyness': 0.33, 'sadness': 0.33},
#  '용서': {'love': 0.4, 'anger': 0.6},
#  '헤어지다': {'love': 0.05,
#   'sadness': 0.58,
#   'anger': 0.12,
#   'longing': 0.07,
#   'lonely': 0.09,
#   'fear': 0.09},
#  '수줍다': {'love': 1.0},
#  '잠들다': {'love': 0.25, 'anger': 0.25, 'lonely': 0.5},
#  '스며들다': {'love': 1.0},
#  '변화': {'love': 1.0},
#  '놀라다': {'love': 1.0},
#  '이름': {'love': 0.22, 'enthusiasm': 0.33, 'sadness': 0.22, 'fear': 0.22},
#  '투명': {'love': 1.0},
#  '내려오다': {'love': 1.0},
#  '피부': {'love': 1.0},
#  '눈앞': {'love': 1.0},
#  '꽃잎': {'love': 1.0},
#  '짧다': {'love': 1.0},
#  '두렵다': {'love': 0.06, 'enthusiasm': 0.16, 'lonely': 0.06, 'fear': 0.71},
#  '사랑이란': {'love': 1.0},
#  '외롭다': {'love': 0.05,
#   'happyness': 0.05,
#   'sadness': 0.07,
#   'lonely': 0.74,
#   'fear': 0.1},
#  '전': {'love': 0.1,
#   'fun': 0.24,
#   'enthusiasm': 0.38,
#   'anger': 0.1,
#   'fear': 0.19},
#  'outta': {'love': 1.0},
#  'control': {'love': 1.0},
#  '오오': {'love': 1.0},
#  '별': {'love': 0.2, 'enthusiasm': 0.3, 'longing': 0.2, 'lonely': 0.3},
#  '강하다': {'love': 1.0},
#  '밀려오다': {'love': 1.0},
#  '파도': {'love': 0.4, 'fun': 0.6},
#  'nobody': {'love': 1.0},
#  'good': {'love': 0.25, 'happyness': 0.38, 'anger': 0.25, 'longing': 0.12},
#  '달리다': {'love': 0.07, 'happyness': 0.07, 'fun': 0.55, 'enthusiasm': 0.31},
#  'always': {'love': 0.2, 'enthusiasm': 0.7, 'lonely': 0.1},
#  '아깝다': {'love': 0.5, 'fun': 0.5},
#  'heart': {'love': 1.0},
#  'ha': {'love': 0.5, 'fun': 0.5},
#  'beat': {'love': 1.0},
#  '반': {'love': 1.0},
#  '잔': {'love': 1.0},
#  '떼': {'love': 1.0},
#  'romantic': {'love': 1.0},
#  '술': {'love': 0.07,
#   'fun': 0.17,
#   'sadness': 0.41,
#   'anger': 0.1,
#   'longing': 0.14,
#   'lonely': 0.1},
#  '혀다': {'love': 1.0},
#  '팔다': {'love': 0.4, 'enthusiasm': 0.6},
#  '타다': {'love': 0.22, 'happyness': 0.44, 'fun': 0.33},
#  '콩': {'love': 1.0},
#  '치다': {'love': 0.08,
#   'happyness': 0.12,
#   'fun': 0.15,
#   'enthusiasm': 0.19,
#   'anger': 0.35,
#   'fear': 0.12},
#  '불만': {'love': 1.0},
#  '커플': {'love': 1.0},
#  '애쓰다': {'love': 0.18, 'sadness': 0.27, 'longing': 0.36, 'lonely': 0.18},
#  '전화': {'love': 0.22, 'anger': 0.56, 'longing': 0.22},
#  '흔하다': {'love': 1.0},
#  '풍기다': {'love': 1.0},
#  '깍다': {'love': 1.0},
#  '나나': {'happyness': 0.45, 'fun': 0.55},
#  'happy': {'happyness': 1.0},
#  '괜찮아': {'happyness': 0.53, 'fun': 0.16, 'anger': 0.11, 'longing': 0.21},
#  '라라': {'happyness': 0.6, 'fun': 0.4},
#  '걱정': {'happyness': 0.29,
#   'fun': 0.25,
#   'enthusiasm': 0.32,
#   'longing': 0.07,
#   'lonely': 0.07},
#  '커다랗다': {'happyness': 1.0},
#  '길': {'happyness': 0.13,
#   'fun': 0.08,
#   'enthusiasm': 0.27,
#   'anger': 0.06,
#   'longing': 0.06,
#   'lonely': 0.19,
#   'fear': 0.21},
#  '쉬다': {'happyness': 0.3,
#   'fun': 0.26,
#   'enthusiasm': 0.22,
#   'lonely': 0.13,
#   'fear': 0.09},
#  'things': {'happyness': 1.0},
#  '떠나다': {'happyness': 0.13,
#   'fun': 0.07,
#   'sadness': 0.28,
#   'anger': 0.09,
#   'longing': 0.15,
#   'lonely': 0.2,
#   'fear': 0.09},
#  '안': {'happyness': 0.11,
#   'fun': 0.04,
#   'enthusiasm': 0.29,
#   'sadness': 0.12,
#   'anger': 0.09,
#   'longing': 0.21,
#   'lonely': 0.04,
#   'fear': 0.11},
#  '맑다': {'happyness': 1.0},
#  '바라다': {'happyness': 0.43, 'sadness': 0.07, 'lonely': 0.36, 'fear': 0.14},
#  '일': {'happyness': 0.12,
#   'fun': 0.07,
#   'enthusiasm': 0.42,
#   'anger': 0.1,
#   'longing': 0.07,
#   'lonely': 0.1,
#   'fear': 0.1},
#  'viva': {'happyness': 1.0},
#  '행운': {'happyness': 1.0},
#  '예': {'happyness': 0.45, 'enthusiasm': 0.27, 'lonely': 0.27},
#  '숨': {'happyness': 0.24,
#   'fun': 0.24,
#   'enthusiasm': 0.14,
#   'lonely': 0.24,
#   'fear': 0.14},
#  '자신': {'happyness': 0.18,
#   'enthusiasm': 0.39,
#   'sadness': 0.11,
#   'longing': 0.07,
#   'lonely': 0.07,
#   'fear': 0.18},
#  '뜨다': {'happyness': 0.16,
#   'fun': 0.08,
#   'enthusiasm': 0.36,
#   'sadness': 0.08,
#   'longing': 0.08,
#   'lonely': 0.24},
#  '부리다': {'happyness': 0.5, 'enthusiasm': 0.5},
#  '상상': {'happyness': 0.57, 'enthusiasm': 0.43},
#  '먹다': {'happyness': 0.24, 'enthusiasm': 0.35, 'anger': 0.29, 'fear': 0.12},
#  '힘': {'happyness': 0.29, 'enthusiasm': 0.36, 'longing': 0.14, 'lonely': 0.21},
#  'primavera': {'happyness': 1.0},
#  '작다': {'happyness': 0.5, 'longing': 0.25, 'fear': 0.25},
#  '위': {'happyness': 0.09,
#   'fun': 0.4,
#   'enthusiasm': 0.4,
#   'sadness': 0.05,
#   'anger': 0.07},
#  '눈부시다': {'happyness': 0.57, 'longing': 0.43},
#  '조금': {'happyness': 0.57, 'sadness': 0.29, 'longing': 0.14},
#  '요즘': {'happyness': 0.29, 'enthusiasm': 0.43, 'anger': 0.14, 'lonely': 0.14},
#  '지하철': {'happyness': 1.0},
#  '창문': {'happyness': 0.8, 'longing': 0.2},
#  '비치다': {'happyness': 0.5, 'sadness': 0.5},
#  '깨다': {'happyness': 0.15, 'enthusiasm': 0.48, 'anger': 0.11, 'lonely': 0.26},
#  'morning': {'happyness': 1.0},
#  'ah': {'happyness': 0.29, 'fun': 0.43, 'fear': 0.29},
#  '껴안다': {'happyness': 1.0},
#  '자리': {'happyness': 0.33, 'enthusiasm': 0.44, 'sadness': 0.22},
#  '일어나다': {'happyness': 0.25, 'enthusiasm': 0.75},
#  '춤': {'happyness': 0.13, 'fun': 0.87},
#  '추다': {'happyness': 0.14, 'fun': 0.86},
#  '버스': {'happyness': 1.0},
#  '걸음': {'happyness': 0.5, 'sadness': 0.5},
#  '동네': {'happyness': 0.5, 'fun': 0.5},
#  '끝나다': {'happyness': 0.27,
#   'enthusiasm': 0.27,
#   'sadness': 0.18,
#   'anger': 0.27},
#  '따르다': {'happyness': 0.5, 'fun': 0.5},
#  '앉다': {'happyness': 0.6, 'sadness': 0.4},
#  '아쉽다': {'happyness': 0.43, 'lonely': 0.57},
#  'anything': {'happyness': 1.0},
#  'time': {'happyness': 0.25, 'fun': 0.75},
#  '표정': {'happyness': 0.6, 'fear': 0.4},
#  '그대와 함께': {'happyness': 1.0},
#  '안녕': {'happyness': 0.23, 'sadness': 0.77},
#  '시작': {'happyness': 0.43, 'lonely': 0.29, 'fear': 0.29},
#  '기대': {'happyness': 0.75, 'longing': 0.25},
#  '받다': {'happyness': 0.1,
#   'fun': 0.06,
#   'enthusiasm': 0.19,
#   'anger': 0.35,
#   'lonely': 0.1,
#   'fear': 0.19},
#  '랄': {'happyness': 1.0},
#  '릴': {'happyness': 1.0},
#  '새': {'happyness': 1.0},
#  '어제': {'happyness': 0.25, 'enthusiasm': 0.33, 'sadness': 0.42},
#  '비': {'happyness': 0.21, 'enthusiasm': 0.21, 'anger': 0.29, 'lonely': 0.29},
#  '이르다': {'happyness': 1.0},
#  'okay': {'happyness': 1.0},
#  'holiday': {'happyness': 1.0},
#  '바쁘다': {'happyness': 0.3, 'anger': 0.3, 'longing': 0.2, 'lonely': 0.2},
#  '날씨': {'happyness': 1.0},
#  'problem': {'happyness': 1.0},
#  'drive': {'happyness': 1.0},
#  'Fall In Love': {'happyness': 1.0},
#  '당장': {'happyness': 1.0},
#  '어울리다': {'happyness': 1.0},
#  '입': {'happyness': 0.12, 'enthusiasm': 0.19, 'sadness': 0.25, 'anger': 0.44},
#  '불다': {'happyness': 0.4, 'fun': 0.6},
#  '걸어가다': {'happyness': 0.5, 'lonely': 0.5},
#  '돌아가다': {'happyness': 0.18, 'longing': 0.18, 'lonely': 0.64},
#  '풀리다': {'happyness': 0.67, 'sadness': 0.33},
#  '펴다': {'happyness': 0.22, 'enthusiasm': 0.78},
#  '음': {'happyness': 0.33, 'longing': 0.67},
#  '젊다': {'happyness': 1.0},
#  '오래되다': {'happyness': 1.0},
#  '바람이 분다': {'happyness': 1.0},
#  '공기': {'happyness': 1.0},
#  '달다': {'happyness': 0.5, 'fear': 0.5},
#  '청춘': {'happyness': 0.33, 'enthusiasm': 0.67},
#  '다시다': {'happyness': 0.2, 'sadness': 0.2, 'anger': 0.6},
#  '빌어': {'happyness': 1.0},
#  '주문': {'happyness': 0.67, 'sadness': 0.33},
#  '지치다': {'happyness': 0.17, 'fun': 0.33, 'sadness': 0.25, 'lonely': 0.25},
#  '해보다': {'happyness': 1.0},
#  '마지막': {'happyness': 0.09,
#   'fun': 0.22,
#   'sadness': 0.13,
#   'anger': 0.22,
#   'longing': 0.17,
#   'lonely': 0.17},
#  '쓸데없다': {'happyness': 0.5, 'fun': 0.5},
#  'bye': {'happyness': 0.33, 'anger': 0.5, 'longing': 0.17},
#  'hey': {'happyness': 0.08, 'fun': 0.68, 'enthusiasm': 0.12, 'anger': 0.12},
#  'know': {'happyness': 0.12,
#   'fun': 0.18,
#   'enthusiasm': 0.35,
#   'anger': 0.24,
#   'fear': 0.12},
#  '밤새다': {'happyness': 0.33, 'fun': 0.33, 'sadness': 0.33},
#  '몸': {'happyness': 0.14, 'fun': 0.5, 'sadness': 0.14, 'fear': 0.21},
#  'gonna': {'happyness': 0.5, 'anger': 0.5},
#  '놓다': {'happyness': 0.29, 'sadness': 0.29, 'fear': 0.43},
#  '끝없다': {'happyness': 1.0},
#  '여행': {'happyness': 1.0},
#  '똑같다': {'happyness': 0.22, 'anger': 0.44, 'longing': 0.11, 'lonely': 0.22},
#  '흘리다': {'happyness': 0.33, 'sadness': 0.33, 'fear': 0.33},
#  '빌다': {'happyness': 0.4, 'anger': 0.6},
#  '서툴다': {'happyness': 0.33, 'sadness': 0.33, 'longing': 0.33},
#  '멈추다': {'happyness': 0.09,
#   'enthusiasm': 0.3,
#   'sadness': 0.17,
#   'longing': 0.09,
#   'lonely': 0.09,
#   'fear': 0.26},
#  'enjoy': {'happyness': 1.0},
#  'life': {'happyness': 0.17, 'enthusiasm': 0.83},
#  '밝다': {'happyness': 1.0},
#  '후후': {'happyness': 1.0},
#  '미래': {'happyness': 0.25, 'enthusiasm': 0.75},
#  '의심': {'happyness': 0.29, 'enthusiasm': 0.71},
#  '슈퍼스타': {'happyness': 1.0},
#  '계획': {'happyness': 1.0},
#  '불안': {'happyness': 0.4, 'fear': 0.6},
#  '반복': {'happyness': 0.17, 'sadness': 0.08, 'longing': 0.58, 'fear': 0.17},
#  '밥': {'happyness': 0.67, 'sadness': 0.33},
#  '지나가다': {'happyness': 0.18, 'longing': 0.36, 'fear': 0.45},
#  '가도': {'happyness': 0.67, 'longing': 0.33},
#  '계단': {'happyness': 1.0},
#  '내려가다': {'happyness': 1.0},
#  '승강장': {'happyness': 1.0},
#  '들어오다': {'happyness': 0.29, 'fun': 0.29, 'enthusiasm': 0.43},
#  '소리': {'happyness': 0.12, 'fun': 0.65, 'fear': 0.24},
#  '구겨지다': {'happyness': 1.0},
#  '민트': {'happyness': 1.0},
#  '열다': {'happyness': 0.29, 'sadness': 0.71},
#  '창밖': {'happyness': 1.0},
#  '어우러지다': {'happyness': 1.0},
#  '아들': {'happyness': 0.4, 'enthusiasm': 0.6},
#  '노랫소리': {'happyness': 1.0},
#  '들려오다': {'happyness': 1.0},
#  '응석': {'happyness': 1.0},
#  '동기': {'happyness': 1.0},
#  '딸': {'happyness': 1.0},
#  '어머니': {'happyness': 1.0},
#  '기쁨': {'happyness': 1.0},
#  '토': {'happyness': 1.0},
#  '학': {'happyness': 1.0},
#  'live': {'happyness': 0.5, 'fear': 0.5},
#  'let': {'happyness': 0.08, 'fun': 0.56, 'enthusiasm': 0.24, 'fear': 0.12},
#  '날개': {'happyness': 0.4, 'fear': 0.6},
#  'r': {'happyness': 1.0},
#  '온종일': {'happyness': 0.67, 'lonely': 0.33},
#  'want': {'happyness': 0.2, 'anger': 0.6, 'longing': 0.2},
#  'go': {'happyness': 0.04,
#   'fun': 0.3,
#   'enthusiasm': 0.49,
#   'longing': 0.02,
#   'fear': 0.15},
#  '앞으로': {'happyness': 1.0},
#  '의미': {'happyness': 0.25, 'enthusiasm': 0.38, 'lonely': 0.38},
#  '창': {'happyness': 0.5, 'sadness': 0.5},
#  '예뻐': {'happyness': 1.0},
#  '하마': {'happyness': 1.0},
#  '하품': {'happyness': 1.0},
#  '둥글다': {'happyness': 1.0},
#  '여유': {'happyness': 1.0},
#  '원하다': {'happyness': 0.12, 'enthusiasm': 0.62, 'fear': 0.25},
#  '오랜만': {'happyness': 0.33, 'fear': 0.67},
#  '좋아하다': {'happyness': 1.0},
#  '출근길': {'happyness': 1.0},
#  '좋아서': {'happyness': 0.33, 'sadness': 0.67},
#  '보너스': {'happyness': 1.0},
#  '휴가': {'happyness': 1.0},
#  '예상': {'happyness': 1.0},
#  '안색': {'happyness': 1.0},
#  '맛있다': {'happyness': 1.0},
#  '누': {'happyness': 0.25, 'lonely': 0.75},
#  '군가': {'happyness': 0.25, 'lonely': 0.75},
#  '쾌': {'happyness': 1.0},
#  '변': {'happyness': 1.0},
#  '즐기다': {'happyness': 1.0},
#  '공부': {'happyness': 1.0},
#  '알아주다': {'happyness': 1.0},
#  '기지개': {'happyness': 1.0},
#  '푸르다': {'happyness': 1.0},
#  '거닐다': {'happyness': 1.0},
#  '거리': {'happyness': 0.07, 'sadness': 0.2, 'longing': 0.33, 'lonely': 0.4},
#  '부서지다': {'happyness': 0.33, 'fear': 0.67},
#  '내사랑': {'happyness': 1.0},
#  'la': {'fun': 0.72, 'fear': 0.28},
#  '놀다': {'fun': 1.0},
#  'dance': {'fun': 1.0},
#  '신나다': {'fun': 1.0},
#  'party': {'fun': 1.0},
#  'like': {'fun': 0.48, 'enthusiasm': 0.44, 'fear': 0.07},
#  'stop': {'fun': 0.92, 'longing': 0.08},
#  '여름': {'fun': 1.0},
#  'ya': {'fun': 0.79, 'enthusiasm': 0.21},
#  '트로트': {'fun': 1.0},
#  'fire': {'fun': 1.0},
#  '랩': {'fun': 0.62, 'enthusiasm': 0.25, 'anger': 0.12},
#  '인생': {'fun': 0.29, 'enthusiasm': 0.44, 'lonely': 0.12, 'fear': 0.15},
#  '던지다': {'fun': 1.0},
#  '부비': {'fun': 1.0},
#  'get': {'fun': 0.41, 'enthusiasm': 0.45, 'anger': 0.14},
#  'right': {'fun': 0.82, 'fear': 0.18},
#  '리듬': {'fun': 1.0},
#  'livin': {'fun': 1.0},
#  'dan': {'fun': 1.0},
#  '움직이다': {'fun': 0.89, 'sadness': 0.11},
#  'whoo': {'fun': 1.0},
#  'boom': {'fun': 1.0},
#  'birthday': {'fun': 1.0},
#  '뜨겁다': {'fun': 1.0},
#  'away': {'fun': 0.5, 'longing': 0.36, 'lonely': 0.14},
#  '난나': {'fun': 1.0},
#  'yeh': {'fun': 1.0},
#  'gon': {'fun': 1.0},
#  'wow': {'fun': 1.0},
#  'magic': {'fun': 1.0},
#  '빠지다': {'fun': 1.0},
#  'shake': {'fun': 1.0},
#  '뒤': {'fun': 0.19,
#   'enthusiasm': 0.35,
#   'sadness': 0.03,
#   'anger': 0.26,
#   'lonely': 0.06,
#   'fear': 0.1},
#  'summer': {'fun': 1.0},
#  '지르다': {'fun': 0.67, 'anger': 0.33},
#  '타오르다': {'fun': 1.0},
#  '아무것': {'fun': 0.23,
#   'enthusiasm': 0.14,
#   'sadness': 0.27,
#   'longing': 0.09,
#   'lonely': 0.14,
#   'fear': 0.14},
#  '분위기': {'fun': 1.0},
#  '아아': {'fun': 1.0},
#  'dancing': {'fun': 1.0},
#  'supermagic': {'fun': 1.0},
#  'keep': {'fun': 1.0},
#  '달': {'fun': 0.62, 'lonely': 0.38},
#  '돈': {'fun': 0.15, 'enthusiasm': 0.74, 'anger': 0.12},
#  'run': {'fun': 0.28, 'enthusiasm': 0.56, 'fear': 0.17},
#  'tonight': {'fun': 1.0},
#  '클럽': {'fun': 1.0},
#  'follow': {'fun': 1.0},
#  'say': {'fun': 0.5, 'anger': 0.5},
#  'wake': {'fun': 1.0},
#  '넘다': {'fun': 1.0},
#  '남': {'fun': 0.36, 'anger': 0.27, 'longing': 0.18, 'lonely': 0.18},
#  '테': {'fun': 0.57, 'anger': 0.43},
#  '발악': {'fun': 1.0},
#  '무대': {'fun': 0.44, 'enthusiasm': 0.56},
#  '빼다': {'fun': 0.4, 'enthusiasm': 0.6},
#  '챙기다': {'fun': 0.57, 'enthusiasm': 0.43},
#  'celebrate': {'fun': 1.0},
#  'everyday': {'fun': 0.57, 'anger': 0.43},
#  'one': {'fun': 0.4, 'enthusiasm': 0.6},
#  '길다': {'fun': 0.33, 'sadness': 0.17, 'anger': 0.25, 'lonely': 0.25},
#  'Come on': {'fun': 1.0},
#  '차렷': {'fun': 1.0},
#  'back': {'fun': 0.36, 'anger': 0.64},
#  'tell': {'fun': 0.36, 'enthusiasm': 0.27, 'anger': 0.36},
#  '나가다': {'fun': 1.0},
#  '틀다': {'fun': 1.0},
#  '파라': {'fun': 1.0},
#  '뭐': {'fun': 0.67, 'anger': 0.33},
#  'da': {'fun': 0.4, 'lonely': 0.6},
#  '울리다': {'fun': 0.57, 'fear': 0.43},
#  'fanfare': {'fun': 1.0},
#  'loud': {'fun': 1.0},
#  'jump': {'fun': 1.0},
#  'higher': {'fun': 1.0},
#  'tik': {'fun': 1.0},
#  'tok': {'fun': 1.0},
#  'welcome': {'fun': 1.0},
#  'rip': {'fun': 1.0},
#  '뚫다': {'fun': 1.0},
#  '리': {'fun': 0.75, 'sadness': 0.25},
#  'fantastic': {'fun': 1.0},
#  'huh': {'fun': 1.0},
#  '얼음': {'fun': 1.0},
#  '넘치다': {'fun': 1.0},
#  '춤추다': {'fun': 1.0},
#  'hit': {'fun': 1.0},
#  '파티': {'fun': 1.0},
#  'mind': {'fun': 0.75, 'lonely': 0.25},
#  '필요': {'fun': 0.17, 'enthusiasm': 0.17, 'anger': 0.56, 'lonely': 0.11},
#  'mister': {'fun': 1.0},
#  'hot': {'fun': 1.0},
#  '맛': {'fun': 1.0},
#  'prr': {'fun': 1.0},
#  '한강': {'fun': 0.6, 'anger': 0.4},
#  '갈래': {'fun': 1.0},
#  '여기다': {'fun': 1.0},
#  '식다': {'fun': 1.0},
#  '탬버린': {'fun': 1.0},
#  'turn': {'fun': 0.43, 'enthusiasm': 0.57},
#  '절대': {'fun': 0.21, 'enthusiasm': 0.36, 'sadness': 0.07, 'anger': 0.36},
#  '음악': {'fun': 0.3, 'enthusiasm': 0.4, 'anger': 0.3},
#  '흥': {'fun': 1.0},
#  '달아오르다': {'fun': 1.0},
#  '맡기다': {'fun': 1.0},
#  '짜증': {'fun': 1.0},
#  'left': {'fun': 1.0},
#  'burn': {'fun': 1.0},
#  '다다': {'fun': 1.0},
#  '붉다': {'fun': 1.0},
#  'come': {'fun': 0.5, 'enthusiasm': 0.5},
#  '형': {'fun': 0.38, 'enthusiasm': 0.62},
#  '들이대다': {'fun': 1.0},
#  '호랑나비': {'fun': 1.0},
#  '쇼': {'fun': 1.0},
#  '싫다': {'fun': 0.05,
#   'enthusiasm': 0.23,
#   'sadness': 0.07,
#   'anger': 0.26,
#   'longing': 0.05,
#   'lonely': 0.21,
#   'fear': 0.12},
#  '열기': {'fun': 1.0},
#  'singing': {'fun': 1.0},
#  '야야': {'fun': 1.0},
#  '시끄럽다': {'fun': 0.5, 'enthusiasm': 0.5},
#  '돌리다': {'fun': 1.0},
#  '태우다': {'fun': 0.6, 'sadness': 0.4},
#  '바퀴': {'fun': 1.0},
#  '붐': {'fun': 1.0},
#  '죽다': {'fun': 0.08,
#   'enthusiasm': 0.3,
#   'sadness': 0.14,
#   'anger': 0.22,
#   'longing': 0.11,
#   'lonely': 0.08,
#   'fear': 0.08},
#  '수저': {'fun': 1.0},
#  '세리머니': {'fun': 1.0},
#  'rock': {'fun': 1.0},
#  '수리': {'fun': 1.0},
#  '외치다': {'fun': 0.6, 'sadness': 0.2, 'longing': 0.2},
#  '리라': {'fun': 1.0},
#  '붙다': {'fun': 1.0},
#  '모이다': {'fun': 1.0},
#  '묻다': {'fun': 0.12,
#   'enthusiasm': 0.25,
#   'sadness': 0.25,
#   'anger': 0.19,
#   'lonely': 0.19},
#  '돌다': {'fun': 0.25, 'longing': 0.38, 'lonely': 0.38},
#  '앞서다': {'fun': 1.0},
#  'wanna': {'fun': 0.15, 'enthusiasm': 0.31, 'anger': 0.23, 'fear': 0.31},
#  '타락': {'fun': 1.0},
#  '가자': {'fun': 0.67, 'sadness': 0.33},
#  'pow': {'fun': 1.0},
#  'money': {'fun': 0.33, 'enthusiasm': 0.67},
#  '미리': {'fun': 1.0},
#  '이건': {'fun': 0.13, 'enthusiasm': 0.33, 'sadness': 0.07, 'anger': 0.47},
#  'team': {'fun': 1.0},
#  '쌓이다': {'fun': 0.33, 'enthusiasm': 0.67},
#  'could': {'fun': 1.0},
#  'champagne': {'fun': 1.0},
#  'positive': {'fun': 1.0},
#  'vibe': {'fun': 1.0},
#  'pop': {'fun': 0.33, 'anger': 0.67},
#  '벗다': {'fun': 1.0},
#  '건배': {'fun': 1.0},
#  'cha': {'fun': 1.0},
#  'boy': {'fun': 0.4, 'enthusiasm': 0.6},
#  '종일': {'fun': 0.4, 'sadness': 0.2, 'lonely': 0.4},
#  'city': {'fun': 1.0},
#  'uh': {'fun': 0.18, 'enthusiasm': 0.64, 'fear': 0.18},
#  'movin': {'fun': 1.0},
#  'deserve': {'fun': 1.0},
#  'diamonds': {'fun': 1.0},
#  '달려가다': {'fun': 1.0},
#  '강남': {'fun': 1.0},
#  '이태원': {'fun': 1.0},
#  '고달프다': {'fun': 1.0},
#  '성공': {'enthusiasm': 0.91, 'fear': 0.09},
#  '깨': {'enthusiasm': 1.0},
#  '벌다': {'enthusiasm': 1.0},
#  'got': {'enthusiasm': 1.0},
#  '포기': {'enthusiasm': 1.0},
#  'independent': {'enthusiasm': 1.0},
#  'way': {'enthusiasm': 1.0},
#  '이루다': {'enthusiasm': 0.82, 'anger': 0.18},
#  'still': {'enthusiasm': 0.69, 'longing': 0.15, 'fear': 0.15},
#  'vvs': {'enthusiasm': 1.0},
#  '기회': {'enthusiasm': 0.67, 'sadness': 0.17, 'fear': 0.17},
#  'high': {'enthusiasm': 1.0},
#  '대하다': {'enthusiasm': 1.0},
#  '어리다': {'enthusiasm': 0.64, 'lonely': 0.09, 'fear': 0.27},
#  '적다': {'enthusiasm': 0.78, 'sadness': 0.11, 'lonely': 0.11},
#  'feel': {'enthusiasm': 1.0},
#  '가지다': {'enthusiasm': 0.6, 'longing': 0.3, 'lonely': 0.1},
#  'top': {'enthusiasm': 1.0},
#  '준비': {'enthusiasm': 1.0},
#  'see': {'enthusiasm': 1.0},
#  'alright': {'enthusiasm': 1.0},
#  'ay': {'enthusiasm': 1.0},
#  '힙합': {'enthusiasm': 1.0},
#  'mr': {'enthusiasm': 0.6, 'lonely': 0.4},
#  '밖': {'enthusiasm': 0.83, 'longing': 0.17},
#  'never': {'enthusiasm': 1.0},
#  '잃다': {'enthusiasm': 0.26, 'sadness': 0.21, 'fear': 0.53},
#  '욕심': {'enthusiasm': 0.71, 'sadness': 0.29},
#  'game': {'enthusiasm': 1.0},
#  '옷': {'enthusiasm': 1.0},
#  '욕': {'enthusiasm': 0.28, 'anger': 0.72},
#  'awake': {'enthusiasm': 1.0},
#  'gotta': {'enthusiasm': 1.0},
#  '그리다': {'enthusiasm': 0.62, 'longing': 0.12, 'lonely': 0.25},
#  'star': {'enthusiasm': 1.0},
#  'im': {'enthusiasm': 0.26, 'anger': 0.21, 'lonely': 0.53},
#  '멀다': {'enthusiasm': 0.28, 'sadness': 0.11, 'longing': 0.33, 'lonely': 0.28},
#  'real': {'enthusiasm': 0.71, 'fear': 0.29},
#  'man': {'enthusiasm': 1.0},
#  '다음': {'enthusiasm': 0.67, 'fear': 0.33},
#  '뒤집다': {'enthusiasm': 1.0},
#  '도전': {'enthusiasm': 1.0},
#  '넘어지다': {'enthusiasm': 1.0},
#  '바뀌다': {'enthusiasm': 1.0},
#  '재밌다': {'enthusiasm': 1.0},
#  'young': {'enthusiasm': 1.0},
#  '새끼': {'enthusiasm': 0.4, 'anger': 0.6},
#  '자유': {'enthusiasm': 1.0},
#  '가리다': {'enthusiasm': 0.67, 'fear': 0.33},
#  'fly': {'enthusiasm': 1.0},
#  '듣다': {'enthusiasm': 0.17,
#   'anger': 0.33,
#   'longing': 0.25,
#   'lonely': 0.08,
#   'fear': 0.17},
#  '열정': {'enthusiasm': 1.0},
#  'give': {'enthusiasm': 1.0},
#  '이기다': {'enthusiasm': 1.0},
#  'dreams': {'enthusiasm': 1.0},
#  '해내다': {'enthusiasm': 0.4, 'sadness': 0.6},
#  '담다': {'enthusiasm': 0.36, 'longing': 0.27, 'lonely': 0.36},
#  '가족': {'enthusiasm': 0.67, 'fear': 0.33},
#  '현실': {'enthusiasm': 0.2,
#   'sadness': 0.1,
#   'anger': 0.1,
#   'longing': 0.05,
#   'lonely': 0.25,
#   'fear': 0.3},
#  '주변': {'enthusiasm': 1.0},
#  '긍정': {'enthusiasm': 1.0},
#  '가사': {'enthusiasm': 0.36, 'sadness': 0.18, 'anger': 0.45},
#  '노력': {'enthusiasm': 0.57, 'anger': 0.43},
#  '망하다': {'enthusiasm': 1.0},
#  '이루어지다': {'enthusiasm': 1.0},
#  '공연': {'enthusiasm': 1.0},
#  '엄마': {'enthusiasm': 1.0},
#  '승리': {'enthusiasm': 1.0},
#  '떡': {'enthusiasm': 0.6, 'sadness': 0.4},
#  '실패': {'enthusiasm': 1.0},
#  '부정': {'enthusiasm': 0.75, 'sadness': 0.25},
#  '높다': {'enthusiasm': 0.6, 'lonely': 0.4},
#  '믿음': {'enthusiasm': 1.0},
#  '신': {'enthusiasm': 1.0},
#  '다': {'enthusiasm': 1.0},
#  '탓': {'enthusiasm': 0.5, 'lonely': 0.17, 'fear': 0.33},
#  '부잣집': {'enthusiasm': 1.0},
#  '주위': {'enthusiasm': 0.6, 'lonely': 0.4},
#  '두르다': {'enthusiasm': 1.0},
#  '배우다': {'enthusiasm': 1.0},
#  '늦다': {'enthusiasm': 0.27, 'longing': 0.36, 'lonely': 0.18, 'fear': 0.18},
#  '잘살다': {'enthusiasm': 1.0},
#  '키우다': {'enthusiasm': 1.0},
#  'world': {'enthusiasm': 1.0},
#  '부모': {'enthusiasm': 1.0},
#  '넓다': {'enthusiasm': 1.0},
#  '위험': {'enthusiasm': 0.6, 'anger': 0.4},
#  'bottom': {'enthusiasm': 1.0},
#  '나라': {'enthusiasm': 1.0},
#  '부시다': {'enthusiasm': 1.0},
#  '주제': {'enthusiasm': 1.0},
#  '지구': {'enthusiasm': 1.0},
#  'boi': {'enthusiasm': 1.0},
#  '젊음': {'enthusiasm': 1.0},
#  '미루다': {'enthusiasm': 0.75, 'longing': 0.25},
#  '눕다': {'enthusiasm': 0.6, 'lonely': 0.4},
#  '싸움': {'enthusiasm': 1.0},
#  '확신': {'enthusiasm': 1.0},
#  '바닥': {'enthusiasm': 1.0},
#  '목소리': {'enthusiasm': 0.25, 'sadness': 0.17, 'anger': 0.33, 'fear': 0.25},
#  '닿다': {'enthusiasm': 0.5, 'fear': 0.5},
#  'yah': {'enthusiasm': 1.0},
#  'true': {'enthusiasm': 0.6, 'fear': 0.4},
#  '시대': {'enthusiasm': 1.0},
#  'crazy': {'enthusiasm': 0.38, 'anger': 0.62},
#  '싫어하다': {'enthusiasm': 0.75, 'sadness': 0.25},
#  '막다': {'enthusiasm': 1.0},
#  '무시': {'enthusiasm': 1.0},
#  '괴롭다': {'enthusiasm': 0.6, 'fear': 0.4},
#  '문제': {'enthusiasm': 0.5, 'anger': 0.5},
#  '늘다': {'enthusiasm': 1.0},
#  '밑': {'enthusiasm': 1.0},
#  '보니': {'enthusiasm': 0.6, 'anger': 0.4},
#  'fame': {'enthusiasm': 1.0},
#  '올라가다': {'enthusiasm': 1.0},
#  '생기다': {'enthusiasm': 1.0},
#  '쫓다': {'enthusiasm': 1.0},
#  'two': {'enthusiasm': 1.0},
#  '어': {'enthusiasm': 0.3, 'sadness': 0.2, 'anger': 0.5},
#  '이별': {'sadness': 0.54, 'longing': 0.36, 'lonely': 0.05, 'fear': 0.05},
#  '지우다': {'sadness': 0.45, 'longing': 0.24, 'lonely': 0.07, 'fear': 0.24},
#  '사진': {'sadness': 0.62, 'anger': 0.24, 'lonely': 0.14},
#  '괜찮다': {'sadness': 0.55,
#   'anger': 0.14,
#   'longing': 0.09,
#   'lonely': 0.09,
#   'fear': 0.14},
#  '보내다': {'sadness': 0.27, 'longing': 0.46, 'lonely': 0.16, 'fear': 0.11},
#  '추억': {'sadness': 0.22, 'longing': 0.32, 'lonely': 0.3, 'fear': 0.16},
#  '슬프다': {'sadness': 0.41, 'longing': 0.18, 'lonely': 0.29, 'fear': 0.12},
#  '찢다': {'sadness': 1.0},
#  '한장': {'sadness': 1.0},
#  '돌아오다': {'sadness': 0.33, 'anger': 0.11, 'longing': 0.22, 'lonely': 0.33},
#  '밉다': {'sadness': 0.5, 'longing': 0.3, 'lonely': 0.2},
#  '붙잡다': {'sadness': 0.29, 'longing': 0.18, 'lonely': 0.12, 'fear': 0.41},
#  '그리워': {'sadness': 0.18, 'longing': 0.55, 'lonely': 0.18, 'fear': 0.09},
#  '서럽다': {'sadness': 1.0},
#  '무너지다': {'sadness': 0.67, 'fear': 0.33},
#  '아니야': {'sadness': 1.0},
#  '슬픔': {'sadness': 0.29, 'longing': 0.36, 'lonely': 0.21, 'fear': 0.14},
#  '그립다': {'sadness': 0.19, 'longing': 0.67, 'lonely': 0.14},
#  '한쪽': {'sadness': 1.0},
#  '편지': {'sadness': 1.0},
#  '남이': {'sadness': 1.0},
#  '한잔': {'sadness': 0.38, 'longing': 0.38, 'lonely': 0.25},
#  '마시다': {'sadness': 1.0},
#  '바보': {'sadness': 0.27, 'longing': 0.18, 'lonely': 0.36, 'fear': 0.18},
#  '차갑다': {'sadness': 0.6, 'fear': 0.4},
#  '차오르다': {'sadness': 0.5, 'longing': 0.5},
#  '찢어지다': {'sadness': 0.5, 'fear': 0.5},
#  '텐': {'sadness': 1.0},
#  '잊히다': {'sadness': 0.27, 'lonely': 0.36, 'fear': 0.36},
#  '이해': {'sadness': 0.33, 'anger': 0.33, 'lonely': 0.33},
#  '견디다': {'sadness': 0.43, 'lonely': 0.57},
#  '끌다': {'sadness': 1.0},
#  '떠오르다': {'sadness': 0.6, 'longing': 0.4},
#  '습관': {'sadness': 0.43, 'anger': 0.57},
#  '말투': {'sadness': 0.75, 'longing': 0.25},
#  '안나': {'sadness': 1.0},
#  '거울': {'sadness': 0.33, 'lonely': 0.33, 'fear': 0.33},
#  '한참': {'sadness': 0.5, 'lonely': 0.5},
#  '찢기다': {'sadness': 1.0},
#  '사랑은': {'sadness': 0.38, 'lonely': 0.62},
#  '종이': {'sadness': 1.0},
#  '내 여자': {'sadness': 1.0},
#  '까맣다': {'sadness': 0.33, 'fear': 0.67},
#  '오늘밤': {'sadness': 0.5, 'lonely': 0.5},
#  '뜸': {'sadness': 1.0},
#  '들이다': {'sadness': 1.0},
#  '방법': {'sadness': 1.0},
#  '한마디': {'sadness': 0.4, 'anger': 0.6},
#  '주저앉히다': {'sadness': 1.0},
#  '예감': {'sadness': 1.0},
#  '사연': {'sadness': 1.0},
#  '곤란': {'sadness': 1.0},
#  '젖다': {'sadness': 0.33, 'anger': 0.67},
#  '평생': {'sadness': 0.33, 'anger': 0.67},
#  '화가': {'sadness': 0.4, 'anger': 0.6},
#  '떠나가다': {'sadness': 0.2, 'longing': 0.2, 'lonely': 0.4, 'fear': 0.2},
#  '쏟아지다': {'sadness': 1.0},
#  '스치다': {'sadness': 0.29, 'longing': 0.29, 'lonely': 0.43},
#  '두다': {'sadness': 0.2, 'anger': 0.2, 'longing': 0.4, 'lonely': 0.2},
#  '아파서': {'sadness': 1.0},
#  '원래': {'sadness': 0.29, 'anger': 0.43, 'fear': 0.29},
#  '소리치다': {'sadness': 0.33, 'longing': 0.17, 'fear': 0.5},
#  '이란': {'sadness': 0.4, 'anger': 0.6},
#  '아무렇다': {'sadness': 0.5, 'longing': 0.5},
#  '공간': {'sadness': 1.0},
#  '알': {'sadness': 1.0},
#  '생각나다': {'sadness': 0.5, 'longing': 0.5},
#  '미워하다': {'sadness': 0.5, 'longing': 0.5},
#  '끝내다': {'sadness': 1.0},
#  '진심': {'sadness': 1.0},
#  '서서': {'sadness': 1.0},
#  '위로': {'sadness': 0.67, 'longing': 0.33},
#  '못나다': {'sadness': 1.0},
#  '실감': {'sadness': 1.0},
#  '비다': {'sadness': 0.12, 'longing': 0.12, 'lonely': 0.65, 'fear': 0.12},
#  '라고': {'sadness': 1.0},
#  '장': {'sadness': 1.0},
#  '만지다': {'sadness': 0.5, 'fear': 0.5},
#  '이때': {'sadness': 1.0},
#  '우': {'sadness': 1.0},
#  '인지': {'sadness': 1.0},
#  '뻔하다': {'sadness': 0.2, 'anger': 0.8},
#  '거짓말': {'sadness': 0.08, 'anger': 0.62, 'longing': 0.08, 'fear': 0.23},
#  '방구석': {'sadness': 1.0},
#  '박히다': {'sadness': 1.0},
#  '느리다': {'sadness': 1.0},
#  '시커': {'sadness': 1.0},
#  '매지': {'sadness': 1.0},
#  '펜': {'sadness': 1.0},
#  '혼잣말': {'sadness': 1.0},
#  '미니': {'sadness': 1.0},
#  '홈': {'sadness': 1.0},
#  '피': {'sadness': 1.0},
#  '제목': {'sadness': 1.0},
#  '본지': {'sadness': 1.0},
#  '끈': {'sadness': 1.0},
#  'tv': {'sadness': 1.0},
#  '연예인': {'sadness': 1.0},
#  '정도': {'sadness': 0.25, 'anger': 0.75},
#  '통과': {'sadness': 1.0},
#  '의례': {'sadness': 1.0},
#  '쇼핑': {'sadness': 1.0},
#  '찾아오다': {'sadness': 0.17, 'lonely': 0.33, 'fear': 0.5},
#  '매일': {'sadness': 1.0},
#  '보채다': {'sadness': 1.0},
#  '핸드폰': {'sadness': 1.0},
#  '할거': {'sadness': 0.5, 'longing': 0.5},
#  '안경': {'sadness': 1.0},
#  '대체': {'sadness': 0.2, 'anger': 0.8},
#  '짓': {'sadness': 0.17, 'anger': 0.83},
#  '엎질러지다': {'sadness': 1.0},
#  '물': {'sadness': 0.33, 'anger': 0.67},
#  '웅크리다': {'sadness': 1.0},
#  '떠보다': {'sadness': 1.0},
#  '알람': {'sadness': 1.0},
#  '깨어나다': {'sadness': 1.0},
#  '중얼거리다': {'sadness': 1.0},
#  '참': {'sadness': 1.0},
#  '휴대폰': {'sadness': 1.0},
#  '확인': {'sadness': 1.0},
#  '마르다': {'sadness': 1.0},
#  '다리': {'sadness': 0.17, 'anger': 0.5, 'lonely': 0.33},
#  '짓밟다': {'sadness': 1.0},
#  '수많다': {'sadness': 0.2, 'fear': 0.8},
#  '흘러나오다': {'sadness': 1.0},
#  '행동': {'sadness': 1.0},
#  '어렵다': {'sadness': 0.33, 'anger': 0.67},
#  '꺼지다': {'anger': 1.0},
#  'x': {'anger': 1.0},
#  'blind': {'anger': 1.0},
#  '악연': {'anger': 1.0},
#  '아냐': {'anger': 0.9, 'lonely': 0.1},
#  'hate': {'anger': 0.75, 'fear': 0.25},
#  '증오': {'anger': 0.73, 'fear': 0.27},
#  'fuck': {'anger': 1.0},
#  '집다': {'anger': 1.0},
#  '미친개': {'anger': 1.0},
#  '끼': {'anger': 1.0},
#  '더럽다': {'anger': 1.0},
#  'blah': {'anger': 1.0},
#  '기도': {'anger': 0.6, 'fear': 0.4},
#  '남은': {'anger': 0.5, 'lonely': 0.33, 'fear': 0.17},
#  'block': {'anger': 1.0},
#  'really': {'anger': 1.0},
#  'Hate You': {'anger': 1.0},
#  '치우다': {'anger': 1.0},
#  'dog': {'anger': 1.0},
#  '감정': {'anger': 0.38, 'longing': 0.15, 'lonely': 0.31, 'fear': 0.15},
#  'please': {'anger': 0.42, 'fear': 0.58},
#  '빨아먹다': {'anger': 1.0},
#  '관심': {'anger': 1.0},
#  '미친놈': {'anger': 1.0},
#  '미친년': {'anger': 1.0},
#  '거짓': {'anger': 1.0},
#  '저주': {'anger': 0.67, 'fear': 0.33},
#  '잘못': {'anger': 0.5, 'lonely': 0.25, 'fear': 0.25},
#  '죽이다': {'anger': 0.67, 'lonely': 0.33},
#  'eah': {'anger': 1.0},
#  '변명': {'anger': 1.0},
#  'lovely': {'anger': 1.0},
#  'ugly': {'anger': 1.0},
#  '상처': {'anger': 0.21, 'longing': 0.42, 'fear': 0.37},
#  '꼴': {'anger': 1.0},
#  '나쁘다': {'anger': 1.0},
#  '지껄이다': {'anger': 1.0},
#  '복수': {'anger': 0.6, 'fear': 0.4},
#  '남편': {'anger': 1.0},
#  '찍다': {'anger': 1.0},
#  '웃기다': {'anger': 1.0},
#  '후': {'anger': 1.0},
#  '연락': {'anger': 0.75, 'longing': 0.25},
#  '정신': {'anger': 1.0},
#  '인': {'anger': 1.0},
#  'look': {'anger': 1.0},
#  '불편': {'anger': 1.0},
#  '불행': {'anger': 1.0},
#  '착하다': {'anger': 1.0},
#  '역겹다': {'anger': 1.0},
#  '화': {'anger': 1.0},
#  '박다': {'anger': 1.0},
#  '피곤': {'anger': 1.0},
#  '속이다': {'anger': 1.0},
#  '짓거리': {'anger': 1.0},
#  '도움': {'anger': 1.0},
#  '그만두다': {'anger': 1.0},
#  '정리': {'anger': 1.0},
#  '막히다': {'anger': 1.0},
#  '사다': {'anger': 1.0},
#  '배로': {'anger': 1.0},
#  '신아': {'anger': 1.0},
#  '빨다': {'anger': 1.0},
#  'bad': {'anger': 1.0},
#  'mosquito': {'anger': 1.0},
#  'woah': {'anger': 1.0},
#  'verse': {'anger': 1.0},
#  'shit': {'anger': 1.0},
#  '드라마': {'anger': 1.0},
#  '완전': {'anger': 1.0},
#  '쥐다': {'anger': 1.0},
#  '무섭다': {'anger': 0.17, 'lonely': 0.17, 'fear': 0.67},
#  '예지': {'anger': 1.0},
#  '오빠': {'anger': 1.0},
#  '바지': {'anger': 1.0},
#  '까다': {'anger': 0.67, 'longing': 0.33},
#  '병신': {'anger': 1.0},
#  '뱉다': {'anger': 1.0},
#  '자살': {'anger': 1.0},
#  '삼키다': {'anger': 1.0},
#  '비키다': {'anger': 1.0},
#  '응답': {'anger': 1.0},
#  '까': {'anger': 1.0},
#  '악몽': {'anger': 0.4, 'fear': 0.6},
#  '병': {'anger': 1.0},
#  '결혼식': {'anger': 1.0},
#  '신고': {'anger': 1.0},
#  '래': {'anger': 1.0},
#  '일기': {'anger': 1.0},
#  '남기다': {'anger': 0.17, 'longing': 0.5, 'lonely': 0.17, 'fear': 0.17},
#  '키스': {'anger': 1.0},
#  '스타': {'anger': 1.0},
#  '배신감': {'anger': 1.0},
#  'mouth': {'anger': 1.0},
#  '차려': {'anger': 1.0},
#  '빌': {'anger': 1.0},
#  'sad': {'anger': 1.0},
#  'sick': {'anger': 1.0},
#  '약하다': {'anger': 1.0},
#  'sorry': {'anger': 1.0},
#  '그리움': {'longing': 1.0},
#  '그날': {'longing': 1.0},
#  '흔적': {'longing': 1.0},
#  '그리워하다': {'longing': 1.0},
#  '파다': {'longing': 0.75, 'fear': 0.25},
#  '그대에게': {'longing': 1.0},
#  '가져가다': {'longing': 0.8, 'lonely': 0.2},
#  '마음속': {'longing': 1.0},
#  '대만': {'longing': 1.0},
#  '앓다': {'longing': 1.0},
#  '드리우다': {'longing': 1.0},
#  'far': {'longing': 1.0},
#  ...}

# %%
def lexicon_emotion_clf(sentence):
    temp = Counter()
    for word in lexicon_tokenizer_komoran(sentence,kmoran):
        try:
            temp = temp + Counter(vocab[word])
        except KeyError:
            pass
    emotion = list(temp.keys())
    score = list(temp.values())
    
    plt.pie(score, labels=emotion, autopct='%.1f%%')
    plt.show()
    
    return [k for k,v in dict(temp).items() if max(dict(temp).values()) == v]

# %%
test = """미래라는 종이에 나라는 글씨를 써
펜을 들고 용기를 내어 손을 뻗어
종이는 이미 검게 칠해져버렸고
아마 내가 설 자린 없던게 아닐까

다 지나온 길인걸
기억은 생기를 잃고
다가올 일들이
어두워 보이지 않아

맞이할 흐름이 두려워
고개를 떨군 것도
나아갈 자신이 없어
내딛지 못했던 것도

일상과도 같은 무력함에
지배당한 것도
모두 제자리에 다 묶여진 것 같아

과거라는 책자에 나라는 글씨를 봐
이렇게 텅 빈 자리가 많이있었나
난 밝게 빛났다 착각을 하고 있었고
실은 검디검은 글씨일 뿐이었다고

다 지나온 길인걸
기억은 생기를 잃고
다가올 일들이
어두워 보이지 않아

맞이할 흐름이 두려워
고개를 떨군 것도
나아갈 자신이 없어
내딛지 못했던 것도

일상과도 같은 무력함에
지배당한 것도
모두 제자리에 다 묶여진 것 같아

Rise up
I said rise up

난 모르겠어 난 모르겠어
난 모르겠어 난 모르겠어"""

# %%
lexicon_emotion_clf(lyrics_to_corpus(test))
# Out:
# ['fear']

# %%
#단어사전 저장
np.save('emotion_vocab_9class.npy', vocab)

# %% [markdown]
# ### 한국어 명사 구 , 형용사 구 , 부사 구 활용 연구
