# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re
from collections import Counter
import pymysql
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../data/emotion_normal.csv', encoding='utf-8')

# %%
# 1부터 시작하는 감정들을 0부터 시작
data['Emotion'] = data['Emotion'].map(lambda x : x - 1)

# %%
import text_hammer as th

# %%
from tqdm._tqdm_notebook import tqdm_notebook
tqdm_notebook.pandas()

def text_preprocessing(df,col_name):
    column = col_name
    df[column] = df[column].progress_apply(lambda x:str(x).lower())
    df[column] = df[column].progress_apply(lambda x: th.cont_exp(x)) #you're -> you are; i'm -> i am
    df[column] = df[column].progress_apply(lambda x: th.remove_emails(x))
#     df[column] = df[column].progress_apply(lambda x: th.remove_html_tags(x))
#     df[column] = df[column].progress_apply(lambda x: ps.remove_stopwords(x))

    df[column] = df[column].progress_apply(lambda x: th.remove_special_chars(x))
    df[column] = df[column].progress_apply(lambda x: th.remove_accented_chars(x))
#     df[column] = df[column].progress_apply(lambda x: th.make_base(x)) #ran -> run,
    return(df)

# %%
df_cleaned = text_preprocessing(data,'Text')
# Out:
#   0%|          | 0/29000 [00:00<?, ?it/s]
#   0%|          | 0/29000 [00:00<?, ?it/s]
#   0%|          | 0/29000 [00:00<?, ?it/s]
#   0%|          | 0/29000 [00:00<?, ?it/s]
#   0%|          | 0/29000 [00:00<?, ?it/s]

# %%
df_cleaned = df_cleaned.copy()

# %%
df_cleaned['Emotion'] = df_cleaned['Emotion'].astype('int')

# %%
from sklearn.model_selection import train_test_split
data_train,data_test = train_test_split(df_cleaned, test_size = 0.3, random_state = 42, stratify = df_cleaned.Emotion)

# %%
data_test
# Out:
#                                                     Text  Emotion
# 26347  i feel paranoid that every time i log onto fac...        5
# 6491                              school today greeeeeat        1
# 5878          yay mom bought sakura bodyshop lotion lt 3        1
# 20204  i feel stronger clearer but a little annoyed n...        4
# 17372      i feel bad that i don t have anything for you        3
# ...                                                  ...      ...
# 646    i kept thinking about how awesome i would feel...        0
# 27905  i was really worried that i would feel intimid...        5
# 27623  i spend time dating or attempting to date only...        5
# 11609                                  girl talk awesome        2
# 3703     i know how you feel lovely post xx xelliealicex        1
#
# [8700 rows x 2 columns]

# %%
from transformers import AutoTokenizer,TFBertModel
tokenizer = AutoTokenizer.from_pretrained('bert-base-cased')
bert = TFBertModel.from_pretrained('bert-base-cased')
# Out:
# Some layers from the model checkpoint at bert-base-cased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-cased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
tokenizer.save_pretrained('bert-tokenizer')
bert.save_pretrained('bert-model')

# %%
from transformers import BertTokenizer, TFBertModel, BertConfig,TFDistilBertModel,DistilBertTokenizer,DistilBertConfig
dbert_model = TFDistilBertModel.from_pretrained('distilbert-base-uncased')
# Out:
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertModel: ['vocab_projector', 'vocab_layer_norm', 'vocab_transform', 'activation_13']
# - This IS expected if you are initializing TFDistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFDistilBertModel were initialized from the model checkpoint at distilbert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertModel for predictions without further training.

# %%
x_train = tokenizer(
    text=data_train.Text.tolist(),
    add_special_tokens=True,
    max_length=70,
    truncation=True,
    padding=True, 
    return_tensors='tf',
    return_token_type_ids = False,
    return_attention_mask = True,
    verbose = True)


x_test = tokenizer(
    text=data_test.Text.tolist(),
    add_special_tokens=True,
    max_length=70,
    truncation=True,
    padding=True, 
    return_tensors='tf',
    return_token_type_ids = False,
    return_attention_mask = True,
    verbose = True)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import TruncatedNormal
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy
from tensorflow.keras.utils import to_categorical

# %%
max_len = 70
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense

input_ids = Input(shape=(max_len,), dtype=tf.int32, name="input_ids")
input_mask = Input(shape=(max_len,), dtype=tf.int32, name="attention_mask")
# embeddings = dbert_model(input_ids,attention_mask = input_mask)[0]


embeddings = bert(input_ids,attention_mask = input_mask)[0] #(0 is the last hidden states,1 means pooler_output)
out = tf.keras.layers.GlobalMaxPool1D()(embeddings)
out = Dense(128, activation='relu')(out)
out = tf.keras.layers.Dropout(0.1)(out)
out = Dense(32,activation = 'relu')(out)

y = Dense(6,activation = 'sigmoid')(out)
    
model = tf.keras.Model(inputs=[input_ids, input_mask], outputs=y)
model.layers[2].trainable = True
# for training bert our lr must be so small
# Out:
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7f949c206c40>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7f949c206c40>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.

# %%
optimizer = Adam(
    learning_rate=5e-05, # this learning rate is for bert model , taken from huggingface website 
    epsilon=1e-08,
    decay=0.01,
    clipnorm=1.0)

# Set loss and metrics
loss =CategoricalCrossentropy(from_logits = True)
metric = CategoricalAccuracy('balanced_accuracy'),
# Compile the model
model.compile(
    optimizer = optimizer,
    loss = loss, 
    metrics = metric)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 70)]         0
# __________________________________________________________________________________________________
# attention_mask (InputLayer)     [(None, 70)]         0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 108310272   input_ids[0][0]
#                                                                  attention_mask[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 768)          0           tf_bert_model[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          98432       global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 128)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           4128        dropout_56[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 6)            198         dense_1[0][0]
# ==================================================================================================
# Total params: 108,413,030
# Trainable params: 108,413,030
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.config.experimental_run_functions_eagerly(True)
tf.config.run_functions_eagerly(True)
# Out:
# WARNING:tensorflow:From <ipython-input-20-9b7e5e30d1f7>:1: experimental_run_functions_eagerly (from tensorflow.python.eager.def_function) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.run_functions_eagerly` instead of the experimental version.

# %%
train_history = model.fit(
    x ={'input_ids':x_train['input_ids'],'attention_mask':x_train['attention_mask']} ,
    y = to_categorical(data_train.Emotion),
    validation_data = (
    {'input_ids':x_test['input_ids'],'attention_mask':x_test['attention_mask']}, to_categorical(data_test.Emotion)),
    epochs=50,
    batch_size=64
)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#   1/318 [..............................] - ETA: 3:04 - loss: 1.8208 - balanced_accuracy: 0.1719WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#   2/318 [..............................] - ETA: 1:46 - loss: 1.8210 - balanced_accuracy: 0.1836WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#   3/318 [..............................] - ETA: 1:43 - loss: 1.8223 - balanced_accuracy: 0.1884WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#   4/318 [..............................] - ETA: 1:41 - loss: 1.8167 - balanced_accuracy: 0.1979WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#   5/318 [..............................] - ETA: 1:41 - loss: 1.8120 - balanced_accuracy: 0.2065WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#   6/318 [..............................] - ETA: 1:42 - loss: 1.8103 - balanced_accuracy: 0.2120WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#   7/318 [..............................] - ETA: 1:45 - loss: 1.8085 - balanced_accuracy: 0.2155WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#   8/318 [..............................] - ETA: 1:44 - loss: 1.8068 - balanced_accuracy: 0.2188WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#   9/318 [..............................] - ETA: 1:43 - loss: 1.8052 - balanced_accuracy: 0.2208WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  10/318 [..............................] - ETA: 1:42 - loss: 1.8035 - balanced_accuracy: 0.2215WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  11/318 [>.............................] - ETA: 1:41 - loss: 1.8017 - balanced_accuracy: 0.2221WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  12/318 [>.............................] - ETA: 1:40 - loss: 1.7999 - balanced_accuracy: 0.2229WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  13/318 [>.............................] - ETA: 1:40 - loss: 1.7980 - balanced_accuracy: 0.2236WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  14/318 [>.............................] - ETA: 1:39 - loss: 1.7963 - balanced_accuracy: 0.2243WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  15/318 [>.............................] - ETA: 1:41 - loss: 1.7944 - balanced_accuracy: 0.2251WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  16/318 [>.............................] - ETA: 1:41 - loss: 1.7923 - balanced_accuracy: 0.2258WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  17/318 [>.............................] - ETA: 1:41 - loss: 1.7904 - balanced_accuracy: 0.2264WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  18/318 [>.............................] - ETA: 1:40 - loss: 1.7886 - balanced_accuracy: 0.2270WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  19/318 [>.............................] - ETA: 1:40 - loss: 1.7873 - balanced_accuracy: 0.2275WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  20/318 [>.............................] - ETA: 1:40 - loss: 1.7860 - balanced_accuracy: 0.2281WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  21/318 [>.............................] - ETA: 1:39 - loss: 1.7848 - balanced_accuracy: 0.2286WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  22/318 [=>............................] - ETA: 1:39 - loss: 1.7835 - balanced_accuracy: 0.2291WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  23/318 [=>............................] - ETA: 1:38 - loss: 1.7822 - balanced_accuracy: 0.2298WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  24/318 [=>............................] - ETA: 1:38 - loss: 1.7810 - balanced_accuracy: 0.2304WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  25/318 [=>............................] - ETA: 1:38 - loss: 1.7797 - balanced_accuracy: 0.2311WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  26/318 [=>............................] - ETA: 1:37 - loss: 1.7785 - balanced_accuracy: 0.2317WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  27/318 [=>............................] - ETA: 1:37 - loss: 1.7771 - balanced_accuracy: 0.2326WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  28/318 [=>............................] - ETA: 1:36 - loss: 1.7757 - balanced_accuracy: 0.2333WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  29/318 [=>............................] - ETA: 1:36 - loss: 1.7743 - balanced_accuracy: 0.2340WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  30/318 [=>............................] - ETA: 1:36 - loss: 1.7729 - balanced_accuracy: 0.2347WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  31/318 [=>............................] - ETA: 1:35 - loss: 1.7715 - balanced_accuracy: 0.2355WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  32/318 [==>...........................] - ETA: 1:35 - loss: 1.7700 - balanced_accuracy: 0.2365WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  33/318 [==>...........................] - ETA: 1:34 - loss: 1.7686 - balanced_accuracy: 0.2374WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  34/318 [==>...........................] - ETA: 1:34 - loss: 1.7670 - balanced_accuracy: 0.2384WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  35/318 [==>...........................] - ETA: 1:34 - loss: 1.7654 - balanced_accuracy: 0.2394WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  36/318 [==>...........................] - ETA: 1:34 - loss: 1.7638 - balanced_accuracy: 0.2404WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  37/318 [==>...........................] - ETA: 1:33 - loss: 1.7622 - balanced_accuracy: 0.2414WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  38/318 [==>...........................] - ETA: 1:33 - loss: 1.7605 - balanced_accuracy: 0.2424WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  39/318 [==>...........................] - ETA: 1:33 - loss: 1.7588 - balanced_accuracy: 0.2433WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  40/318 [==>...........................] - ETA: 1:32 - loss: 1.7572 - balanced_accuracy: 0.2442WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  41/318 [==>...........................] - ETA: 1:32 - loss: 1.7555 - balanced_accuracy: 0.2451WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  42/318 [==>...........................] - ETA: 1:32 - loss: 1.7539 - balanced_accuracy: 0.2460WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  43/318 [===>..........................] - ETA: 1:31 - loss: 1.7522 - balanced_accuracy: 0.2470WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  44/318 [===>..........................] - ETA: 1:31 - loss: 1.7507 - balanced_accuracy: 0.2478WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  45/318 [===>..........................] - ETA: 1:30 - loss: 1.7491 - balanced_accuracy: 0.2488WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  46/318 [===>..........................] - ETA: 1:30 - loss: 1.7475 - balanced_accuracy: 0.2497WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  47/318 [===>..........................] - ETA: 1:30 - loss: 1.7459 - balanced_accuracy: 0.2507WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  48/318 [===>..........................] - ETA: 1:29 - loss: 1.7443 - balanced_accuracy: 0.2516WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  49/318 [===>..........................] - ETA: 1:29 - loss: 1.7427 - balanced_accuracy: 0.2526WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  50/318 [===>..........................] - ETA: 1:29 - loss: 1.7410 - balanced_accuracy: 0.2536WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  51/318 [===>..........................] - ETA: 1:28 - loss: 1.7393 - balanced_accuracy: 0.2545WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  52/318 [===>..........................] - ETA: 1:28 - loss: 1.7376 - balanced_accuracy: 0.2555WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  53/318 [====>.........................] - ETA: 1:28 - loss: 1.7358 - balanced_accuracy: 0.2564WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  54/318 [====>.........................] - ETA: 1:27 - loss: 1.7341 - balanced_accuracy: 0.2574WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  55/318 [====>.........................] - ETA: 1:27 - loss: 1.7325 - balanced_accuracy: 0.2583WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  56/318 [====>.........................] - ETA: 1:27 - loss: 1.7309 - balanced_accuracy: 0.2592WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  57/318 [====>.........................] - ETA: 1:26 - loss: 1.7293 - balanced_accuracy: 0.2601WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  58/318 [====>.........................] - ETA: 1:26 - loss: 1.7277 - balanced_accuracy: 0.2610WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  59/318 [====>.........................] - ETA: 1:26 - loss: 1.7261 - balanced_accuracy: 0.2619WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  60/318 [====>.........................] - ETA: 1:26 - loss: 1.7245 - balanced_accuracy: 0.2628WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  61/318 [====>.........................] - ETA: 1:25 - loss: 1.7228 - balanced_accuracy: 0.2638WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  62/318 [====>.........................] - ETA: 1:25 - loss: 1.7212 - balanced_accuracy: 0.2647WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  63/318 [====>.........................] - ETA: 1:24 - loss: 1.7195 - balanced_accuracy: 0.2657WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  64/318 [=====>........................] - ETA: 1:24 - loss: 1.7178 - balanced_accuracy: 0.2667WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  65/318 [=====>........................] - ETA: 1:24 - loss: 1.7161 - balanced_accuracy: 0.2677WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  66/318 [=====>........................] - ETA: 1:24 - loss: 1.7145 - balanced_accuracy: 0.2686WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  67/318 [=====>........................] - ETA: 1:24 - loss: 1.7128 - balanced_accuracy: 0.2696WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  68/318 [=====>........................] - ETA: 1:24 - loss: 1.7111 - balanced_accuracy: 0.2707WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  69/318 [=====>........................] - ETA: 1:23 - loss: 1.7095 - balanced_accuracy: 0.2716WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  70/318 [=====>........................] - ETA: 1:23 - loss: 1.7078 - balanced_accuracy: 0.2726WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  71/318 [=====>........................] - ETA: 1:23 - loss: 1.7062 - balanced_accuracy: 0.2736WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  72/318 [=====>........................] - ETA: 1:22 - loss: 1.7046 - balanced_accuracy: 0.2746WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  73/318 [=====>........................] - ETA: 1:22 - loss: 1.7029 - balanced_accuracy: 0.2756WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  74/318 [=====>........................] - ETA: 1:22 - loss: 1.7013 - balanced_accuracy: 0.2765WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  75/318 [======>.......................] - ETA: 1:21 - loss: 1.6996 - balanced_accuracy: 0.2775WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  76/318 [======>.......................] - ETA: 1:21 - loss: 1.6980 - balanced_accuracy: 0.2785WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  77/318 [======>.......................] - ETA: 1:21 - loss: 1.6964 - balanced_accuracy: 0.2794WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  78/318 [======>.......................] - ETA: 1:20 - loss: 1.6947 - balanced_accuracy: 0.2804WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  79/318 [======>.......................] - ETA: 1:20 - loss: 1.6930 - balanced_accuracy: 0.2814WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  80/318 [======>.......................] - ETA: 1:20 - loss: 1.6913 - balanced_accuracy: 0.2824WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  81/318 [======>.......................] - ETA: 1:19 - loss: 1.6897 - balanced_accuracy: 0.2833WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  82/318 [======>.......................] - ETA: 1:19 - loss: 1.6880 - balanced_accuracy: 0.2843WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  83/318 [======>.......................] - ETA: 1:18 - loss: 1.6864 - balanced_accuracy: 0.2853WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  84/318 [======>.......................] - ETA: 1:18 - loss: 1.6847 - balanced_accuracy: 0.2863WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  85/318 [=======>......................] - ETA: 1:18 - loss: 1.6830 - balanced_accuracy: 0.2872WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  86/318 [=======>......................] - ETA: 1:17 - loss: 1.6814 - balanced_accuracy: 0.2882WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  87/318 [=======>......................] - ETA: 1:17 - loss: 1.6797 - balanced_accuracy: 0.2892WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  88/318 [=======>......................] - ETA: 1:17 - loss: 1.6780 - balanced_accuracy: 0.2902WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  89/318 [=======>......................] - ETA: 1:17 - loss: 1.6763 - balanced_accuracy: 0.2912WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  90/318 [=======>......................] - ETA: 1:16 - loss: 1.6745 - balanced_accuracy: 0.2921WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  91/318 [=======>......................] - ETA: 1:16 - loss: 1.6728 - balanced_accuracy: 0.2931WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  92/318 [=======>......................] - ETA: 1:16 - loss: 1.6711 - balanced_accuracy: 0.2941WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  93/318 [=======>......................] - ETA: 1:15 - loss: 1.6693 - balanced_accuracy: 0.2951WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  94/318 [=======>......................] - ETA: 1:15 - loss: 1.6676 - balanced_accuracy: 0.2960WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  95/318 [=======>......................] - ETA: 1:15 - loss: 1.6659 - balanced_accuracy: 0.2970WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  96/318 [========>.....................] - ETA: 1:14 - loss: 1.6642 - balanced_accuracy: 0.2979WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  97/318 [========>.....................] - ETA: 1:14 - loss: 1.6624 - balanced_accuracy: 0.2989WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  98/318 [========>.....................] - ETA: 1:14 - loss: 1.6607 - balanced_accuracy: 0.2998WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
#  99/318 [========>.....................] - ETA: 1:13 - loss: 1.6590 - balanced_accuracy: 0.3007WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 100/318 [========>.....................] - ETA: 1:13 - loss: 1.6573 - balanced_accuracy: 0.3017WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 101/318 [========>.....................] - ETA: 1:13 - loss: 1.6556 - balanced_accuracy: 0.3026WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 102/318 [========>.....................] - ETA: 1:13 - loss: 1.6539 - balanced_accuracy: 0.3035WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 103/318 [========>.....................] - ETA: 1:12 - loss: 1.6523 - balanced_accuracy: 0.3044WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 104/318 [========>.....................] - ETA: 1:12 - loss: 1.6506 - balanced_accuracy: 0.3053WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 105/318 [========>.....................] - ETA: 1:12 - loss: 1.6489 - balanced_accuracy: 0.3062WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 106/318 [=========>....................] - ETA: 1:11 - loss: 1.6472 - balanced_accuracy: 0.3071WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 107/318 [=========>....................] - ETA: 1:11 - loss: 1.6455 - balanced_accuracy: 0.3080WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 108/318 [=========>....................] - ETA: 1:11 - loss: 1.6438 - balanced_accuracy: 0.3089WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 109/318 [=========>....................] - ETA: 1:10 - loss: 1.6421 - balanced_accuracy: 0.3098WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 110/318 [=========>....................] - ETA: 1:10 - loss: 1.6404 - balanced_accuracy: 0.3107WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 111/318 [=========>....................] - ETA: 1:10 - loss: 1.6388 - balanced_accuracy: 0.3116WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 112/318 [=========>....................] - ETA: 1:10 - loss: 1.6371 - balanced_accuracy: 0.3125WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 113/318 [=========>....................] - ETA: 1:09 - loss: 1.6354 - balanced_accuracy: 0.3134WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 114/318 [=========>....................] - ETA: 1:09 - loss: 1.6338 - balanced_accuracy: 0.3142WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 115/318 [=========>....................] - ETA: 1:08 - loss: 1.6321 - balanced_accuracy: 0.3151WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 116/318 [=========>....................] - ETA: 1:08 - loss: 1.6304 - balanced_accuracy: 0.3160WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 117/318 [==========>...................] - ETA: 1:08 - loss: 1.6288 - balanced_accuracy: 0.3169WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 118/318 [==========>...................] - ETA: 1:07 - loss: 1.6271 - balanced_accuracy: 0.3178WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 119/318 [==========>...................] - ETA: 1:07 - loss: 1.6255 - balanced_accuracy: 0.3186WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 120/318 [==========>...................] - ETA: 1:07 - loss: 1.6238 - balanced_accuracy: 0.3195WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 121/318 [==========>...................] - ETA: 1:06 - loss: 1.6221 - balanced_accuracy: 0.3204WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 122/318 [==========>...................] - ETA: 1:06 - loss: 1.6205 - balanced_accuracy: 0.3213WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 123/318 [==========>...................] - ETA: 1:06 - loss: 1.6188 - balanced_accuracy: 0.3221WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 124/318 [==========>...................] - ETA: 1:06 - loss: 1.6172 - balanced_accuracy: 0.3230WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 125/318 [==========>...................] - ETA: 1:05 - loss: 1.6155 - balanced_accuracy: 0.3239WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 126/318 [==========>...................] - ETA: 1:05 - loss: 1.6139 - balanced_accuracy: 0.3248WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 127/318 [==========>...................] - ETA: 1:05 - loss: 1.6122 - balanced_accuracy: 0.3256WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 128/318 [===========>..................] - ETA: 1:04 - loss: 1.6106 - balanced_accuracy: 0.3265WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 129/318 [===========>..................] - ETA: 1:04 - loss: 1.6089 - balanced_accuracy: 0.3274WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 130/318 [===========>..................] - ETA: 1:03 - loss: 1.6073 - balanced_accuracy: 0.3282WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 131/318 [===========>..................] - ETA: 1:03 - loss: 1.6056 - balanced_accuracy: 0.3291WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 132/318 [===========>..................] - ETA: 1:03 - loss: 1.6040 - balanced_accuracy: 0.3299WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 133/318 [===========>..................] - ETA: 1:02 - loss: 1.6024 - balanced_accuracy: 0.3308WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 134/318 [===========>..................] - ETA: 1:02 - loss: 1.6008 - balanced_accuracy: 0.3316WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 135/318 [===========>..................] - ETA: 1:02 - loss: 1.5992 - balanced_accuracy: 0.3325WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 136/318 [===========>..................] - ETA: 1:01 - loss: 1.5975 - balanced_accuracy: 0.3333WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 137/318 [===========>..................] - ETA: 1:01 - loss: 1.5959 - balanced_accuracy: 0.3341WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 138/318 [============>.................] - ETA: 1:01 - loss: 1.5943 - balanced_accuracy: 0.3349WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 139/318 [============>.................] - ETA: 1:00 - loss: 1.5927 - balanced_accuracy: 0.3358WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 140/318 [============>.................] - ETA: 1:00 - loss: 1.5912 - balanced_accuracy: 0.3366WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 141/318 [============>.................] - ETA: 1:00 - loss: 1.5896 - balanced_accuracy: 0.3374WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 142/318 [============>.................] - ETA: 59s - loss: 1.5880 - balanced_accuracy: 0.3382 WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 143/318 [============>.................] - ETA: 59s - loss: 1.5865 - balanced_accuracy: 0.3390WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 144/318 [============>.................] - ETA: 59s - loss: 1.5849 - balanced_accuracy: 0.3398WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 145/318 [============>.................] - ETA: 58s - loss: 1.5834 - balanced_accuracy: 0.3406WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 146/318 [============>.................] - ETA: 58s - loss: 1.5819 - balanced_accuracy: 0.3414WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 147/318 [============>.................] - ETA: 58s - loss: 1.5803 - balanced_accuracy: 0.3421WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 148/318 [============>.................] - ETA: 57s - loss: 1.5788 - balanced_accuracy: 0.3429WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 149/318 [=============>................] - ETA: 57s - loss: 1.5773 - balanced_accuracy: 0.3437WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 150/318 [=============>................] - ETA: 57s - loss: 1.5758 - balanced_accuracy: 0.3445WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 151/318 [=============>................] - ETA: 56s - loss: 1.5743 - balanced_accuracy: 0.3453WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 152/318 [=============>................] - ETA: 56s - loss: 1.5728 - balanced_accuracy: 0.3460WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 153/318 [=============>................] - ETA: 56s - loss: 1.5713 - balanced_accuracy: 0.3468WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 154/318 [=============>................] - ETA: 55s - loss: 1.5698 - balanced_accuracy: 0.3476WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 155/318 [=============>................] - ETA: 55s - loss: 1.5683 - balanced_accuracy: 0.3483WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 156/318 [=============>................] - ETA: 55s - loss: 1.5669 - balanced_accuracy: 0.3491WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 157/318 [=============>................] - ETA: 54s - loss: 1.5654 - balanced_accuracy: 0.3499WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 158/318 [=============>................] - ETA: 54s - loss: 1.5639 - balanced_accuracy: 0.3506WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 159/318 [==============>...............] - ETA: 54s - loss: 1.5625 - balanced_accuracy: 0.3514WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 160/318 [==============>...............] - ETA: 53s - loss: 1.5610 - balanced_accuracy: 0.3521WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 161/318 [==============>...............] - ETA: 53s - loss: 1.5596 - balanced_accuracy: 0.3529WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 162/318 [==============>...............] - ETA: 53s - loss: 1.5581 - balanced_accuracy: 0.3536WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 163/318 [==============>...............] - ETA: 52s - loss: 1.5567 - balanced_accuracy: 0.3543WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 164/318 [==============>...............] - ETA: 52s - loss: 1.5552 - balanced_accuracy: 0.3551WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 165/318 [==============>...............] - ETA: 51s - loss: 1.5538 - balanced_accuracy: 0.3558WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 166/318 [==============>...............] - ETA: 51s - loss: 1.5524 - balanced_accuracy: 0.3565WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 167/318 [==============>...............] - ETA: 51s - loss: 1.5510 - balanced_accuracy: 0.3572WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 168/318 [==============>...............] - ETA: 51s - loss: 1.5496 - balanced_accuracy: 0.3580WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 169/318 [==============>...............] - ETA: 50s - loss: 1.5482 - balanced_accuracy: 0.3587WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 170/318 [===============>..............] - ETA: 50s - loss: 1.5467 - balanced_accuracy: 0.3594WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 171/318 [===============>..............] - ETA: 50s - loss: 1.5453 - balanced_accuracy: 0.3601WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 172/318 [===============>..............] - ETA: 49s - loss: 1.5439 - balanced_accuracy: 0.3608WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 173/318 [===============>..............] - ETA: 49s - loss: 1.5425 - balanced_accuracy: 0.3616WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 174/318 [===============>..............] - ETA: 49s - loss: 1.5411 - balanced_accuracy: 0.3623WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 175/318 [===============>..............] - ETA: 48s - loss: 1.5397 - balanced_accuracy: 0.3630WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 176/318 [===============>..............] - ETA: 48s - loss: 1.5383 - balanced_accuracy: 0.3637WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 177/318 [===============>..............] - ETA: 48s - loss: 1.5369 - balanced_accuracy: 0.3644WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 178/318 [===============>..............] - ETA: 47s - loss: 1.5355 - balanced_accuracy: 0.3651WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 179/318 [===============>..............] - ETA: 47s - loss: 1.5341 - balanced_accuracy: 0.3658WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 180/318 [===============>..............] - ETA: 47s - loss: 1.5327 - balanced_accuracy: 0.3665WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 181/318 [================>.............] - ETA: 46s - loss: 1.5313 - balanced_accuracy: 0.3672WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# ...
# 238/318 [=====================>........] - ETA: 27s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 239/318 [=====================>........] - ETA: 26s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 240/318 [=====================>........] - ETA: 26s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 241/318 [=====================>........] - ETA: 26s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 242/318 [=====================>........] - ETA: 25s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 243/318 [=====================>........] - ETA: 25s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 244/318 [======================>.......] - ETA: 25s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 245/318 [======================>.......] - ETA: 24s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 246/318 [======================>.......] - ETA: 24s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 247/318 [======================>.......] - ETA: 24s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 248/318 [======================>.......] - ETA: 23s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 249/318 [======================>.......] - ETA: 23s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 250/318 [======================>.......] - ETA: 23s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 251/318 [======================>.......] - ETA: 22s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 252/318 [======================>.......] - ETA: 22s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 253/318 [======================>.......] - ETA: 22s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 254/318 [======================>.......] - ETA: 21s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 255/318 [=======================>......] - ETA: 21s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 256/318 [=======================>......] - ETA: 21s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 257/318 [=======================>......] - ETA: 20s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 258/318 [=======================>......] - ETA: 20s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 259/318 [=======================>......] - ETA: 20s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 260/318 [=======================>......] - ETA: 19s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 261/318 [=======================>......] - ETA: 19s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 262/318 [=======================>......] - ETA: 18s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 263/318 [=======================>......] - ETA: 18s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 264/318 [=======================>......] - ETA: 18s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 265/318 [========================>.....] - ETA: 17s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 266/318 [========================>.....] - ETA: 17s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 267/318 [========================>.....] - ETA: 17s - loss: 0.1326 - balanced_accuracy: 0.9539WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 268/318 [========================>.....] - ETA: 16s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 269/318 [========================>.....] - ETA: 16s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 270/318 [========================>.....] - ETA: 16s - loss: 0.1327 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 271/318 [========================>.....] - ETA: 15s - loss: 0.1327 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 272/318 [========================>.....] - ETA: 15s - loss: 0.1327 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 273/318 [========================>.....] - ETA: 15s - loss: 0.1327 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 274/318 [========================>.....] - ETA: 14s - loss: 0.1327 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 275/318 [========================>.....] - ETA: 14s - loss: 0.1327 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 276/318 [=========================>....] - ETA: 14s - loss: 0.1327 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 277/318 [=========================>....] - ETA: 13s - loss: 0.1327 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 278/318 [=========================>....] - ETA: 13s - loss: 0.1327 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 279/318 [=========================>....] - ETA: 13s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 280/318 [=========================>....] - ETA: 12s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 281/318 [=========================>....] - ETA: 12s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 282/318 [=========================>....] - ETA: 12s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 283/318 [=========================>....] - ETA: 11s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 284/318 [=========================>....] - ETA: 11s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 285/318 [=========================>....] - ETA: 11s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 286/318 [=========================>....] - ETA: 10s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 287/318 [==========================>...] - ETA: 10s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 288/318 [==========================>...] - ETA: 10s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 289/318 [==========================>...] - ETA: 9s - loss: 0.1326 - balanced_accuracy: 0.9540 WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 290/318 [==========================>...] - ETA: 9s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 291/318 [==========================>...] - ETA: 9s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 292/318 [==========================>...] - ETA: 8s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 293/318 [==========================>...] - ETA: 8s - loss: 0.1326 - balanced_accuracy: 0.9540WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 294/318 [==========================>...] - ETA: 8s - loss: 0.1326 - balanced_accuracy: 0.9541WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 295/318 [==========================>...] - ETA: 7s - loss: 0.1326 - balanced_accuracy: 0.9541WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 296/318 [==========================>...] - ETA: 7s - loss: 0.1326 - balanced_accuracy: 0.9541WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 297/318 [===========================>..] - ETA: 7s - loss: 0.1326 - balanced_accuracy: 0.9541WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.

# %%
model.save_weights('new_multi_sentiment_weights')

# %%
predicted_raw = model.predict({'input_ids':x_test['input_ids'],'attention_mask':x_test['attention_mask']})

# %%
predicted_raw[2]

# %%
y_predicted = np.argmax(predicted_raw, axis = 1)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(data_test.Emotion, y_predicted))

# %%
# 시각화
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string], '')
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

# %%
plot_graphs(train_history, 'balanced_accuracy')

# %%
def emotion_predict(sentence):
    x_val = tokenizer(
        text=sentence,
        add_special_tokens=True,
        max_length=70,
        truncation=True,
        padding='max_length', 
        return_tensors='tf',
        return_token_type_ids = False,
        return_attention_mask = True,
        verbose = True)
    validation = model.predict({'input_ids':x_val['input_ids'],'attention_mask':x_val['attention_mask']})*100
    return np.argmax(validation, axis = 1)
